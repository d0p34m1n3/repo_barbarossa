# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=307,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# {'alias': 'NGZ2018G2019V2018Z2018', 'strategy_id': 1141}

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='LNQ18M18VCS',description_string='strategy_class=vcs&betsize=39197')
# Out:
# {'alias': 'LNQ18M18VCS', 'strategy_id': 1155}

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
tfl.load_tt_trades(tags2exclude=['ifs','ocs','DeltaHedge'])     # 'DeltaHedge','ocs'
#tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
import ta.trade_fill_loader as tfl
tt_export_frame_filtered = tfl.load_latest_tt_fills(tags2exclude=['ifs','ocs','DeltaHedge'])

tt_export_frame_filtered
tags2exclude=['ifs','ocs','DeltaHedge']

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_jan18',as_of_date=cu.get_doubledate())
wuhu
# Out:
# WZ18N18VCS
#      ticker option_type  strike_price instrument    qty
# 0   CLM2018        None           NaN          F  -0.72
# 1   CLZ2018        None           NaN          F   0.30
# 2    CU2018        None           NaN          F  -0.22
# 3    CZ2018        None           NaN          F   0.18
# 4   ECH2018        None           NaN          F   0.30
# 5   ECM2018        None           NaN          F   0.14
# 6   ESH2018        None           NaN          F  14.00
# 7   ESM2018        None           NaN          F -14.20
# 8   LCM2018        None           NaN          F  -0.20
# 9   LCV2018        None           NaN          F   0.09
# 10  LNJ2018        None           NaN          F   0.12
# 11  LNK2018        None           NaN          F   0.20
# 17  SMN2018        None           NaN          F  -0.11
# 18  SMU2018        None           NaN          F   0.39
# 21   WN2018        None           NaN          F -22.10
# 22   WZ2018        None           NaN          F  13.49

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='EC_OptionInventoryMar2018')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['ticker_portfolio']
print(output['strike_portfolio']['total_oev'].sum())
output['ticker_portfolio']
output['strike_portfolio']
# Out:
# -9.341811244247522
#     ticker option_type  strike_price instrument  qty     theta      vega  \
# 0  ECH2018           C         1.165          O  -90 -0.000079  0.009814
# 1  ECH2018           C         1.230          O    7 -0.000393  0.070065
# 2  ECH2018           P         1.165          O  -90 -0.000073  0.008991
# 3  ECH2018           P         1.230          O    7 -0.000393  0.070073
#
#       delta  delta_diff       oev  total_oev  dollar_theta  dollar_vega
# 0  0.978133    0.478133  0.128855 -11.596962     884.25000 -1104.103125
# 1  0.337435    0.162565  0.919912   6.439386    -343.77875   613.069713
# 2 -0.019250    0.519250  0.118048 -10.624338     826.31250 -1011.503250
# 3 -0.661947    1.161947  0.920015   6.440103    -343.60375   613.137963

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='SIN17U17VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  total_delta  \
# 0           SIN2017      18.0775          4.90             -5.10        -0.20
# 1           SIU2017      18.1400         -4.76              5.13         0.37
#
#    hedge
# 0   0.20
# 1  -0.37

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='RBV2018X2018X2018Z2018',broker='abn')

# %%
import ta.man_position_reconciler as mpr
mpr.reconcile_position()
# Out:
# Empty DataFrame
# Columns: [generalized_ticker, qty_x, ticker, option_type, strike_price, instrument, qty_y, qty_diff]
# Index: []

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='EC_OptionInventoryMar2018',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
# Empty DataFrame
# Columns: [total_oev, theta, dollar_vega, ticker]
# Index: []

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                          alias generalized_ticker instrument option_type  \
# 4    EC_OptionInventoryMar2018                NaN    options           P
# 3    EC_OptionInventoryMar2018                NaN    options           P
# 44                   Portfolio   ECH2018-P-1.2300    options           P
# 43                   Portfolio   ECH2018-P-1.1650    options           P
# 42                   Portfolio   ECH2018-C-1.2300    options           C
# 41                   Portfolio   ECH2018-C-1.1650    options           C
# 2    EC_OptionInventoryMar2018                NaN    options           C
# 1    EC_OptionInventoryMar2018                NaN    options           C
# 51                   Portfolio            ESH2018    futures        None
# 6                  delta_jan18                NaN    futures        None
# 0    EC_OptionInventoryMar2018                NaN    futures        None
# 40                   Portfolio            ECH2018    futures        None
# 4                  delta_jan18                NaN    futures        None
# 88                   Portfolio  LNJ2018-C-74.0000    options           C
# 0                  LNK18J18VCS                NaN    futures        None
# 89                   Portfolio  LNJ2018-P-74.0000    options           P
# 2                  LNK18J18VCS                NaN    options           P
# 1                  LNK18J18VCS                NaN    options           C
# 87                   Portfolio            LNJ2018    futures        None
# 10                 delta_jan18                NaN    futures        None
# 0          CLK2018_CLM2018_ocs                NaN    futures        None
# 16                   Portfolio            CLK2018    futures        None
# 4           spreadCarryFeb18_2                NaN    futures        None
# 54                   Portfolio            FCJ2018    futures        None
# 0          BM2018_BN2018_ocs_2                NaN    futures        None
# 2                    Portfolio             BM2018    futures        None
# 46                   Portfolio   ECK2018-P-1.2350    options           P
# 45                   Portfolio   ECK2018-C-1.2350    options           C
# 0             ECK2018_long_scv                NaN    options           C
# 1             ECK2018_long_scv                NaN    options           P
# ..                         ...                ...        ...         ...
# 116                  Portfolio            SBH2019    futures        None
# 0        CK2019N2019H2019K2019                NaN    futures        None
# 65                   Portfolio            KWH2019    futures        None
# 13                   Portfolio             CH2019    futures        None
# 120                  Portfolio             SH2019    futures        None
# 2             spreadCarryFeb18                NaN    futures        None
# 6             spreadCarryFeb18                NaN    futures        None
# 1        SH2019K2019F2019H2019                NaN    futures        None
# 2        SH2019K2019F2019H2019                NaN    futures        None
# 14                   Portfolio             CK2019    futures        None
# 1        CK2019N2019H2019K2019                NaN    futures        None
# 121                  Portfolio             SK2019    futures        None
# 20                   Portfolio            CLM2019    futures        None
# 0       CLU2019Z2019M2019U2019                NaN    futures        None
# 1     CLH2019M2019Z2018H2019_3                NaN    futures        None
# 0          EDM2019_EDU2019_ocs                NaN    futures        None
# 48                   Portfolio            EDM2019    futures        None
# 27                   Portfolio             CN2019    futures        None
# 2        CK2019N2019H2019K2019                NaN    futures        None
# 1       CLU2019Z2019M2019U2019                NaN    futures        None
# 22                   Portfolio            CLU2019    futures        None
# 49                   Portfolio            EDU2019    futures        None
# 1          EDM2019_EDU2019_ocs                NaN    futures        None
# 1     EDZ2019H2020U2019Z2019_2                NaN    futures        None
# 26                   Portfolio            CLZ2019    futures        None
# 2       CLU2019Z2019M2019U2019                NaN    futures        None
# 50                   Portfolio            EDZ2019    futures        None
# 2     EDZ2019H2020U2019Z2019_2                NaN    futures        None
# 47                   Portfolio            EDH2020    futures        None
# 0     EDZ2019H2020U2019Z2019_2                NaN    futures        None
#
#           qty strike_price   ticker  tr_days_2roll
# 4          10         1.23  ECH2018              4
# 3         -90        1.165  ECH2018              4
# 44      10.00       1.2300  ECH2018              4
# 43     -90.00       1.1650  ECH2018              4
# 42      10.00       1.2300  ECH2018              4
# 41     -90.00       1.1650  ECH2018              4
# 2          10         1.23  ECH2018              4
# 1         -90        1.165  ECH2018              4
# 51      14.00         None  ESH2018              9
# 6          14          NaN  ESH2018              9
# 0       87.58          NaN  ECH2018             12
# 40      85.00         None  ECH2018             12
# 4       -2.58          NaN  ECH2018             12
# 88     -25.00      74.0000  LNJ2018             28
# 0      -11.91          NaN  LNJ2018             28
# 89     -25.00      74.0000  LNJ2018             28
# 2         -25           74  LNJ2018             28
# 1         -25           74  LNJ2018             28
# 87     -11.00         None  LNJ2018             28
# 10       0.91          NaN  LNJ2018             28
# 0         -21          NaN  CLK2018             33
# 16     -21.00         None  CLK2018             33
# 4          -8          NaN  FCJ2018             38
# 54      -8.00         None  FCJ2018             38
# 0         -28          NaN   BM2018             41
# 2      -28.00         None   BM2018             41
# 46      21.00       1.2350  ECK2018             43
# 45      21.00       1.2350  ECK2018             43
# 0          21        1.235  ECK2018             43
# 1          21        1.235  ECK2018             43
# ..        ...          ...      ...            ...
# 116    -79.00         None  SBH2019            250
# 0          -2          NaN   CH2019            260
# 65      36.00         None  KWH2019            260
# 13      62.00         None   CH2019            260
# 120    130.00         None   SH2019            260
# 2          64          NaN   CH2019            260
# 6          36          NaN  KWH2019            260
# 1         130          NaN   SH2019            260
# 2         -65          NaN   SK2019            303
# 14       4.00         None   CK2019            303
# 1           4          NaN   CK2019            303
# 121    -65.00         None   SK2019            303
# 20    -125.00         None  CLM2019            308
# 0         -39          NaN  CLM2019            308
# 1         -86          NaN  CLM2019            308
# 0          16          NaN  EDM2019            328
# 48      16.00         None  EDM2019            328
# 27      -2.00         None   CN2019            342
# 2          -2          NaN   CN2019            342
# 1          85          NaN  CLU2019            371
# 22      85.00         None  CLU2019            371
# 49   -1386.00         None  EDU2019            391
# 1         -16          NaN  EDU2019            391
# 1       -1370          NaN  EDU2019            391
# 26     -46.00         None  CLZ2019            436
# 2         -46          NaN  CLZ2019            436
# 50    2740.00         None  EDZ2019            455
# 2        2740          NaN  EDZ2019            455
# 47   -1370.00         None  EDH2020            518
# 0       -1370          NaN  EDH2020            518
#
# [338 rows x 8 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryDec17_2',strategy_to='spreadCarryFeb18_2')

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='KCU2018Z2018N2018U2018',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='LCJ2018_LCM2018_ocs')
wuhu

# sell 1 Z futures after

# W_KW_ifs_2_Aug-2017
# HO FG, 10
# Out:
#     ticker option_type  strike_price instrument  qty
# 0  KCN2018        None           NaN          F  -52
# 1  KCU2018        None           NaN          F  104
# 2  KCZ2018        None           NaN          F  -52

# %%
wuhu  = tas.get_net_position_4strategy_alias(alias='KCU2018Z2018N2018U2018')
wuhu
# Out:
#     ticker option_type  strike_price instrument  qty
# 0  KCN2018        None           NaN          F  -52
# 1  KCU2018        None           NaN          F  104
# 2  KCZ2018        None           NaN          F  -52

# %%
import ta.position_close_helper as pch

#pch.calc_intrday_pnl_from_prices(alias='GCZ17J18VCS',structure_price=38.6,GCZ2017=1288.9,GCJ2018=1297)
#pch.calc_intrday_pnl_from_prices(alias='SQ18X18VCS',structure_price=17.125,SQ2018=1058,SX2018=1032)
pch.calc_intrday_pnl_from_prices(alias='LNK18J18VCS',structure_price=0.27,LNJ2018=68.225,LNK2018=75.2)

# sell 3 CLF
# Out:
# {'futures_pnl': 6058.800000000036,
#  'structure_pnl': -8799.9999999999982,
#  'structure_settle': 1.1499999999999999}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='ESH2018_short_scv',structure_price=169.25,ESH2018=2602.25)
# sell 2 WH futures
# Out:
# {'futures_pnl': 170.75, 'structure_pnl': -0.0, 'structure_settle': 169.25}

# %%
0.8125*64
# Out:
# 52.0

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017'],
                                            structure_price = 10.275,
                                            strike_list=[68],
                                            underlying_price_list=[78.025],
                                            qty = -7,
                                            structure_type='straddle')


# sell 2 LNM futures
# Out:
# {'delta_pnl': 185.49394290000703,
#  'structure_pnl': 70.000000000001,
#  'structure_price_yesterday': 10.3,
#  'total_pnl': 255.49394290000802}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['CU2018','CZ2018'],
                                            structure_price =7,
                                            strike_list=[380,390],
                                            underlying_price_list=[387,394.5],
                                            qty =-173,
                                            structure_type='straddle_spread')

# sell 7 ZSN futures
# Out:
# {'delta_pnl': -229.18157699999989,
#  'structure_pnl': -4325.0,
#  'structure_price_yesterday': 6.5,
#  'total_pnl': -4554.1815770000003}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNV2017','LNZ2017'],
                                            structure_price =-0.6,
                                            strike_list=[71,64],
                                            underlying_price_list=[62.85,58.2],
                                            qty =15,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': 1370.0762159999849,
#  'structure_pnl': -1349.9999999999998,
#  'structure_price_yesterday': -0.375,
#  'total_pnl': 20.076215999985152}
