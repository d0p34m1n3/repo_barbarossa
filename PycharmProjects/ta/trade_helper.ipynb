# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=187,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# {'alias': 'BM2019N2019N2019Q2019', 'strategy_id': 1358}

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='SMZ18V18VCS',description_string='strategy_class=vcs&betsize=39197')
# Out:
# {'alias': 'SMZ18V18VCS', 'strategy_id': 1374}

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
tfl.load_tt_trades(tags2exclude=['ifs','ocs','DeltaHedge'])     # 'DeltaHedge','ocs'
#tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
import ta.trade_fill_loader as tfl
tt_export_frame_filtered = tfl.load_latest_tt_fills(tags2exclude=['ifs','ocs','DeltaHedge'])

tt_export_frame_filtered
tags2exclude=['ifs','ocs','DeltaHedge']

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
#sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_jan18',as_of_date=cu.get_doubledate())
wuhu
# Out:
#      ticker option_type  strike_price instrument    qty
# 0   CLM2018        None           NaN          F   0.03
# 1   CLZ2018        None           NaN          F   0.06
# 2    CN2018        None           NaN          F   0.07
# 3    CU2018        None           NaN          F  -0.27
# 4    CZ2018        None           NaN          F  -0.30
# 5   ECH2018        None           NaN          F   5.00
# 6   ECM2018        None           NaN          F  -5.20
# 9   LCM2018        None           NaN          F  -1.68
# 10  LCV2018        None           NaN          F   1.19
# 13  LNM2018        None           NaN          F  -0.13
# 14  LNQ2018        None           NaN          F  -0.12
# 20  SMN2018        None           NaN          F   0.25
# 21  SMU2018        None           NaN          F  -0.71
# 24   WN2018        None           NaN          F  13.19
# 25   WZ2018        None           NaN          F -13.26

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='CN2018_short_scv')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['ticker_portfolio']
print(output['strike_portfolio']['total_oev'].sum())
output['ticker_portfolio']
output['strike_portfolio']
# Out:
# -63.43589631294344
#    ticker option_type  strike_price instrument  qty     theta       vega  \
# 0  CN2018           C           400          O  -34 -0.086696  68.638681
# 1  CN2018           P           400          O  -34 -0.086082  68.697261
#
#       delta  delta_diff       oev  total_oev  dollar_theta  dollar_vega
# 0  0.352105    0.147895  0.932483 -31.704419    147.382384 -1166.857582
# 1 -0.641702    1.141702  0.933279 -31.731477    146.338924 -1167.853439

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='SIN17U17VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  total_delta  \
# 0           SIN2017      18.0775          4.90             -5.10        -0.20
# 1           SIU2017      18.1400         -4.76              5.13         0.37
#
#    hedge
# 0   0.20
# 1  -0.37

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='HOX2018F2019U2018X2018',broker='abn')

# %%
import ta.man_position_reconciler as mpr
mpr.reconcile_position()
# Out:
#     generalized_ticker  qty_x   ticker option_type strike_price instrument  \
# 0              SMF2019    -10  SMF2019        None         None          F
# 16              SQ2018    -12   SQ2018        None         None          F
# 17              SU2018     10   SU2018        None         None          F
# 18              SX2018    -31   SX2018        None         None          F
# 25              WN2018    145   WN2018        None         None          F
# 27              WZ2018    -90   WZ2018        None         None          F
# 36             LCQ2018     21  LCQ2018        None         None          F
# 37             LCV2018     19  LCV2018        None         None          F
# 38             LCZ2018    -33  LCZ2018        None         None          F
# 69             KCN2018   -158  KCN2018        None         None          F
# 70             KCU2018    335  KCU2018        None         None          F
# 71             KCZ2018   -177  KCZ2018        None         None          F
# 73             CCU2018    168  CCU2018        None         None          F
# 74             CCZ2018   -429  CCZ2018        None         None          F
# 75             CCH2019    238  CCH2019        None         None          F
# 78             CLX2018    -12  CLX2018        None         None          F
# 79             CLZ2018    387  CLZ2018        None         None          F
# 108            NGF2019    260  NGF2019        None         None          F
# 109            NGG2019   -501  NGG2019        None         None          F
# 110            NGH2019    241      NaN         NaN          NaN        NaN
# 133             BU2019    -71   BU2019        None         None          F
# 136             BZ2019    382   BZ2019        None         None          F
# 138              BH202    -77   BH2020        None         None          F
# 139            BOH2019    NaN  BOH2019        None         None          F
# 140            BOK2019    NaN  BOK2019        None         None          F
# 141            RBQ2018    NaN  RBQ2018        None         None          F
# 142            RBU2018    NaN  RBU2018        None         None          F
# 143            SBK2019    NaN  SBK2019        None         None          F
# 144            SBN2019    NaN  SBN2019        None         None          F
# 145            SMQ2018    NaN  SMQ2018        None         None          F
# 146            SMU2018    NaN  SMU2018        None         None          F
# 147            SMV2018    NaN  SMV2018        None         None          F
# 148            SMZ2018    NaN  SMZ2018        None         None          F
#
#        qty_y  qty_diff
# 0      20.00       -30
# 16     -5.00        -7
# 17    -10.00        20
# 18    -17.00       -14
# 25    150.00        -5
# 27    -93.00         3
# 36     37.00       -16
# 37     10.00         9
# 38    -37.00         4
# 69   -105.00       -53
# 70    230.00       105
# 71   -125.00       -52
# 73    -12.00       180
# 74    -63.00      -366
# 75     52.00       186
# 78    -17.00         5
# 79    392.00        -5
# 108     1.00       259
# 109    -1.00      -500
# 110      NaN       NaN
# 133  -126.00        55
# 136   497.00      -115
# 138  -137.00        60
# 139    79.00       NaN
# 140   -79.00       NaN
# 141   -13.00       NaN
# 142    13.00       NaN
# 143   -34.00       NaN
# 144    34.00       NaN
# 145    19.00       NaN
# 146   -19.00       NaN
# 147     1.00       NaN
# 148   -30.00       NaN

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='EC_OptionInventoryMar2018',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
# Empty DataFrame
# Columns: [total_oev, theta, dollar_vega, ticker]
# Index: []

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                         alias  generalized_ticker instrument option_type  \
# 5                 delta_jan18                 NaN    futures        None
# 45                  Portfolio             ECH2018    futures        None
# 0       FCJ2018_FCK2018_ocs_8                 NaN    futures        None
# 53                  Portfolio             FCJ2018    futures        None
# 0         BM2018_BN2018_ocs_3                 NaN    futures        None
# 2                   Portfolio              BM2018    futures        None
# 0            ECK2018_long_scv                 NaN    options           C
# 1            ECK2018_long_scv                 NaN    options           P
# 46                  Portfolio    ECK2018-C-1.2350    options           C
# 47                  Portfolio    ECK2018-P-1.2350    options           P
# 33                  Portfolio             CTK2018    futures        None
# 4          spreadCarryFeb18_2                 NaN    futures        None
# 0       LNK2018_LNM2018_ocs_4                 NaN    futures        None
# 85                  Portfolio             LNK2018    futures        None
# 0      BOK2018Q2018Q2018V2018                 NaN    futures        None
# 4                   Portfolio             BOK2018    futures        None
# 8            spreadCarryFeb18                 NaN    futures        None
# 23                  Portfolio   CLM2018-P-58.0000    options           P
# 22                  Portfolio   CLM2018-C-58.0000    options           C
# 1                 CLM18Z18VCS                 NaN    options           C
# 2                 CLM18Z18VCS                 NaN    options           P
# 21                  Portfolio             CLM2018    futures        None
# 0                 delta_jan18                 NaN    futures        None
# 2          spreadCarryFeb18_2                 NaN    futures        None
# 0                 CLM18Z18VCS                 NaN    futures        None
# 1       FCJ2018_FCK2018_ocs_8                 NaN    futures        None
# 54                  Portfolio             FCK2018    futures        None
# 74                  Portfolio  LCM2018-P-115.0000    options           P
# 2                 LCV18M18VCS                 NaN    options           C
# 6                 LCV18M18VCS                 NaN    options           P
# ..                        ...                 ...        ...         ...
# 1           CH2019_CK2019_ocs                 NaN    futures        None
# 19                  Portfolio              CK2019    futures        None
# 2       SH2019K2019F2019H2019                 NaN    futures        None
# 111                 Portfolio              SK2019    futures        None
# 1       CH2019K2019Z2018H2019                 NaN    futures        None
# 14                  Portfolio             CCK2019    futures        None
# 1      CCH2019K2019Z2018H2019                 NaN    futures        None
# 1         CCH2019_CCK2019_ocs                 NaN    futures        None
# 0      CLU2019Z2019M2019U2019                 NaN    futures        None
# 24                  Portfolio             CLM2019    futures        None
# 1    CLH2019M2019Z2018H2019_3                 NaN    futures        None
# 0         EDM2019_EDU2019_ocs                 NaN    futures        None
# 50                  Portfolio             EDM2019    futures        None
# 26                  Portfolio             CLU2019    futures        None
# 1      CLU2019Z2019M2019U2019                 NaN    futures        None
# 8                   Portfolio              BV2019    futures        None
# 0       BV2019X2019X2019Z2019                 NaN    futures        None
# 1         EDM2019_EDU2019_ocs                 NaN    futures        None
# 1    EDZ2019H2020U2019Z2019_2                 NaN    futures        None
# 51                  Portfolio             EDU2019    futures        None
# 1       BV2019X2019X2019Z2019                 NaN    futures        None
# 10                  Portfolio              BX2019    futures        None
# 2       BV2019X2019X2019Z2019                 NaN    futures        None
# 12                  Portfolio              BZ2019    futures        None
# 2      CLU2019Z2019M2019U2019                 NaN    futures        None
# 30                  Portfolio             CLZ2019    futures        None
# 52                  Portfolio             EDZ2019    futures        None
# 2    EDZ2019H2020U2019Z2019_2                 NaN    futures        None
# 49                  Portfolio             EDH2020    futures        None
# 0    EDZ2019H2020U2019Z2019_2                 NaN    futures        None
#
#           qty strike_price   ticker  tr_days_2roll
# 5           5          NaN  ECH2018              3
# 45       5.00         None  ECH2018              3
# 0           4          NaN  FCJ2018             29
# 53       4.00         None  FCJ2018             29
# 0         -24          NaN   BM2018             32
# 2      -24.00         None   BM2018             32
# 0          21        1.235  ECK2018             34
# 1          21        1.235  ECK2018             34
# 46      21.00       1.2350  ECK2018             34
# 47      21.00       1.2350  ECK2018             34
# 33     -10.00         None  CTK2018             38
# 4         -10          NaN  CTK2018             38
# 0           6          NaN  LNK2018             42
# 85      17.00         None  LNK2018             42
# 0        -172          NaN  BOK2018             42
# 4     -172.00         None  BOK2018             42
# 8          11          NaN  LNK2018             42
# 23      30.00      58.0000  CLM2018             44
# 22      30.00      58.0000  CLM2018             44
# 1          30           58  CLM2018             44
# 2          30           58  CLM2018             44
# 21     -30.00         None  CLM2018             48
# 0        0.03          NaN  CLM2018             48
# 2         -17          NaN  CLM2018             48
# 0      -13.03          NaN  CLM2018             48
# 1          -4          NaN  FCK2018             49
# 54      -4.00         None  FCK2018             49
# 74     -40.00     115.0000  LCM2018             54
# 2         -50          113  LCM2018             54
# 6         -40          115  LCM2018             54
# ..        ...          ...      ...            ...
# 1         -61          NaN   CK2019            294
# 19     -71.00         None   CK2019            294
# 2          -9          NaN   SK2019            294
# 111     -9.00         None   SK2019            294
# 1         -10          NaN   CK2019            294
# 14    -278.00         None  CCK2019            295
# 1        -200          NaN  CCK2019            295
# 1         -78          NaN  CCK2019            295
# 0         -39          NaN  CLM2019            299
# 24     -82.00         None  CLM2019            299
# 1         -43          NaN  CLM2019            299
# 0          16          NaN  EDM2019            319
# 50      16.00         None  EDM2019            319
# 26      85.00         None  CLU2019            362
# 1          85          NaN  CLU2019            362
# 8        4.00         None   BV2019            370
# 0           4          NaN   BV2019            370
# 1         -16          NaN  EDU2019            382
# 1       -1370          NaN  EDU2019            382
# 51   -1386.00         None  EDU2019            382
# 1          -8          NaN   BX2019            392
# 10      -8.00         None   BX2019            392
# 2           4          NaN   BZ2019            414
# 12       4.00         None   BZ2019            414
# 2         -46          NaN  CLZ2019            427
# 30     -46.00         None  CLZ2019            427
# 52    2740.00         None  EDZ2019            446
# 2        2740          NaN  EDZ2019            446
# 49   -1370.00         None  EDH2020            509
# 0       -1370          NaN  EDH2020            509
#
# [325 rows x 8 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryDec17_2',strategy_to='spreadCarryFeb18_2')

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='BZ2019H2020U2019Z2019',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='LCV18M18VCS')
wuhu

# sell 1 Z futures after

# W_KW_ifs_2_Aug-2017
# HO FG, 10

#bought 84 June
#sold 49
# Out:
#    ticker option_type  strike_price instrument  qty
# 0  BH2020        None           NaN          F -137
# 1  BU2019        None           NaN          F -126
# 2  BZ2019        None           NaN          F  263

# %%
wuhu  = tas.get_net_position_4strategy_alias(alias='EC_OptionInventoryMar2018')
wuhu
# Out:
# Empty DataFrame
# Columns: [ticker, option_type, strike_price, instrument, qty]
# Index: []

# %%
import ta.position_close_helper as pch

#pch.calc_intrday_pnl_from_prices(alias='GCZ17J18VCS',structure_price=38.6,GCZ2017=1288.9,GCJ2018=1297)
#pch.calc_intrday_pnl_from_prices(alias='SMU18N18VCS',structure_price=14.75,SMN2018=383.6,SMU2018=382.6)
pch.calc_intrday_pnl_from_prices(alias='LNZ18Q18VCS',structure_price=0.425,LNQ2018=77.825,LNZ2018=60.4)

# sell 3 CLF
# Out:
# {'futures_pnl': 318.3000000000018,
#  'structure_pnl': -3150.0000000000005,
#  'structure_settle': 0.65000000000000002}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='LCV2018_long_scv',structure_price=10.825,LCV2018=109.1)
# sell 2 WH futures
# Out:
# {'futures_pnl': -1842.0000000000698,
#  'structure_pnl': 399.99999999997726,
#  'structure_settle': 10.800000000000001}

# %%
0.8125*64
# Out:
# 52.0

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017'],
                                            structure_price = 10.275,
                                            strike_list=[68],
                                            underlying_price_list=[78.025],
                                            qty = -7,
                                            structure_type='straddle')


# sell 2 LNM futures
# Out:
# {'delta_pnl': 185.49394290000703,
#  'structure_pnl': 70.000000000001,
#  'structure_price_yesterday': 10.3,
#  'total_pnl': 255.49394290000802}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['CU2018','CZ2018'],
                                            structure_price =8.25,
                                            strike_list=[380,390],
                                            underlying_price_list=[388.5,382.2],
                                            qty =-23,
                                            structure_type='straddle_spread')

# sell 7 ZSN futures
# Out:
# {'delta_pnl': 19.222376500000028,
#  'structure_pnl': -143.75,
#  'structure_price_yesterday': 8.125,
#  'total_pnl': -124.52762349999998}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['SMN2018','SMU2018'],
                                            structure_price =13.6,
                                            strike_list=[380,370],
                                            underlying_price_list=[382.8,380.3],
                                            qty =50,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': -646.09015999999531,
#  'structure_pnl': -249.99999999999466,
#  'structure_price_yesterday': 13.649999999999999,
#  'total_pnl': -896.09015999998996}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2018','LNQ2018'],
                                            structure_price =1.55,
                                            strike_list=[82,82],
                                            underlying_price_list=[77.7,79.775],
                                            qty =35,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': -4710.0674039999913,
#  'structure_pnl': 4550.0000000000055,
#  'structure_price_yesterday': 1.2249999999999996,
#  'total_pnl': -160.0674039999858}
