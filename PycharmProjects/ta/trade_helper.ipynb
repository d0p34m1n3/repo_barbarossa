# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=271,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# 457

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='NGV17U17VCS',description_string='strategy_class=vcs&betsize=18970')
# Out:
# 462

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
#tfl.load_tt_trades(tags2exclude=['ifs','DeltaHedge','ocs'])     # 'DeltaHedge','ocs'
tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
import ta.trade_fill_loader as tfl
tt_export_frame_filtered = tfl.load_latest_tt_fills(tags2exclude=['ifs','ocs','DeltaHedge'])

tt_export_frame_filtered
tags2exclude=['ifs','ocs','DeltaHedge']

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
#sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_apr17',as_of_date=cu.get_doubledate())
wuhu

#wuhu  = tas.get_net_position_4strategy_alias(alias='delta_oct16',as_of_date=20161031)
#wuhu
# Out:
#      ticker option_type  strike_price instrument   qty
# 2   CLH2018        None           NaN          F -1.36
# 3   CLZ2017        None           NaN          F  1.13
# 4    CU2017        None           NaN          F  8.28
# 5    CZ2017        None           NaN          F -8.18
# 6   ESM2017        None           NaN          F  3.00
# 7   ESU2017        None           NaN          F -3.00
# 8   GCJ2018        None           NaN          F -1.24
# 10  GCQ2017        None           NaN          F  6.89
# 11  GCV2017        None           NaN          F -2.67
# 12  GCZ2017        None           NaN          F -3.28
# 13  LCQ2017        None           NaN          F  0.01
# 14  LCV2017        None           NaN          F  0.27
# 19  SIN2017        None           NaN          F -3.00
# 20  SIU2017        None           NaN          F  3.00
# 21  SMQ2017        None           NaN          F  0.42
# 22  SMU2017        None           NaN          F -0.10

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='SIN17U17VCS')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
output['strike_portfolio']
# Out:
#     ticker option_type  strike_price instrument  qty     theta      vega  \
# 0  SIN2017           C          17.5          O   21 -0.003368  3.907616
# 1  SIN2017           P          17.5          O   21 -0.003390  3.907479
# 0  SIU2017           C          17.5          O  -21 -0.002924  4.855933
# 1  SIU2017           P          17.5          O  -21 -0.002948  4.855679
#
#       delta  delta_diff       oev  total_oev  dollar_theta  dollar_vega
# 0  0.651631    0.151631  0.925150  19.428158    -353.58960  4102.997251
# 1 -0.344417    0.844417  0.925118  19.427472    -355.95105  4102.852478
# 0  0.637411    0.137411  0.936789 -19.672562     306.98850 -5098.729797
# 1 -0.356417    0.856417  0.936740 -19.671534     309.56520 -5098.463349

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='SIN17U17VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  total_delta  \
# 0           SIN2017      18.0775          4.90             -5.10        -0.20
# 1           SIU2017      18.1400         -4.76              5.13         0.37
#
#    hedge
# 0   0.20
# 1  -0.37

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='GCQ17Z17VCS')

# %%
import ta.abn_position_reconciler as pr
pr.reconcile_position()
# Out:
#     generalized_ticker  qty_x   ticker option_type strike_price instrument  \
# 0              SMQ2017     12  SMQ2017        None         None          F
# 3              SMU2017     -8  SMU2017        None         None          F
# 11              CU2017     -9   CU2017        None         None          F
# 25              SX2017    -14   SX2017        None         None          F
# 26              SF2018     14   SF2018        None         None          F
# 29              WN2017     -8   WN2017        None         None          F
# 31             LCM2017     -4  LCM2017        None         None          F
# 32             LCQ2017    -17  LCQ2017        None         None          F
# 37             LCV2017     28  LCV2017        None         None          F
# 54             CLX2017      1      NaN         NaN          NaN        NaN
# 55             CLZ2017    -11  CLZ2017        None         None          F
# 59             CLG2018     -2      NaN         NaN          NaN        NaN
# 60             CLH2018     -6  CLH2018        None         None          F
# 63             CLK2018      1      NaN         NaN          NaN        NaN
# 64             CLM2018      5      NaN         NaN          NaN        NaN
# 68             HOX2017    -42      NaN         NaN          NaN        NaN
# 69             HOZ2017     74      NaN         NaN          NaN        NaN
# 70             HOF2018    -32      NaN         NaN          NaN        NaN
# 82             RBJ2018     20  RBJ2018        None         None          F
# 83             RBK2018    -40  RBK2018        None         None          F
# 84             RBM2018     20  RBM2018        None         None          F
# 85             CTZ2017    -29  CTZ2017        None         None          F
# 86             CTH2018     55  CTH2018        None         None          F
# 87             CTK2018    -26  CTK2018        None         None          F
# 88             OJX2017     -6  OJX2017        None         None          F
# 89             OJF2018     10  OJF2018        None         None          F
# 91             GCQ2017      1  GCQ2017        None         None          F
# 92      GCQ2017-C-1230     10      NaN         NaN          NaN        NaN
# 93      GCQ2017-P-1230     10      NaN         NaN          NaN        NaN
# 97      GCZ2017-C-1235    -10      NaN         NaN          NaN        NaN
# 98      GCZ2017-P-1235    -10      NaN         NaN          NaN        NaN
# 122            GCZ2017    NaN  GCZ2017        None         None          F
# 123            KWN2017    NaN  KWN2017        None         None          F
# 124            LCG2018    NaN  LCG2018        None         None          F
# 125            LCJ2018    NaN  LCJ2018        None         None          F
# 126             WH2018    NaN   WH2018        None         None          F
# 127       WH2018-C-480    NaN   WH2018           C     480.0000          O
# 128       WH2018-P-480    NaN   WH2018           P     480.0000          O
# 129       WZ2017-C-470    NaN   WZ2017           C     470.0000          O
# 130       WZ2017-P-470    NaN   WZ2017           P     470.0000          O
#
#       qty_y  qty_diff
# 0     14.00        -2
# 3    -10.00         2
# 11    -4.00        -5
# 25   -24.00        10
# 26    24.00       -10
# 29    -7.00        -1
# 31    -3.00        -1
# 32   -14.00        -3
# 37    24.00         4
# 54      NaN       NaN
# 55   -16.00         5
# 59      NaN       NaN
# 60     4.00       -10
# 63      NaN       NaN
# 64      NaN       NaN
# 68      NaN       NaN
# 69      NaN       NaN
# 70      NaN       NaN
# 82    30.00       -10
# 83   -61.00        21
# 84    31.00       -11
# 85   -41.00        12
# 86    81.00       -26
# 87   -40.00        14
# 88   -13.00         7
# 89    17.00        -7
# 91     7.00        -6
# 92      NaN       NaN
# 93      NaN       NaN
# 97      NaN       NaN
# 98      NaN       NaN
# 122   -3.00       NaN
# 123   -1.00       NaN
# 124   -4.00       NaN
# 125    4.00       NaN
# 126   -4.00       NaN
# 127   45.00       NaN
# 128   45.00       NaN
# 129  -45.00       NaN
# 130  -45.00       NaN

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='LCZ16V16VCS',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
#     ticker  total_oev      theta
# 0  LCV2016 -19.988474  157.53088
# 1  LCZ2016  19.999996 -120.84700

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                         alias generalized_ticker instrument option_type  \
# 58                  Portfolio            ESH2017    futures        None
# 6                 delta_mar17                NaN    futures        None
# 65                  Portfolio            GCJ2017    futures        None
# 8                 delta_mar17                NaN    futures        None
# 0      CCN2017U2017K2017N2017                NaN    futures        None
# 18                  Portfolio            CCK2017    futures        None
# 25                  Portfolio  CLM2017-C-55.5000    options           C
# 4                 CLM17N17VCS                NaN    options           P
# 3                 CLM17N17VCS                NaN    options           P
# 2                 CLM17N17VCS                NaN    options           C
# 1                 CLM17N17VCS                NaN    options           C
# 24                  Portfolio  CLM2017-C-54.0000    options           C
# 27                  Portfolio  CLM2017-P-55.5000    options           P
# 26                  Portfolio  CLM2017-P-54.0000    options           P
# 1      KCU2017H2018K2017U2017                NaN    futures        None
# 78                  Portfolio            KCK2017    futures        None
# 2                 delta_mar17                NaN    futures        None
# 23                  Portfolio            CLM2017    futures        None
# 0                 CLM17N17VCS                NaN    futures        None
# 63                  Portfolio            FCK2017    futures        None
# 4            spreadCarryMar17                NaN    futures        None
# 16                delta_mar17                NaN    futures        None
# 118                 Portfolio            SIK2017    futures        None
# 89                  Portfolio            LNM2017    futures        None
# 1                 LNV17M17VCS                NaN    options           C
# 2                 LNV17M17VCS                NaN    options           P
# 13                delta_mar17                NaN    futures        None
# 90                  Portfolio  LNM2017-C-76.0000    options           C
# 6                 LNQ17M17VCS                NaN    options           P
# 5                 LNQ17M17VCS                NaN    options           P
# ..                        ...                ...        ...         ...
# 2                 B_pca_Feb17                NaN    futures        None
# 15                  Portfolio             BU2018    futures        None
# 3                 B_pca_Feb17                NaN    futures        None
# 16                  Portfolio             BV2018    futures        None
# 1      EDZ2018H2019U2018Z2018                NaN    futures        None
# 56                  Portfolio            EDU2018    futures        None
# 0    CLX2018Z2018V2018X2018_2                NaN    futures        None
# 36                  Portfolio            CLV2018    futures        None
# 1    CLX2018Z2018V2018X2018_2                NaN    futures        None
# 37                  Portfolio            CLX2018    futures        None
# 2    CLX2018Z2018V2018X2018_2                NaN    futures        None
# 1    CLM2019Z2019Z2018M2019_2                NaN    futures        None
# 38                  Portfolio            CLZ2018    futures        None
# 2      EDZ2018M2019M2018Z2018                NaN    futures        None
# 2      EDZ2018H2019U2018Z2018                NaN    futures        None
# 57                  Portfolio            EDZ2018    futures        None
# 53                  Portfolio            EDH2019    futures        None
# 0      EDZ2018H2019U2018Z2018                NaN    futures        None
# 0       BZ2019M2020M2019Z2019                NaN    futures        None
# 6                   Portfolio             BM2019    futures        None
# 0    CLM2019Z2019Z2018M2019_2                NaN    futures        None
# 28                  Portfolio            CLM2019    futures        None
# 55                  Portfolio            EDM2019    futures        None
# 1      EDZ2018M2019M2018Z2018                NaN    futures        None
# 17                  Portfolio             BZ2019    futures        None
# 2       BZ2019M2020M2019Z2019                NaN    futures        None
# 2    CLM2019Z2019Z2018M2019_2                NaN    futures        None
# 39                  Portfolio            CLZ2019    futures        None
# 1       BZ2019M2020M2019Z2019                NaN    futures        None
# 7                   Portfolio             BM2020    futures        None
#
#          qty strike_price   ticker  tr_dte
# 58      4.00         None  ESH2017       6
# 6          4          NaN  ESH2017       6
# 65     -1.00         None  GCJ2017      33
# 8         -1          NaN  GCJ2017      33
# 0        -43          NaN  CCK2017      46
# 18    -43.00         None  CCK2017      46
# 25     20.00      55.5000  CLM2017      48
# 4         20         55.5  CLM2017      48
# 3         20           54  CLM2017      48
# 2         20         55.5  CLM2017      48
# 1         20           54  CLM2017      48
# 24     20.00      54.0000  CLM2017      48
# 27     20.00      55.5000  CLM2017      48
# 26     20.00      54.0000  CLM2017      48
# 1        -11          NaN  KCK2017      49
# 78    -11.00         None  KCK2017      49
# 2      -0.16          NaN  CLM2017      51
# 23     20.00         None  CLM2017      51
# 0      20.16          NaN  CLM2017      51
# 63      2.00         None  FCK2017      54
# 4          2          NaN  FCK2017      54
# 16         1          NaN  SIK2017      55
# 118     1.00         None  SIK2017      55
# 89     -5.00         None  LNM2017      67
# 1        -25           80  LNM2017      67
# 2        -25           80  LNM2017      67
# 13      0.46          NaN  LNM2017      67
# 90    -13.00      76.0000  LNM2017      67
# 6         -2           80  LNM2017      67
# 5        -37           78  LNM2017      67
# ..       ...          ...      ...     ...
# 2        -26          NaN   BU2018     353
# 15    -26.00         None   BU2018     353
# 3         26          NaN   BV2018     375
# 16     26.00         None   BV2018     375
# 1       -100          NaN  EDU2018     386
# 56   -100.00         None  EDU2018     386
# 0         -1          NaN  CLV2018     387
# 36     -1.00         None  CLV2018     387
# 1          2          NaN  CLX2018     409
# 37      2.00         None  CLX2018     409
# 2         -1          NaN  CLZ2018     429
# 1        -10          NaN  CLZ2018     429
# 38    -11.00         None  CLZ2018     429
# 2        237          NaN  EDZ2018     450
# 2        200          NaN  EDZ2018     450
# 57    437.00         None  EDZ2018     450
# 53   -100.00         None  EDH2019     513
# 0       -100          NaN  EDH2019     513
# 0        -21          NaN   BM2019     543
# 6     -21.00         None   BM2019     543
# 0         22          NaN  CLM2019     554
# 28     22.00         None  CLM2019     554
# 55   -122.00         None  EDM2019     576
# 1       -122          NaN  EDM2019     576
# 17     46.00         None   BZ2019     672
# 2         46          NaN   BZ2019     672
# 2        -12          NaN  CLZ2019     682
# 39    -12.00         None  CLZ2019     682
# 1        -25          NaN   BM2020     798
# 7     -25.00         None   BM2020     798
#
# [327 rows x 8 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='W_KW_ifs_2_May-2017',strategy_to='W_KW_ifs_May-2017')

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='CU17Z17VCS',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='S_BO_SM_ifs_Nov-2016')
wuhu

# sell 1 Z futures after

# HO VX, -16
# HO FG, 10
# Out:
#    ticker option_type  strike_price instrument    qty
# 0  CU2017        None           NaN          F  -3.06
# 2  CU2017           C           380          O  98.00
# 4  CU2017           P           380          O  98.00
# 5  CZ2017        None           NaN          F   8.00
# 7  CZ2017           C           390          O -98.00
# 9  CZ2017           P           390          O -98.00

# %%
import ta.position_close_helper as pch

#pch.calc_intrday_pnl_from_prices(alias='SMQ17U17VCS',structure_price=5.97,SMQ2017=313.6,SMU2017=314.1)
pch.calc_intrday_pnl_from_prices(alias='GCQ17Z17VCS',structure_price=43.8,GCQ2017=1265.7,GCZ2017=1272.6)

# also buy one CLZ
# Out:
# {'futures_pnl': 1487.7000000000119,
#  'structure_pnl': -1099.9999999999943,
#  'structure_settle': 42.700000000000003}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='CLZ2017_short_scv',structure_price=8.79,CLZ2017=50.74)
# buy 1 CLZ futures
# Out:
# {'futures_pnl': -193.20000000000078,
#  'structure_pnl': 80.0000000000054,
#  'structure_settle': 8.8100000000000005}

# %%
0.8125*64
# Out:
# 52.0

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017'],
                                            structure_price = 10.275,
                                            strike_list=[68],
                                            underlying_price_list=[78.025],
                                            qty = -7,
                                            structure_type='straddle')


# sell 2 LNM futures
# Out:
# {'delta_pnl': 185.49394290000703,
#  'structure_pnl': 70.000000000001,
#  'structure_price_yesterday': 10.3,
#  'total_pnl': 255.49394290000802}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['CU2017','CZ2017'],
                                            structure_price =13,
                                            strike_list=[370,380],
                                            underlying_price_list=[383,394],
                                            qty =-44,
                                            structure_type='straddle_spread')

# sell 7 ZSN futures
# Out:
# {'delta_pnl': 107.34779549999978,
#  'structure_pnl': -550.0,
#  'structure_price_yesterday': 12.75,
#  'total_pnl': -442.65220450000021}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017','LNQ2017'],
                                            structure_price =3.1,
                                            strike_list=[80,80],
                                            underlying_price_list=[78.6,78.6],
                                            qty =2,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': -344.28541319999817,
#  'structure_pnl': 420.0000000000003,
#  'structure_price_yesterday': 2.5749999999999997,
#  'total_pnl': 75.71458680000211}
