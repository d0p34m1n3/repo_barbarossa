# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=55,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# 583

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='BPV17X17VCS',description_string='strategy_class=vcs&betsize=27268')
# Out:
# 579

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
tfl.load_tt_trades(tags2exclude=['ifs','DeltaHedge','ocs'])     # 'DeltaHedge','ocs'
#tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
import ta.trade_fill_loader as tfl
tt_export_frame_filtered = tfl.load_latest_tt_fills(tags2exclude=['ifs','ocs','DeltaHedge'])

tt_export_frame_filtered
tags2exclude=['ifs','ocs','DeltaHedge']

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
#sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_june17',as_of_date=cu.get_doubledate())
wuhu

#wuhu  = tas.get_net_position_4strategy_alias(alias='delta_oct16',as_of_date=20161031)
#wuhu
# Out:
#      ticker option_type  strike_price instrument    qty
# 0   BPZ2017        None           NaN          F  -0.16
# 1   CLH2018        None           NaN          F  -0.11
# 2   CLZ2017        None           NaN          F  -0.05
# 3    CN2018        None           NaN          F  -0.14
# 4    CZ2017        None           NaN          F   0.43
# 5   ESU2017        None           NaN          F   4.00
# 6   ESZ2017        None           NaN          F  -3.70
# 7   GCJ2018        None           NaN          F   8.56
# 8   GCQ2017        None           NaN          F  14.00
# 9   GCV2017        None           NaN          F  -7.29
# 10  GCZ2017        None           NaN          F -14.93
# 11  LNV2017        None           NaN          F  -0.21
# 12  LNZ2017        None           NaN          F   0.66
# 15   SH2018        None           NaN          F  -0.54
# 20  SMZ2017        None           NaN          F   0.15
# 21   SX2017        None           NaN          F   0.47
# 22   WH2018        None           NaN          F  -3.72
# 23   WZ2017        None           NaN          F   3.29

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='SIN17U17VCS')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
output['strike_portfolio']
# Out:
#     ticker option_type  strike_price instrument  qty     theta      vega  \
# 0  SIN2017           C          17.5          O   21 -0.003368  3.907616
# 1  SIN2017           P          17.5          O   21 -0.003390  3.907479
# 0  SIU2017           C          17.5          O  -21 -0.002924  4.855933
# 1  SIU2017           P          17.5          O  -21 -0.002948  4.855679
#
#       delta  delta_diff       oev  total_oev  dollar_theta  dollar_vega
# 0  0.651631    0.151631  0.925150  19.428158    -353.58960  4102.997251
# 1 -0.344417    0.844417  0.925118  19.427472    -355.95105  4102.852478
# 0  0.637411    0.137411  0.936789 -19.672562     306.98850 -5098.729797
# 1 -0.356417    0.856417  0.936740 -19.671534     309.56520 -5098.463349

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='SIN17U17VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  total_delta  \
# 0           SIN2017      18.0775          4.90             -5.10        -0.20
# 1           SIU2017      18.1400         -4.76              5.13         0.37
#
#    hedge
# 0   0.20
# 1  -0.37

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='CU2018Z2018N2018U2018_2')

# %%
import ta.abn_position_reconciler as pr
pr.reconcile_position()
# Out:
# Empty DataFrame
# Columns: [generalized_ticker, qty_x, ticker, option_type, strike_price, instrument, qty_y, qty_diff]
# Index: []

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='LCZ16V16VCS',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
#     ticker  total_oev      theta  dollar_vega
# 0  LCV2016 -19.988474  157.53088 -2050.367122
# 1  LCZ2016  19.999996 -120.84700  2517.126992

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                         alias  generalized_ticker instrument option_type  \
# 5                 delta_apr17                 NaN    futures        None
# 47                  Portfolio             ESM2017    futures        None
# 0            C_W_ifs_Jun-2017                 NaN    futures        None
# 29                  Portfolio              CN2017    futures        None
# 122                 Portfolio              WN2017    futures        None
# 1            C_W_ifs_Jun-2017                 NaN    futures        None
# 111                 Portfolio  SMQ2017-C-320.0000    options           C
# 112                 Portfolio  SMQ2017-P-320.0000    options           P
# 1                 SMQ17U17VCS                 NaN    options           C
# 2                 SMQ17U17VCS                 NaN    options           P
# 104                 Portfolio             SIN2017    futures        None
# 15                delta_apr17                 NaN    futures        None
# 70                  Portfolio  LCQ2017-P-124.0000    options           P
# 69                  Portfolio  LCQ2017-C-124.0000    options           C
# 1               LCV17Q17VCS_2                 NaN    options           C
# 2               LCV17Q17VCS_2                 NaN    options           P
# 0                 SMQ17U17VCS                 NaN    futures        None
# 17                delta_apr17                 NaN    futures        None
# 110                 Portfolio             SMQ2017    futures        None
# 4                 SMQ17U17VCS                 NaN    options           C
# 114                 Portfolio  SMU2017-C-320.0000    options           C
# 5                 SMQ17U17VCS                 NaN    options           P
# 115                 Portfolio  SMU2017-P-320.0000    options           P
# 82                  Portfolio    NGU2017-C-3.1000    options           C
# 83                  Portfolio    NGU2017-P-3.1000    options           P
# 1                 NGV17U17VCS                 NaN    options           C
# 2                 NGV17U17VCS                 NaN    options           P
# 8                 delta_apr17                 NaN    futures        None
# 0                 NGV17U17VCS                 NaN    futures        None
# 13                delta_apr17                 NaN    futures        None
# ..                        ...                 ...        ...         ...
# 0       CU2018Z2018N2018U2018                 NaN    futures        None
# 0       BV2018X2018U2018V2018                 NaN    futures        None
# 9                   Portfolio              BU2018    futures        None
# 2                 B_pca_Feb17                 NaN    futures        None
# 2      NGK2018N2018N2018U2018                 NaN    futures        None
# 84                  Portfolio             NGU2018    futures        None
# 1       BV2018X2018U2018V2018                 NaN    futures        None
# 10                  Portfolio              BV2018    futures        None
# 3                 B_pca_Feb17                 NaN    futures        None
# 2      CCK2018U2018H2018K2018                 NaN    futures        None
# 16                  Portfolio             CCU2018    futures        None
# 1       CU2018Z2018N2018U2018                 NaN    futures        None
# 37                  Portfolio              CU2018    futures        None
# 2      EDM2018U2018H2018M2018                 NaN    futures        None
# 45                  Portfolio             EDU2018    futures        None
# 1      EDZ2018H2019U2018Z2018                 NaN    futures        None
# 2       BV2018X2018U2018V2018                 NaN    futures        None
# 11                  Portfolio              BX2018    futures        None
# 1    CLM2019Z2019Z2018M2019_2                 NaN    futures        None
# 27                  Portfolio             CLZ2018    futures        None
# 2       CU2018Z2018N2018U2018                 NaN    futures        None
# 41                  Portfolio              CZ2018    futures        None
# 2      EDZ2018H2019U2018Z2018                 NaN    futures        None
# 46                  Portfolio             EDZ2018    futures        None
# 43                  Portfolio             EDH2019    futures        None
# 0      EDZ2018H2019U2018Z2018                 NaN    futures        None
# 23                  Portfolio             CLM2019    futures        None
# 0    CLM2019Z2019Z2018M2019_2                 NaN    futures        None
# 28                  Portfolio             CLZ2019    futures        None
# 2    CLM2019Z2019Z2018M2019_2                 NaN    futures        None
#
#          qty strike_price   ticker  tr_dte
# 5          3          NaN  ESM2017       9
# 47      3.00         None  ESM2017       9
# 0         -1          NaN   CN2017      28
# 29     -1.00         None   CN2017      28
# 122     1.00         None   WN2017      28
# 1          1          NaN   WN2017      28
# 111    25.00     320.0000  SMQ2017      33
# 112    25.00     320.0000  SMQ2017      33
# 1         25          320  SMQ2017      33
# 2         25          320  SMQ2017      33
# 104    -3.00         None  SIN2017      37
# 15        -3          NaN  SIN2017      37
# 70    -30.00     124.0000  LCQ2017      43
# 69    -30.00     124.0000  LCQ2017      43
# 1        -30          124  LCQ2017      43
# 2        -30          124  LCQ2017      43
# 0      11.82          NaN  SMQ2017      49
# 17      0.18          NaN  SMQ2017      49
# 110    12.00         None  SMQ2017      49
# 4        -25          320  SMU2017      58
# 114   -25.00     320.0000  SMU2017      58
# 5        -25          320  SMU2017      58
# 115   -25.00     320.0000  SMU2017      58
# 82    -49.00       3.1000  NGU2017      59
# 83    -49.00       3.1000  NGU2017      59
# 1        -49          3.1  NGU2017      59
# 2        -49          3.1  NGU2017      59
# 8          5          NaN  GCQ2017      60
# 0      -2.12          NaN  NGU2017      60
# 13      0.12          NaN  NGU2017      60
# ..       ...          ...      ...     ...
# 0        -12          NaN   CN2018     279
# 0         -2          NaN   BU2018     293
# 9     -99.00         None   BU2018     293
# 2        -97          NaN   BU2018     293
# 2         31          NaN  NGU2018     312
# 84     31.00         None  NGU2018     312
# 1          4          NaN   BV2018     315
# 10    101.00         None   BV2018     315
# 3         97          NaN   BV2018     315
# 2         -5          NaN  CCU2018     322
# 16     -5.00         None  CCU2018     322
# 1         25          NaN   CU2018     323
# 37     25.00         None   CU2018     323
# 2       -175          NaN  EDU2018     326
# 45   -275.00         None  EDU2018     326
# 1       -100          NaN  EDU2018     326
# 2         -2          NaN   BX2018     335
# 11     -2.00         None   BX2018     335
# 1        -22          NaN  CLZ2018     369
# 27    -22.00         None  CLZ2018     369
# 2        -13          NaN   CZ2018     387
# 41    -13.00         None   CZ2018     387
# 2        200          NaN  EDZ2018     390
# 46    200.00         None  EDZ2018     390
# 43   -100.00         None  EDH2019     453
# 0       -100          NaN  EDH2019     453
# 23     48.00         None  CLM2019     494
# 0         48          NaN  CLM2019     494
# 28    -26.00         None  CLZ2019     622
# 2        -26          NaN  CLZ2019     622
#
# [302 rows x 8 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryJune17',strategy_to='spreadCarryJuly17')

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='B_pca_Feb17',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='LCJ2018_LCM2018_ocs')
wuhu

# sell 1 Z futures after

# HO VX, -16spreadCarryMay17
# HO FG, 10
# Out:
#    ticker option_type  strike_price instrument  qty
# 2  BM2018        None           NaN          F   81
# 3  BN2018        None           NaN          F  -81
# 4  BU2018        None           NaN          F  -91
# 5  BV2018        None           NaN          F   91

# %%
import ta.position_close_helper as pch

pch.calc_intrday_pnl_from_prices(alias='CN18Z17VCS',structure_price=21.25,CZ2017=375.5,CN2018=397.5)
#pch.calc_intrday_pnl_from_prices(alias='LCV17Q17VCS_2',structure_price=3.025,LCQ2017=124.6,LCV2017=120.3)

# also buy two LCV7
# Out:
# {'futures_pnl': -65.375, 'structure_pnl': -1325.0, 'structure_settle': 21.75}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='CLZ2017_short_scv',structure_price=8.79,CLZ2017=50.74)
# buy 1 CLZ futures
# Out:
# {'futures_pnl': -193.20000000000078,
#  'structure_pnl': 80.0000000000054,
#  'structure_settle': 8.8100000000000005}

# %%
0.8125*64
# Out:
# 52.0

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017'],
                                            structure_price = 10.275,
                                            strike_list=[68],
                                            underlying_price_list=[78.025],
                                            qty = -7,
                                            structure_type='straddle')


# sell 2 LNM futures
# Out:
# {'delta_pnl': 185.49394290000703,
#  'structure_pnl': 70.000000000001,
#  'structure_price_yesterday': 10.3,
#  'total_pnl': 255.49394290000802}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['NGU2017','NGV2017'],
                                            structure_price =0.086,
                                            strike_list=[3.1,3.15],
                                            underlying_price_list=[3.071,3.101],
                                            qty =49,
                                            structure_type='straddle_spread')

# sell 7 ZSN futures
# Out:
# {'delta_pnl': -1204.5549411000111,
#  'structure_pnl': 1470.000000000015,
#  'structure_price_yesterday': 0.08299999999999996,
#  'total_pnl': 265.44505890000391}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017','LNQ2017'],
                                            structure_price =3.1,
                                            strike_list=[80,80],
                                            underlying_price_list=[78.6,78.6],
                                            qty =2,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': -344.28541319999817,
#  'structure_pnl': 420.0000000000003,
#  'structure_price_yesterday': 2.5749999999999997,
#  'total_pnl': 75.71458680000211}
