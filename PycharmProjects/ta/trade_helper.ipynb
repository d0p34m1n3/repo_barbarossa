# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=159,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# {'alias': 'CLH2019M2019Z2018H2019_3', 'strategy_id': 1108}

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='LCV2018_long_scv',description_string='strategy_class=scv&betsize=15678')
# Out:
# {'alias': 'LCV2018_long_scv', 'strategy_id': 1107}

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
tfl.load_tt_trades(tags2exclude=['ifs','ocs','DeltaHedge'])     # 'DeltaHedge','ocs'
#tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
import ta.trade_fill_loader as tfl
tt_export_frame_filtered = tfl.load_latest_tt_fills(tags2exclude=['ifs','ocs','DeltaHedge'])

tt_export_frame_filtered
tags2exclude=['ifs','ocs','DeltaHedge']

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
#sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_jan18',as_of_date=cu.get_doubledate())
wuhu
# Out:
#      ticker option_type  strike_price instrument   qty
# 0   CLM2018        None           NaN          F  0.40
# 1   CLZ2018        None           NaN          F -0.07
# 2    CU2018        None           NaN          F -1.97
# 3    CZ2018        None           NaN          F  1.82
# 4   ECH2018        None           NaN          F  0.04
# 5   ESH2018        None           NaN          F  3.00
# 6   ESM2018        None           NaN          F  2.85
# 7   LCM2018        None           NaN          F  0.39
# 8   LCV2018        None           NaN          F -0.89
# 9   LNJ2018        None           NaN          F  0.33
# 10  LNK2018        None           NaN          F -0.08
# 14  SIH2018        None           NaN          F -4.00
# 15  SIK2018        None           NaN          F  4.00
# 16   SQ2018        None           NaN          F  0.04
# 17   SX2018        None           NaN          F -0.11
# 18   WN2018        None           NaN          F -0.02
# 19   WZ2018        None           NaN          F -0.11

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='EC_OptionInventoryMar2018')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['ticker_portfolio']
print(output['strike_portfolio']['total_oev'].sum())
output['ticker_portfolio']
output['strike_portfolio']
# Out:
# -16.402271288022618
#     ticker option_type  strike_price instrument  qty     theta      vega  \
# 0  ECH2018           C         1.165          O  -90 -0.000055  0.025065
# 1  ECH2018           C         1.230          O   10 -0.000235  0.128239
# 2  ECH2018           P         1.165          O  -90 -0.000064  0.026804
# 3  ECH2018           P         1.230          O   10 -0.000236  0.128239
#
#       delta  delta_diff       oev  total_oev  dollar_theta  dollar_vega
# 0  0.963410    0.463410  0.195454 -17.590852      622.9125 -2819.794500
# 1  0.515601    0.015601  1.000000  10.000000     -293.3500  1602.989125
# 2 -0.038327    0.538327  0.209016 -18.811447      721.9125 -3015.454500
# 3 -0.483144    0.983144  1.000003  10.000028     -294.6250  1602.993625

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='SIN17U17VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  total_delta  \
# 0           SIN2017      18.0775          4.90             -5.10        -0.20
# 1           SIU2017      18.1400         -4.76              5.13         0.37
#
#    hedge
# 0   0.20
# 1  -0.37

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='spreadCarryDec17',broker='abn')

# %%
import ta.man_position_reconciler as mpr
mpr.reconcile_position()
# Out:
# Empty DataFrame
# Columns: [generalized_ticker, qty_x, ticker, option_type, strike_price, instrument, qty_y, qty_diff]
# Index: []

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='EC_OptionInventoryMar2018',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
# Empty DataFrame
# Columns: [total_oev, theta, dollar_vega, ticker]
# Index: []

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                          alias generalized_ticker instrument option_type  \
# 0    EC_OptionInventoryMar2018                NaN    options           C
# 1    EC_OptionInventoryMar2018                NaN    options           P
# 42                   Portfolio   ECG2018-P-1.1650    options           P
# 41                   Portfolio   ECG2018-C-1.1650    options           C
# 11                 delta_jan18                NaN    futures        None
# 113                  Portfolio            SIH2018    futures        None
# 47                   Portfolio   ECH2018-P-1.2300    options           P
# 3    EC_OptionInventoryMar2018                NaN    options           C
# 4    EC_OptionInventoryMar2018                NaN    options           C
# 5    EC_OptionInventoryMar2018                NaN    options           P
# 6    EC_OptionInventoryMar2018                NaN    options           P
# 46                   Portfolio   ECH2018-P-1.1650    options           P
# 45                   Portfolio   ECH2018-C-1.2300    options           C
# 44                   Portfolio   ECH2018-C-1.1650    options           C
# 53                   Portfolio            ESH2018    futures        None
# 5                  delta_jan18                NaN    futures        None
# 68                   Portfolio            KCH2018    futures        None
# 0       KCK2018N2018H2018K2018                NaN    futures        None
# 2    EC_OptionInventoryMar2018                NaN    futures        None
# 43                   Portfolio            ECH2018    futures        None
# 4                  delta_jan18                NaN    futures        None
# 0          HOJ2018_HOK2018_ocs                NaN    futures        None
# 63                   Portfolio            HOJ2018    futures        None
# 1                  LNK18J18VCS                NaN    options           C
# 2                  LNK18J18VCS                NaN    options           P
# 87                   Portfolio            LNJ2018    futures        None
# 88                   Portfolio  LNJ2018-C-74.0000    options           C
# 89                   Portfolio  LNJ2018-P-74.0000    options           P
# 0                  LNK18J18VCS                NaN    futures        None
# 9                  delta_jan18                NaN    futures        None
# ..                         ...                ...        ...         ...
# 0             spreadCarryDec17                NaN    futures        None
# 17                   Portfolio             CH2019    futures        None
# 1            SF2019_SH2019_ocs                NaN    futures        None
# 71                   Portfolio            KWH2019    futures        None
# 1        SH2019K2019F2019H2019                NaN    futures        None
# 0        BM2019U2019U2019Z2019                NaN    futures        None
# 2                    Portfolio             BM2019    futures        None
# 115                  Portfolio             SK2019    futures        None
# 2        SH2019K2019F2019H2019                NaN    futures        None
# 0       CLU2019Z2019M2019U2019                NaN    futures        None
# 22                   Portfolio            CLM2019    futures        None
# 9                    Portfolio             BU2019    futures        None
# 1        BM2019U2019U2019Z2019                NaN    futures        None
# 23                   Portfolio            CLU2019    futures        None
# 1       CLU2019Z2019M2019U2019                NaN    futures        None
# 1     EDZ2019H2020U2019Z2019_2                NaN    futures        None
# 51                   Portfolio            EDU2019    futures        None
# 13                   Portfolio             BZ2019    futures        None
# 1        BM2020Z2020Z2019M2020                NaN    futures        None
# 2        BM2019U2019U2019Z2019                NaN    futures        None
# 27                   Portfolio            CLZ2019    futures        None
# 2       CLU2019Z2019M2019U2019                NaN    futures        None
# 52                   Portfolio            EDZ2019    futures        None
# 2     EDZ2019H2020U2019Z2019_2                NaN    futures        None
# 48                   Portfolio            EDH2020    futures        None
# 0     EDZ2019H2020U2019Z2019_2                NaN    futures        None
# 3                    Portfolio             BM2020    futures        None
# 0        BM2020Z2020Z2019M2020                NaN    futures        None
# 14                   Portfolio             BZ2020    futures        None
# 2        BM2020Z2020Z2019M2020                NaN    futures        None
#
#           qty strike_price   ticker  tr_days_2roll
# 0          90        1.165  ECG2018             -3
# 1          90        1.165  ECG2018             -3
# 42      90.00       1.1650  ECG2018             -3
# 41      90.00       1.1650  ECG2018             -3
# 11         -4          NaN  SIH2018             10
# 113     -4.00         None  SIH2018             10
# 47      10.00       1.2300  ECH2018             15
# 3         -90        1.165  ECH2018             15
# 4          10         1.23  ECH2018             15
# 5         -90        1.165  ECH2018             15
# 6          10         1.23  ECH2018             15
# 46     -90.00       1.1650  ECH2018             15
# 45      10.00       1.2300  ECH2018             15
# 44     -90.00       1.1650  ECH2018             15
# 53       4.00         None  ESH2018             20
# 5           4          NaN  ESH2018             20
# 68     -45.00         None  KCH2018             23
# 0         -45          NaN  KCH2018             23
# 2       -9.78          NaN  ECH2018             23
# 43     -10.00         None  ECH2018             23
# 4       -0.22          NaN  ECH2018             23
# 0         -18          NaN  HOJ2018             30
# 63     -18.00         None  HOJ2018             30
# 1         -25           74  LNJ2018             39
# 2         -25           74  LNJ2018             39
# 87     -12.00         None  LNJ2018             39
# 88     -25.00      74.0000  LNJ2018             39
# 89     -25.00      74.0000  LNJ2018             39
# 0       -11.8          NaN  LNJ2018             39
# 9        -0.2          NaN  LNJ2018             39
# ..        ...          ...      ...            ...
# 0          64          NaN   CH2019            271
# 17      64.00         None   CH2019            271
# 1          31          NaN   SH2019            271
# 71      33.00         None  KWH2019            271
# 1         130          NaN   SH2019            271
# 0          67          NaN   BM2019            307
# 2       67.00         None   BM2019            307
# 115    -65.00         None   SK2019            314
# 2         -65          NaN   SK2019            314
# 0        -194          NaN  CLM2019            319
# 22    -194.00         None  CLM2019            319
# 9     -141.00         None   BU2019            371
# 1        -141          NaN   BU2019            371
# 23     400.00         None  CLU2019            382
# 1         400          NaN  CLU2019            382
# 1       -1370          NaN  EDU2019            403
# 51   -1370.00         None  EDU2019            403
# 13      60.00         None   BZ2019            435
# 1         -14          NaN   BZ2019            435
# 2          74          NaN   BZ2019            435
# 27    -206.00         None  CLZ2019            447
# 2        -206          NaN  CLZ2019            447
# 52    2740.00         None  EDZ2019            467
# 2        2740          NaN  EDZ2019            467
# 48   -1370.00         None  EDH2020            530
# 0       -1370          NaN  EDH2020            530
# 3       31.00         None   BM2020            561
# 0          31          NaN   BM2020            561
# 14     -17.00         None   BZ2020            688
# 2         -17          NaN   BZ2020            688
#
# [312 rows x 8 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryDec17_2',strategy_to='spreadCarryFeb18_2')

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='CLH2019M2019Z2018H2019_3',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='LCJ2018_LCM2018_ocs')
wuhu

# sell 1 Z futures after

# W_KW_ifs_2_Aug-2017
# HO FG, 10
# Out:
#     ticker option_type  strike_price instrument  qty
# 0  CLH2019        None           NaN          F   60
# 1  CLM2019        None           NaN          F  -32
# 2  CLZ2018        None           NaN          F  -28

# %%
wuhu  = tas.get_net_position_4strategy_alias(alias='CLH2019M2019Z2018H2019_3')
wuhu
# Out:
#     ticker option_type  strike_price instrument  qty
# 0  CLH2019        None           NaN          F   60
# 1  CLM2019        None           NaN          F  -32
# 2  CLZ2018        None           NaN          F  -28

# %%
import ta.position_close_helper as pch

#pch.calc_intrday_pnl_from_prices(alias='GCZ17J18VCS',structure_price=38.6,GCZ2017=1288.9,GCJ2018=1297)
#pch.calc_intrday_pnl_from_prices(alias='BOF18Z17VCS',structure_price=0.23,BOZ2017=32.61,BOF2018=32.78)
pch.calc_intrday_pnl_from_prices(alias='NGK18J18VCS',structure_price=0.027,NGJ2018=2.707,NGK2018=2.72)

# sell 3 CLF
# Out:
# {'futures_pnl': 424.6000000000105,
#  'structure_pnl': -599.99999999999636,
#  'structure_settle': 0.028999999999999988}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='ESH2018_short_scv',structure_price=169.25,ESH2018=2602.25)
# sell 2 WH futures
# Out:
# {'futures_pnl': 170.75, 'structure_pnl': -0.0, 'structure_settle': 169.25}

# %%
0.8125*64
# Out:
# 52.0

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017'],
                                            structure_price = 10.275,
                                            strike_list=[68],
                                            underlying_price_list=[78.025],
                                            qty = -7,
                                            structure_type='straddle')


# sell 2 LNM futures
# Out:
# {'delta_pnl': 185.49394290000703,
#  'structure_pnl': 70.000000000001,
#  'structure_price_yesterday': 10.3,
#  'total_pnl': 255.49394290000802}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['CU2018','CZ2018'],
                                            structure_price =7,
                                            strike_list=[380,390],
                                            underlying_price_list=[387,394.5],
                                            qty =-173,
                                            structure_type='straddle_spread')

# sell 7 ZSN futures
# Out:
# {'delta_pnl': -229.18157699999989,
#  'structure_pnl': -4325.0,
#  'structure_price_yesterday': 6.5,
#  'total_pnl': -4554.1815770000003}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNV2017','LNZ2017'],
                                            structure_price =-0.6,
                                            strike_list=[71,64],
                                            underlying_price_list=[62.85,58.2],
                                            qty =15,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': 1370.0762159999849,
#  'structure_pnl': -1349.9999999999998,
#  'structure_price_yesterday': -0.375,
#  'total_pnl': 20.076215999985152}
