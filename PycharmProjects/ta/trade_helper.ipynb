# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=315,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# {'alias': 'NGK2019N2019N2019U2019', 'strategy_id': 1600}

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='LNG19Z18VCS',description_string='strategy_class=vcs&betsize=39197')
# Out:
# {'alias': 'LNG19Z18VCS', 'strategy_id': 1581}

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
tfl.load_tt_trades(tags2exclude=['ifs','ocs','DeltaHedge'])     # 'DeltaHedge','ocs'
#tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
import ta.trade_fill_loader as tfl
tt_export_frame_filtered = tfl.load_latest_tt_fills(tags2exclude=['ifs','ocs','DeltaHedge'])

tt_export_frame_filtered
tags2exclude=['ifs','ocs','DeltaHedge']

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
#sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_may18',as_of_date=cu.get_doubledate())
wuhu
# Out:
#      ticker option_type  strike_price instrument   qty
# 0   CLX2018        None           NaN          F  0.42
# 1   CLZ2018        None           NaN          F -0.41
# 3   LCG2019        None           NaN          F -0.41
# 5   LCV2018        None           NaN          F -0.45
# 6   LCZ2018        None           NaN          F  0.67
# 9    SH2019        None           NaN          F  0.12
# 14   SX2018        None           NaN          F  0.28
# 15   WH2019        None           NaN          F -0.20
# 17   WU2018        None           NaN          F -0.52
# 18   WZ2018        None           NaN          F  0.50

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='CN2018_short_scv')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['ticker_portfolio']
print(output['strike_portfolio']['total_oev'].sum())
output['ticker_portfolio']
output['strike_portfolio']
# Out:
# -63.43589631294344
#    ticker option_type  strike_price instrument  qty     theta       vega  \
# 0  CN2018           C           400          O  -34 -0.086696  68.638681
# 1  CN2018           P           400          O  -34 -0.086082  68.697261
#
#       delta  delta_diff       oev  total_oev  dollar_theta  dollar_vega
# 0  0.352105    0.147895  0.932483 -31.704419    147.382384 -1166.857582
# 1 -0.641702    1.141702  0.933279 -31.731477    146.338924 -1167.853439

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='SIN17U17VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  total_delta  \
# 0           SIN2017      18.0775          4.90             -5.10        -0.20
# 1           SIU2017      18.1400         -4.76              5.13         0.37
#
#    hedge
# 0   0.20
# 1  -0.37

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='BOF2019H2019Z2018F2019',broker='abn')

# %%
import ta.man_position_reconciler as mpr
mpr.reconcile_position()
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Empty DataFrame
# Columns: [generalized_ticker, qty_x, ticker, option_type, strike_price, instrument, qty_y, qty_diff]
# Index: []

# %%
import h5py
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import ta.man_position_reconciler as mpr
abn_position = mpr.load_and_convert_man_position_file()
abn_position
# Out:
#              generalized_ticker    qty
# 0                       SMV2018  -17.0
# 1                       SMZ2018   17.0
# 2                       SMF2019  -10.0
# 3                       SMH2019  -20.0
# 4                       SMK2019  -17.0
# 5                       SMN2019  100.0
# 6                       SMQ2019  -12.0
# 7                       SMU2019  -41.0
# 8                       BOV2018  -92.0
# 9                       BOZ2018  312.0
# 10                      BOF2019 -220.0
# 11                      TYU2018    2.0
# 12                TYZ2018-C-120  -37.0
# 13                TYZ2018-P-120  -37.0
# 14                       CN2019   16.0
# 15                       CU2019  -16.0
# 16                       SX2018  -29.0
# 17                       SF2019   12.0
# 18                       SH2019   13.0
# 19                       SK2019   -1.0
# 20                       SN2019    1.0
# 21                 SX2018-C-860  -20.0
# 22                 SX2018-P-860  -20.0
# ...

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='EC_OptionInventoryMar2018',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
# Empty DataFrame
# Columns: [total_oev, theta, dollar_vega, ticker]
# Index: []

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                       alias  generalized_ticker instrument option_type  \
# 17                Portfolio             CLQ2018    futures        None
# 2        spreadCarryJun18_2                 NaN    futures        None
# 10       spreadCarryJun18_2                 NaN    futures        None
# 68                Portfolio             LNQ2018    futures        None
# 18                Portfolio             CLU2018    futures        None
# 3        spreadCarryJun18_2                 NaN    futures        None
# 0     NGU2018_NGV2018_ocs_4                 NaN    futures        None
# 0           FCQ2018_long_fm                 NaN    futures        None
# 37                Portfolio             FCQ2018    futures        None
# 74                Portfolio             NGU2018    futures        None
# 110               Portfolio              WU2018    futures        None
# 1     WZ2018H2019U2018Z2018                 NaN    futures        None
# ...

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryFeb18_2',strategy_to='spreadCarryJun18_2')

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='NGK2019N2019N2019U2019',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='LCV18M18VCS')
wuhu

# sell 1 Z futures after

# W_KW_ifs_2_Aug-2017
# HO FG, 10

#bought 84 June
#sold 49
# Out:
#     ticker option_type  strike_price instrument  qty
# 0  NGK2019        None           NaN          F  1.0
# 1  NGN2019        None           NaN          F -2.0
# 2  NGU2019        None           NaN          F  1.0

# %%
wuhu  = tas.get_net_position_4strategy_alias(alias='CLV2019X2019U2019V2019')
wuhu
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d73d6bc6a7a> in <module>()
# ----> 1 wuhu  = tas.get_net_position_4strategy_alias(alias='CLV2019X2019U2019V2019')
#       2 wuhu
#
# NameError: name 'tas' is not defined

# %%
import ta.position_close_helper as pch

#pch.calc_intrday_pnl_from_prices(alias='CU2018_short_scv',structure_price=48.875,CU2018=384.75)
#pch.calc_intrday_pnl_from_prices(alias='WZ2018_long_scv',structure_price=78.375,WZ2018=559.75)
pch.calc_intrday_pnl_from_prices(alias='WZ18U18VCS',structure_price=16.25,WU2018=488,WZ2018=504.25)

# sell 3 CLF
# Out:
# {'structure_pnl': -5250.0, 'futures_pnl': 3068.0, 'structure_settle': 18.875}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='LCV2018_long_scv',structure_price=10.825,LCV2018=109.1)
# sell 2 WH futures
# Out:
# {'futures_pnl': -1842.0000000000698,
#  'structure_pnl': 399.99999999997726,
#  'structure_settle': 10.800000000000001}

# %%
0.8125*64
# Out:
# 52.0

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017'],
                                            structure_price = 10.275,
                                            strike_list=[68],
                                            underlying_price_list=[78.025],
                                            qty = -7,
                                            structure_type='straddle')


# sell 2 LNM futures
# Out:
# {'delta_pnl': 185.49394290000703,
#  'structure_pnl': 70.000000000001,
#  'structure_price_yesterday': 10.3,
#  'total_pnl': 255.49394290000802}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['CLX2018','CLZ2018'],
                                            structure_price =0.95,
                                            strike_list=[65.5,65],
                                            underlying_price_list=[68.21,67.78],
                                            qty =-40,
                                            structure_type='straddle_spread')

# sell 7 ZSN futures
# Out:
# C:\Research\PycharmProjects\ta\position_close_helper.py:84: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   ('qty', [-1, -1, 1, 1])])
# {'total_pnl': -154.45582800006048,
#  'structure_pnl': 799.9999999999741,
#  'delta_pnl': -954.4558280000346,
#  'structure_price_yesterday': 0.9699999999999993}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['WN2018','WZ2018'],
                                            structure_price =19.5,
                                            strike_list=[470,510],
                                            underlying_price_list=[528.25,564.75],
                                            qty =80,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': 29714.956679999999,
#  'structure_pnl': -29000.0,
#  'structure_price_yesterday': 26.75,
#  'total_pnl': 714.95667999999932}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LCQ2018','LCV2018'],
                                            structure_price =2.8,
                                            strike_list=[103,108],
                                            underlying_price_list=[103.375,106.975],
                                            qty =20,
                                            structure_type='straddle_spread')
# Out:
# C:\Research\PycharmProjects\ta\position_close_helper.py:84: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   ('qty', [-1, -1, 1, 1])])
# {'total_pnl': 502.4880359999952,
#  'structure_pnl': 4199.999999999995,
#  'delta_pnl': -3697.5119640000003,
#  'structure_price_yesterday': 2.2750000000000004}
