# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=22,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# 306

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='LNQ17M17VCS',description_string='strategy_class=vcs&betsize=13197')
# Out:
# 305

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
tfl.load_tt_trades(tags2exclude=['ifs_0','ifs_1','ifs_2','DeltaHedge'])
#tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
trade_frame = tfl.get_formatted_cme_direct_fills()
trade_frame['aggregate_trades']
# Out:
#                          trade_price  trade_quantity   ticker ticker_head  \
# generalized_ticker side
# CLX2016            Buy         51.30               1  CLX2016          CL
# CLZ2016            Sell        51.63              -1  CLZ2016          CL
# LCV2016            Sell       116.90              -1  LCV2016          LC
# LCZ2016            Buy        116.90               1  LCZ2016          LC
# WU2016             Buy        508.25               4   WU2016           W
#                    Sell       508.00              -1   WU2016           W
# WZ2016             Sell       527.50              -2   WZ2016           W
#
#                         instrument option_type  strike_price real_tradeQ
# generalized_ticker side
# CLX2016            Buy           F        None           NaN        True
# CLZ2016            Sell          F        None           NaN        True
# LCV2016            Sell          F        None           NaN        True
# LCZ2016            Buy           F        None           NaN        True
# WU2016             Buy           F        None           NaN        True
#                    Sell          F        None           NaN        True
# WZ2016             Sell          F        None           NaN        True

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
#sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_oct16',as_of_date=cu.get_doubledate())
wuhu

#wuhu  = tas.get_net_position_4strategy_alias(alias='delta_oct16',as_of_date=20161031)
#wuhu
# Out:
#      ticker option_type  strike_price instrument    qty
# 4   CLM2017        None           NaN          F   0.10
# 5   CLZ2017        None           NaN          F  -0.12
# 6    CU2017        None           NaN          F  -0.75
# 8    CZ2017        None           NaN          F   0.83
# 9   ECH2017        None           NaN          F  -4.00
# 10  ECM2017        None           NaN          F   4.00
# 12  ESH2017        None           NaN          F   2.00
# 13  ESU2017        None           NaN          F  -1.66
# 15  GCG2017        None           NaN          F  -7.00
# 16  GCJ2017        None           NaN          F   8.57
# 18  GCQ2017        None           NaN          F  -1.19
# 24  LNJ2017        None           NaN          F   0.39
# 25  LNM2017        None           NaN          F  -0.36
# 26  LNQ2017        None           NaN          F  -0.34
# 30  SIH2017        None           NaN          F   0.17
# 31  SIK2017        None           NaN          F   0.22
# 32  SIN2017        None           NaN          F  -0.29
# 37   WK2017        None           NaN          F  18.00
# 38   WN2017        None           NaN          F -18.00

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='SI_inventory_Aug16')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
# Out:
#     ticker  total_oev    theta  dollar_vega
# 0  SIH2017  -2.357274  63.8763  -275.077031

# %%
output['ticker_portfolio']
# Out:
#     ticker  total_oev     theta  dollar_vega
# 0  SIH2017  -6.054893  154.0729  -841.851821

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='NGU2017V2017Q2017U2017_3')

# %%
import ta.abn_position_reconciler as pr
pr.reconcile_position()
# Out:
# Empty DataFrame
# Columns: [generalized_ticker, qty_x, ticker, option_type, strike_price, instrument, qty_y, qty_diff]
# Index: []

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='LCZ16V16VCS',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
#     ticker  total_oev      theta
# 0  LCV2016 -19.988474  157.53088
# 1  LCZ2016  19.999996 -120.84700

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                       alias  generalized_ticker instrument option_type  \
# 54                Portfolio             ECZ2016    futures        None
# 6               delta_oct16                 NaN    futures        None
# 64                Portfolio             FCF2017    futures        None
# 0    FCH2017J2017F2017H2017                 NaN    futures        None
# 118               Portfolio   SIH2017-P-19.0000    options           P
# 116               Portfolio   SIH2017-C-19.0000    options           C
# 115               Portfolio   SIH2017-C-16.5000    options           C
# 1        SI_inventory_Aug16                 NaN    options           C
# 2        SI_inventory_Aug16                 NaN    options           C
# 3        SI_inventory_Aug16                 NaN    options           P
# 4        SI_inventory_Aug16                 NaN    options           P
# 117               Portfolio   SIH2017-P-16.5000    options           P
# 1               SMN17H17VCS                 NaN    options           C
# 2               SMN17H17VCS                 NaN    options           P
# 100               Portfolio             NGH2017    futures        None
# 9               delta_oct16                 NaN    futures        None
# 126               Portfolio  SMH2017-C-320.0000    options           C
# 127               Portfolio  SMH2017-P-320.0000    options           P
# 68                Portfolio             GCG2017    futures        None
# 2                CH17K17VCS                 NaN    options           C
# 19                Portfolio   CH2017-C-350.0000    options           C
# 8          spreadCarryDec16                 NaN    futures        None
# 3                CH17K17VCS                 NaN    options           P
# 22                Portfolio   CH2017-P-360.0000    options           P
# 4                CH17K17VCS                 NaN    options           P
# 21                Portfolio   CH2017-P-350.0000    options           P
# 1                CH17K17VCS                 NaN    options           C
# 20                Portfolio   CH2017-C-360.0000    options           C
# 2               ECH17M17VCS                 NaN    options           P
# 1               ECH17M17VCS                 NaN    options           C
# ..                      ...                 ...        ...         ...
# 6          spreadCarryDec16                 NaN    futures        None
# 82                Portfolio             LNG2018    futures        None
# 1               B_pca_Aug16                 NaN    futures        None
# 2                 Portfolio              BJ2018    futures        None
# 1     SH2018K2018F2018H2018                 NaN    futures        None
# 113               Portfolio              SH2018    futures        None
# 75                Portfolio             KCH2018    futures        None
# 0    KCU2017H2018K2017U2017                 NaN    futures        None
# 55                Portfolio             EDH2018    futures        None
# 0    EDZ2017H2018U2017Z2017                 NaN    futures        None
# 124               Portfolio              SK2018    futures        None
# 2     SH2018K2018F2018H2018                 NaN    futures        None
# 1     BZ2018M2019U2018Z2018                 NaN    futures        None
# 11                Portfolio              BU2018    futures        None
# 0    CLX2018Z2018V2018X2018                 NaN    futures        None
# 39                Portfolio             CLV2018    futures        None
# 1    EDZ2018H2019U2018Z2018                 NaN    futures        None
# 58                Portfolio             EDU2018    futures        None
# 40                Portfolio             CLX2018    futures        None
# 1    CLX2018Z2018V2018X2018                 NaN    futures        None
# 14                Portfolio              BZ2018    futures        None
# 2     BZ2018M2019U2018Z2018                 NaN    futures        None
# 46                Portfolio             CLZ2018    futures        None
# 2    CLX2018Z2018V2018X2018                 NaN    futures        None
# 2    EDZ2018H2019U2018Z2018                 NaN    futures        None
# 60                Portfolio             EDZ2018    futures        None
# 56                Portfolio             EDH2019    futures        None
# 0    EDZ2018H2019U2018Z2018                 NaN    futures        None
# 5                 Portfolio              BM2019    futures        None
# 0     BZ2018M2019U2018Z2018                 NaN    futures        None
#
#          qty strike_price   ticker  tr_dte
# 54      3.00         None  ECZ2016       2
# 6          3          NaN  ECZ2016       2
# 64     -2.00         None  FCF2017      27
# 0         -2          NaN  FCF2017      27
# 118     2.00      19.0000  SIH2017      46
# 116     2.00      19.0000  SIH2017      46
# 115    -4.00      16.5000  SIH2017      46
# 1         -4         16.5  SIH2017      46
# 2          2           19  SIH2017      46
# 3         -4         16.5  SIH2017      46
# 4          2           19  SIH2017      46
# 117    -4.00      16.5000  SIH2017      46
# 1        -51          320  SMH2017      47
# 2        -51          320  SMH2017      47
# 100    -1.00         None  NGH2017      47
# 9         -7          NaN  GCG2017      47
# 126   -51.00     320.0000  SMH2017      47
# 127   -51.00     320.0000  SMH2017      47
# 68     -7.00         None  GCG2017      47
# 2         25          360   CH2017      47
# 19     30.00     350.0000   CH2017      47
# 8         -1          NaN  NGH2017      47
# 3         30          350   CH2017      47
# 22     25.00     360.0000   CH2017      47
# 4         25          360   CH2017      47
# 21     30.00     350.0000   CH2017      47
# 1         30          350   CH2017      47
# 20     25.00     360.0000   CH2017      47
# 2         20         1.09  ECH2017      52
# 1         20         1.09  ECH2017      52
# ..       ...          ...      ...     ...
# 6         -3          NaN  LNG2018     292
# 82     -3.00         None  LNG2018     292
# 1        -70          NaN   BJ2018     305
# 2     -70.00         None   BJ2018     305
# 1          2          NaN   SH2018     311
# 113     2.00         None   SH2018     311
# 75    -11.00         None  KCH2018     314
# 0        -11          NaN  KCH2018     314
# 55   -280.00         None  EDH2018     318
# 0       -280          NaN  EDH2018     318
# 124    -1.00         None   SK2018     353
# 2         -1          NaN   SK2018     353
# 1        -27          NaN   BU2018     411
# 11    -27.00         None   BU2018     411
# 0         -3          NaN  CLV2018     443
# 39     -3.00         None  CLV2018     443
# 1       -100          NaN  EDU2018     444
# 58   -100.00         None  EDU2018     444
# 40      6.00         None  CLX2018     465
# 1          6          NaN  CLX2018     465
# 14     44.00         None   BZ2018     476
# 2         44          NaN   BZ2018     476
# 46     -3.00         None  CLZ2018     485
# 2         -3          NaN  CLZ2018     485
# 2        200          NaN  EDZ2018     508
# 60    200.00         None  EDZ2018     508
# 56   -100.00         None  EDH2019     571
# 0       -100          NaN  EDH2019     571
# 5     -17.00         None   BM2019     601
# 0        -17          NaN   BM2019     601
#
# [327 rows x 8 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryDec16_2',strategy_to='spreadCarryJan17_2')

# %%
import ta.strategy as ts
import shared.calendar_utilities as cu
wuhu = ts.get_net_position_4strategy_alias(alias='NGX2018Z2018V2018X2018')
wuhu
# Out:
#     ticker option_type  strike_price instrument  qty
# 0  NGV2018        None           NaN          F  -25
# 1  NGX2018        None           NaN          F   50
# 2  NGZ2018        None           NaN          F  -25

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='RBG2018H2018F2018G2018',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='S_BO_SM_ifs_Nov-2016')
wuhu

# sell 1 Z futures after
# Out:
#     ticker option_type  strike_price instrument  qty
# 0  RBF2018        None           NaN          F  -30
# 1  RBG2018        None           NaN          F   59
# 2  RBH2018        None           NaN          F  -29

# %%
import ta.position_close_helper as pch
#pch.calc_intrday_pnl_from_prices(alias='SMN17H17VCS',structure_price=14.59,SMH2017=317.8,SMN2017=323.1)
pch.calc_intrday_pnl_from_prices(alias='WN17K17VCS',structure_price=14.75,WK2017=439,WN2017=453.5)

# also buy one CLZ
# Out:
# {'futures_pnl': 283.0, 'structure_pnl': 300.0, 'structure_settle': 14.625}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='SMN2017_long_scv',structure_price=41.9,SMN2017=348)
# buy 1 CLM futures
# Out:
# {'futures_pnl': 30.599999999999966,
#  'structure_pnl': 5360.0000000000018,
#  'structure_settle': 38.549999999999997}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['CLM2017','CLZ2017'],
                                            structure_price = 3.5,
                                            strike_list=[48.5,50],
                                            underlying_price_list=[54.34, 55.25],
                                            qty = 4,
                                            structure_type='straddle_spread')


# but 3 CH for 30 lot
# Out:
# {'delta_pnl': -349.9347839999931,
#  'structure_pnl': 559.9999999999952,
#  'structure_price_yesterday': 3.360000000000001,
#  'total_pnl': 210.06521600000212}
