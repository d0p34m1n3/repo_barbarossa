# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# %matplotlib inline
import futures_charts.futures_curve as fc
#fc.get_futures_curve_chart_4date(ticker_head='RB',settle_date=report_date,tr_dte_limit=600)  # 600

no = 18

#aggregation_method, contracts_back
bf_signals_output = fc.get_butterfly_panel_plot(report_date=report_date,id=no)   # 315 so much to clean!!!
bf_signals_output = fc.get_butterfly_scatter_plot(report_date=report_date,id=no)

# %% [raw]
# * one:
# * second:
#
# S_T = S_0 \exp((r - 0.5\sigma^2) T + \sigma \sqrt{T} z)

# %%
import get_price.presave_price as pp
pp.generate_and_update_futures_data_file_4tickerhead(ticker_head='HO')

# %%
import get_price.get_futures_price as gfp
gfp.get_futures_price_preloaded(ticker_head='ED',settle_date=20160217)
# Out:
#        settle_date   ticker ticker_head  ticker_month  ticker_year  cal_dte  \
# 236359  2016-02-17  EDH2016          ED             3         2016       26
# 236394  2016-02-17  EDJ2016          ED             4         2016       61
# 236429  2016-02-17  EDK2016          ED             5         2016       89
# 236464  2016-02-17  EDM2016          ED             6         2016      117
# 236481  2016-02-17  EDN2016          ED             7         2016      152
# 236516  2016-02-17  EDU2016          ED             9         2016      215
# 236551  2016-02-17  EDZ2016          ED            12         2016      306
# 236586  2016-02-17  EDH2017          ED             3         2017      390
# 236621  2016-02-17  EDM2017          ED             6         2017      488
# 236656  2016-02-17  EDU2017          ED             9         2017      579
# 236691  2016-02-17  EDZ2017          ED            12         2017      670
# 236726  2016-02-17  EDH2018          ED             3         2018      761
# 236761  2016-02-17  EDM2018          ED             6         2018      852
# 236796  2016-02-17  EDU2018          ED             9         2018      943
# 236831  2016-02-17  EDZ2018          ED            12         2018     1034
# 236866  2016-02-17  EDH2019          ED             3         2019     1125
# 236901  2016-02-17  EDM2019          ED             6         2019     1216
# 236936  2016-02-17  EDU2019          ED             9         2019     1307
# 236971  2016-02-17  EDZ2019          ED            12         2019     1398
#
#         tr_dte  close_price  volume  cont_indx  change1  change2  change5  \
# 236359      18      99.3575  219544     201603      NaN      NaN      NaN
# 236394      42      99.3400    1688     201604      NaN      NaN      NaN
# 236429      62      99.3250       0     201605      NaN      NaN      NaN
# 236464      81      99.3150  314816     201606      NaN      NaN      NaN
# 236481     105      99.3000       2     201607      NaN      NaN      NaN
# 236516     149      99.2750  225783     201609      NaN      NaN      NaN
# 236551     213      99.2200  264250     201612      NaN      NaN      NaN
# 236586     271      99.1750  240482     201703      NaN      NaN      NaN
# 236621     339      99.1150  175044     201706      NaN      NaN      NaN
# 236656     402      99.0550  133355     201709      NaN      NaN      NaN
# 236691     466      98.9750  159985     201712      NaN      NaN      NaN
# 236726     529      98.9050   88687     201803      NaN      NaN      NaN
# 236761     592      98.8250   76487     201806      NaN      NaN      NaN
# 236796     655      98.7450   62160     201809      NaN      NaN      NaN
# 236831     719      98.6600   64068     201812      NaN      NaN      NaN
# 236866     782      98.5900   44908     201903      NaN      NaN      NaN
# 236901     845      98.5100   29430     201906      NaN      NaN      NaN
# 236936     908      98.4300   24593     201909      NaN      NaN      NaN
# 236971     972      98.3500   24805     201912      NaN      NaN      NaN
#
#         change10  change20  change_5  change_1
# 236359       NaN       NaN    0.0125    -0.005
# 236394       NaN       NaN    0.0050    -0.005
# 236429       NaN       NaN   -0.0050    -0.015
# 236464       NaN       NaN    0.0000    -0.020
# 236481       NaN       NaN   -0.0100    -0.025
# 236516       NaN       NaN   -0.0150    -0.025
# 236551       NaN       NaN   -0.0300    -0.030
# 236586       NaN       NaN   -0.0450    -0.030
# 236621       NaN       NaN   -0.0600    -0.035
# 236656       NaN       NaN   -0.0650    -0.035
# 236691       NaN       NaN   -0.0650    -0.040
# 236726       NaN       NaN   -0.0600    -0.040
# 236761       NaN       NaN   -0.0550    -0.045
# 236796       NaN       NaN   -0.0550    -0.050
# 236831       NaN       NaN   -0.0500    -0.050
# 236866       NaN       NaN   -0.0450    -0.050
# 236901       NaN       NaN   -0.0450    -0.050
# 236936       NaN       NaN   -0.0500    -0.055
# 236971       NaN       NaN   -0.0500    -0.055

# %%
print('Q:' + str(bf_signals_output['q']))
print('QF:' + str(bf_signals_output['qf']))
print('zscore1:' + str(bf_signals_output['zscore1']))
print('zscore2:' + str(bf_signals_output['zscore2']))
print('theo_pnl:' + str(bf_signals_output['theo_pnl']))
# Out:
# Q:62
# QF:99
# zscore1:0.850649218047
# zscore2:0.904724189223
# theo_pnl:-69.5469209534

# %%
aligned_data = bf_signals_output['aligned_output']['aligned_data']


grouped = aligned_data.groupby(aligned_data['c1']['cont_indx'])

aligned_data['shifted_residuals'] = grouped['residuals'].shift(-5)

aligned_data['residual_change'] = aligned_data['shifted_residuals']-aligned_data['residuals']

import statsmodels.api as sm

results = sm.OLS(aligned_data['residual_change'].values, aligned_data['residuals'].values, hasconst=True).fit()
results.params

import numpy as np

x=aligned_data['residuals'] 
y=aligned_data['residual_change'] 

nan_indx_x = np.isnan(x)
nan_indx_y = np.isnan(y)

clean_y = [y[i] for i in range(len(y)) if not nan_indx_x[i] and not nan_indx_y[i]]
clean_x = [x[i] for i in range(len(y)) if not nan_indx_x[i] and not nan_indx_y[i]]


results = sm.OLS(clean_y, sm.add_constant(clean_x), hasconst=True).fit()
results.conf_int()
# Out:
# array([[-0.00467772,  0.03873896],
#        [-0.25729764, -0.19520576]])

# %%
import get_price.get_futures_price as gfp
data4_tickerhead = gfp.get_futures_price_4ticker(ticker_head='CL')

# %%
data4_tickerhead
# Out:
#        settle_date   ticker ticker_head  ticker_month  ticker_year  cal_dte  \
# 0       1983-03-30  CLM1983          CL             6         1983       51
# 1       1983-03-30  CLN1983          CL             7         1983       83
# 2       1983-03-30  CLQ1983          CL             8         1983      112
# 3       1983-03-30  CLU1983          CL             9         1983      145
# 4       1983-03-30  CLV1983          CL            10         1983      174
# 5       1983-03-30  CLX1983          CL            11         1983      204
# 6       1983-03-30  CLZ1983          CL            12         1983      236
# 7       1983-03-31  CLM1983          CL             6         1983       50
# 8       1983-03-31  CLN1983          CL             7         1983       82
# 9       1983-03-31  CLQ1983          CL             8         1983      111
# 10      1983-03-31  CLU1983          CL             9         1983      144
# 11      1983-03-31  CLV1983          CL            10         1983      173
# 12      1983-03-31  CLX1983          CL            11         1983      203
# 13      1983-03-31  CLZ1983          CL            12         1983      235
# 14      1983-04-04  CLM1983          CL             6         1983       46
# 15      1983-04-04  CLN1983          CL             7         1983       78
# 16      1983-04-04  CLQ1983          CL             8         1983      107
# 17      1983-04-04  CLU1983          CL             9         1983      140
# 18      1983-04-04  CLV1983          CL            10         1983      169
# 19      1983-04-04  CLX1983          CL            11         1983      199
# 20      1983-04-04  CLZ1983          CL            12         1983      231
# 21      1983-04-05  CLM1983          CL             6         1983       45
# 22      1983-04-05  CLN1983          CL             7         1983       77
# 23      1983-04-05  CLQ1983          CL             8         1983      106
# 24      1983-04-05  CLU1983          CL             9         1983      139
# 25      1983-04-05  CLV1983          CL            10         1983      168
# 26      1983-04-05  CLX1983          CL            11         1983      198
# 27      1983-04-05  CLZ1983          CL            12         1983      230
# 28      1983-04-06  CLM1983          CL             6         1983       44
# 29      1983-04-06  CLN1983          CL             7         1983       76
# ...            ...      ...         ...           ...          ...      ...
# 315447  2016-01-12  CLQ2017          CL             8         2017      555
# 315448  2016-01-12  CLU2017          CL             9         2017      588
# 315449  2016-01-12  CLV2017          CL            10         2017      617
# 315450  2016-01-12  CLX2017          CL            11         2017      647
# 315451  2016-01-12  CLZ2017          CL            12         2017      678
# 315452  2016-01-12  CLF2018          CL             1         2018      707
# 315453  2016-01-13  CLG2016          CL             2         2016        7
# 315454  2016-01-13  CLH2016          CL             3         2016       40
# 315455  2016-01-13  CLJ2016          CL             4         2016       68
# 315456  2016-01-13  CLK2016          CL             5         2016       98
# 315457  2016-01-13  CLM2016          CL             6         2016      128
# 315458  2016-01-13  CLN2016          CL             7         2016      160
# 315459  2016-01-13  CLQ2016          CL             8         2016      189
# 315460  2016-01-13  CLU2016          CL             9         2016      222
# 315461  2016-01-13  CLV2016          CL            10         2016      251
# 315462  2016-01-13  CLX2016          CL            11         2016      281
# 315463  2016-01-13  CLZ2016          CL            12         2016      313
# 315464  2016-01-13  CLF2017          CL             1         2017      342
# 315465  2016-01-13  CLG2017          CL             2         2017      373
# 315466  2016-01-13  CLH2017          CL             3         2017      405
# 315467  2016-01-13  CLJ2017          CL             4         2017      433
# 315468  2016-01-13  CLK2017          CL             5         2017      463
# 315469  2016-01-13  CLM2017          CL             6         2017      495
# 315470  2016-01-13  CLN2017          CL             7         2017      524
# 315471  2016-01-13  CLQ2017          CL             8         2017      554
# 315472  2016-01-13  CLU2017          CL             9         2017      587
# 315473  2016-01-13  CLV2017          CL            10         2017      616
# 315474  2016-01-13  CLX2017          CL            11         2017      646
# 315475  2016-01-13  CLZ2017          CL            12         2017      677
# 315476  2016-01-13  CLF2018          CL             1         2018      706
#
#         tr_dte close_price  volume
# 0           36     29.4000     949
# 1           57     29.3500     471
# 2           77     29.2000     216
# 3          100     28.9500     160
# 4          120     28.9500      18
# 5          142     28.9000      32
# 6          164     28.7500      38
# 7           35     29.2900     521
# 8           56     29.2400     399
# 9           76     29.0500     300
# 10          99     28.8500     218
# 11         119     28.7500       3
# 12         141     28.7000       9
# 13         163     28.6000      28
# 14          34     29.4400     156
# 15          55     29.2500     185
# 16          75     29.1000     123
# 17          98     29.0500       9
# 18         118     28.9500       0
# 19         140     28.9500       2
# 20         162     28.8500       3
# 21          33     29.7100     175
# 22          54     29.5400     164
# 23          74     29.3500      61
# 24          97     29.2000      69
# 25         117     29.1000       5
# 26         139     29.0000       2
# 27         161     29.0000       2
# 28          32     29.9000     392
# 29          53     29.6800     257
# ...        ...         ...     ...
# 315447     383     41.0000      33
# 315448     406     41.2900      38
# 315449     426     41.5900       4
# 315450     448     41.8900      43
# 315451     469     42.2000   13045
# 315452     489     42.4100      45
# 315453       4     30.4800  623300
# 315454      26     31.3900  344899
# 315455      46     32.3500  114017
# 315456      67     33.2800   61497
# 315457      89     34.1200   63419
# 315458     110     34.8300   21212
# 315459     130     35.4200    8788
# 315460     153     35.9400   13638
# 315461     173     36.4100    4882
# 315462     195     36.9000    3106
# 315463     217     37.4100   42047
# 315464     237     37.8200    2317
# 315465     257     38.2200    1121
# 315466     278     38.6000    1232
# 315467     298     38.9600     220
# 315468     319     39.2900     224
# 315469     341     39.6100   10917
# 315470     361     39.8800      91
# 315471     382     40.1500      45
# 315472     405     40.4400     118
# 315473     425     40.7400      84
# 315474     447     41.0300     178
# 315475     468     41.3300   16406
# 315476     488     41.5300     145
#
# [315477 rows x 9 columns]

# %%
import datetime as dt
import pandas as pd
dirty_data = pd.DataFrame.from_items([('ticker', ['CLG2008','CLH2008']), ('settle_date', [dt.date(2007,5,31),dt.date(2007,5,31)])])
data4_tickerhead
dirty_data
# Out:
#     ticker settle_date
# 0  CLG2008  2007-05-31
# 1  CLH2008  2007-05-31

# %%
import get_price.presave_price as psp
psp.generate_and_update_futures_data_file_4tickerhead(ticker_head='HO')

# %%
import pandas as pd
import numpy as np
import get_price.presave_price as psp
dirty_data_points = psp.dirty_data_points
data4_tickerhead = pd.merge(data4_tickerhead, dirty_data_points, on=['settle_date', 'ticker'],how='left')
data4_tickerhead_filtered = data4_tickerhead[data4_tickerhead['discard'] !=True]

# %%
data4_tickerhead_filtered[(data4_tickerhead_filtered['settle_date']==dirty_data_points['settle_date'][0])&
                 (data4_tickerhead_filtered['ticker']==dirty_data_points['ticker'][0])]
# Out:
# Empty DataFrame
# Columns: [settle_date, ticker, ticker_head, ticker_month, ticker_year, cal_dte, tr_dte, close_price, volume, discard]
# Index: []

# %%
data4_tickerhead
# Out:
#        settle_date   ticker ticker_head  ticker_month  ticker_year  cal_dte  \
# 0       1983-03-30  CLM1983          CL             6         1983       51
# 1       1983-03-30  CLN1983          CL             7         1983       83
# 2       1983-03-30  CLQ1983          CL             8         1983      112
# 3       1983-03-30  CLU1983          CL             9         1983      145
# 4       1983-03-30  CLV1983          CL            10         1983      174
# 5       1983-03-30  CLX1983          CL            11         1983      204
# 6       1983-03-30  CLZ1983          CL            12         1983      236
# 7       1983-03-31  CLM1983          CL             6         1983       50
# 8       1983-03-31  CLN1983          CL             7         1983       82
# 9       1983-03-31  CLQ1983          CL             8         1983      111
# 10      1983-03-31  CLU1983          CL             9         1983      144
# 11      1983-03-31  CLV1983          CL            10         1983      173
# 12      1983-03-31  CLX1983          CL            11         1983      203
# 13      1983-03-31  CLZ1983          CL            12         1983      235
# 14      1983-04-04  CLM1983          CL             6         1983       46
# 15      1983-04-04  CLN1983          CL             7         1983       78
# 16      1983-04-04  CLQ1983          CL             8         1983      107
# 17      1983-04-04  CLU1983          CL             9         1983      140
# 18      1983-04-04  CLV1983          CL            10         1983      169
# 19      1983-04-04  CLX1983          CL            11         1983      199
# 20      1983-04-04  CLZ1983          CL            12         1983      231
# 21      1983-04-05  CLM1983          CL             6         1983       45
# 22      1983-04-05  CLN1983          CL             7         1983       77
# 23      1983-04-05  CLQ1983          CL             8         1983      106
# 24      1983-04-05  CLU1983          CL             9         1983      139
# 25      1983-04-05  CLV1983          CL            10         1983      168
# 26      1983-04-05  CLX1983          CL            11         1983      198
# 27      1983-04-05  CLZ1983          CL            12         1983      230
# 28      1983-04-06  CLM1983          CL             6         1983       44
# 29      1983-04-06  CLN1983          CL             7         1983       76
# ...            ...      ...         ...           ...          ...      ...
# 315447  2016-01-12  CLQ2017          CL             8         2017      555
# 315448  2016-01-12  CLU2017          CL             9         2017      588
# 315449  2016-01-12  CLV2017          CL            10         2017      617
# 315450  2016-01-12  CLX2017          CL            11         2017      647
# 315451  2016-01-12  CLZ2017          CL            12         2017      678
# 315452  2016-01-12  CLF2018          CL             1         2018      707
# 315453  2016-01-13  CLG2016          CL             2         2016        7
# 315454  2016-01-13  CLH2016          CL             3         2016       40
# 315455  2016-01-13  CLJ2016          CL             4         2016       68
# 315456  2016-01-13  CLK2016          CL             5         2016       98
# 315457  2016-01-13  CLM2016          CL             6         2016      128
# 315458  2016-01-13  CLN2016          CL             7         2016      160
# 315459  2016-01-13  CLQ2016          CL             8         2016      189
# 315460  2016-01-13  CLU2016          CL             9         2016      222
# 315461  2016-01-13  CLV2016          CL            10         2016      251
# 315462  2016-01-13  CLX2016          CL            11         2016      281
# 315463  2016-01-13  CLZ2016          CL            12         2016      313
# 315464  2016-01-13  CLF2017          CL             1         2017      342
# 315465  2016-01-13  CLG2017          CL             2         2017      373
# 315466  2016-01-13  CLH2017          CL             3         2017      405
# 315467  2016-01-13  CLJ2017          CL             4         2017      433
# 315468  2016-01-13  CLK2017          CL             5         2017      463
# 315469  2016-01-13  CLM2017          CL             6         2017      495
# 315470  2016-01-13  CLN2017          CL             7         2017      524
# 315471  2016-01-13  CLQ2017          CL             8         2017      554
# 315472  2016-01-13  CLU2017          CL             9         2017      587
# 315473  2016-01-13  CLV2017          CL            10         2017      616
# 315474  2016-01-13  CLX2017          CL            11         2017      646
# 315475  2016-01-13  CLZ2017          CL            12         2017      677
# 315476  2016-01-13  CLF2018          CL             1         2018      706
#
#         tr_dte close_price  volume discard
# 0           36     29.4000     949     NaN
# 1           57     29.3500     471     NaN
# 2           77     29.2000     216     NaN
# 3          100     28.9500     160     NaN
# 4          120     28.9500      18     NaN
# 5          142     28.9000      32     NaN
# 6          164     28.7500      38     NaN
# 7           35     29.2900     521     NaN
# 8           56     29.2400     399     NaN
# 9           76     29.0500     300     NaN
# 10          99     28.8500     218     NaN
# 11         119     28.7500       3     NaN
# 12         141     28.7000       9     NaN
# 13         163     28.6000      28     NaN
# 14          34     29.4400     156     NaN
# 15          55     29.2500     185     NaN
# 16          75     29.1000     123     NaN
# 17          98     29.0500       9     NaN
# 18         118     28.9500       0     NaN
# 19         140     28.9500       2     NaN
# 20         162     28.8500       3     NaN
# 21          33     29.7100     175     NaN
# 22          54     29.5400     164     NaN
# 23          74     29.3500      61     NaN
# 24          97     29.2000      69     NaN
# 25         117     29.1000       5     NaN
# 26         139     29.0000       2     NaN
# 27         161     29.0000       2     NaN
# 28          32     29.9000     392     NaN
# 29          53     29.6800     257     NaN
# ...        ...         ...     ...     ...
# 315447     383     41.0000      33     NaN
# 315448     406     41.2900      38     NaN
# 315449     426     41.5900       4     NaN
# 315450     448     41.8900      43     NaN
# 315451     469     42.2000   13045     NaN
# 315452     489     42.4100      45     NaN
# 315453       4     30.4800  623300     NaN
# 315454      26     31.3900  344899     NaN
# 315455      46     32.3500  114017     NaN
# 315456      67     33.2800   61497     NaN
# 315457      89     34.1200   63419     NaN
# 315458     110     34.8300   21212     NaN
# 315459     130     35.4200    8788     NaN
# 315460     153     35.9400   13638     NaN
# 315461     173     36.4100    4882     NaN
# 315462     195     36.9000    3106     NaN
# 315463     217     37.4100   42047     NaN
# 315464     237     37.8200    2317     NaN
# 315465     257     38.2200    1121     NaN
# 315466     278     38.6000    1232     NaN
# 315467     298     38.9600     220     NaN
# 315468     319     39.2900     224     NaN
# 315469     341     39.6100   10917     NaN
# 315470     361     39.8800      91     NaN
# 315471     382     40.1500      45     NaN
# 315472     405     40.4400     118     NaN
# 315473     425     40.7400      84     NaN
# 315474     447     41.0300     178     NaN
# 315475     468     41.3300   16406     NaN
# 315476     488     41.5300     145     NaN
#
# [315477 rows x 10 columns]
