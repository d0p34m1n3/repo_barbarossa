# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=252,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# {'alias': 'HOV2018X2018U2018V2018_2', 'strategy_id': 1034}

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='EDJ2018_EDK2018_ocs',description_string='strategy_class=ocs&betsize=850&ticker1=EDJ2018&ticker2=EDK2018')
# Out:
# {'alias': 'EDJ2018_EDK2018_ocs', 'strategy_id': 1035}

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies(trade_source='tt')
#wuhu
tfl.load_tt_trades(tags2exclude=['ifs','DeltaHedge'])     # 'DeltaHedge','ocs'
#tfl.load_cme_direct_trades()
#tfl.load_manual_entry_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu['aggregate_trades']

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()
#wuhu = tfl.get_formatted_cme_direct_fills()
#wuhu['aggregate_trades']

# %%
import ta.trade_fill_loader as tfl
tt_export_frame_filtered = tfl.load_latest_tt_fills(tags2exclude=['ifs','ocs','DeltaHedge'])

tt_export_frame_filtered
tags2exclude=['ifs','ocs','DeltaHedge']

# %%
import ta.trade_fill_loader as tfl
wuhu = tfl.get_formatted_manual_entry_fills()
wuhu
# Out:
#    ticker option_type  strike_price  trade_price  trade_quantity
# 0  SU2016           P          1040       24.875               5
# 1  SU2016           C          1040       90.625               5
# 2  SX2016           P          1020       32.250              -5
# 3  SX2016           C          1020       97.250              -5

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
#sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='delta_jan18',as_of_date=cu.get_doubledate())
wuhu
# Out:
#      ticker option_type  strike_price instrument    qty
# 0   CLM2018        None           NaN          F   0.24
# 1   CLZ2018        None           NaN          F  -0.13
# 2    CU2018        None           NaN          F  -7.45
# 3    CZ2018        None           NaN          F   7.29
# 4   ECH2018        None           NaN          F  -0.24
# 5   ESH2018        None           NaN          F  14.00
# 6   ESM2018        None           NaN          F -14.37
# 7   LCM2018        None           NaN          F   0.25
# 8   LCV2018        None           NaN          F  -0.46
# 9   NGH2018        None           NaN          F   0.14
# 10  NGJ2018        None           NaN          F  -0.44
# 11  NGK2018        None           NaN          F   0.78
# 12  SIH2018        None           NaN          F  -4.00
# 13  SIK2018        None           NaN          F   4.00
# 14   SQ2018        None           NaN          F   0.18
# 15   SX2018        None           NaN          F  -0.48

# %%
import ta.strategy_greeks as sg
import pandas as pd
import get_price.get_options_price as gop
output = sg.get_greeks_4strategy_4date(alias='SIN17U17VCS')

# SIU16Z16VCS
output['ticker_portfolio']
#output['strike_portfolio']
# 2.6/ -5.2
# 3/-6
#output['strike_portfolio']

# silver portfolio might cause problems
#output

# Z7 vol from 29.15 to 27.6
# to 29.6 to 28
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
output['strike_portfolio']['total_oev'].sum()
output['ticker_portfolio']
output['strike_portfolio']
# Out:
#     ticker option_type  strike_price instrument  qty     theta      vega  \
# 0  SIN2017           C          17.5          O   21 -0.003368  3.907616
# 1  SIN2017           P          17.5          O   21 -0.003390  3.907479
# 0  SIU2017           C          17.5          O  -21 -0.002924  4.855933
# 1  SIU2017           P          17.5          O  -21 -0.002948  4.855679
#
#       delta  delta_diff       oev  total_oev  dollar_theta  dollar_vega
# 0  0.651631    0.151631  0.925150  19.428158    -353.58960  4102.997251
# 1 -0.344417    0.844417  0.925118  19.427472    -355.95105  4102.852478
# 0  0.637411    0.137411  0.936789 -19.672562     306.98850 -5098.729797
# 1 -0.356417    0.856417  0.936740 -19.671534     309.56520 -5098.463349

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='SIN17U17VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  total_delta  \
# 0           SIN2017      18.0775          4.90             -5.10        -0.20
# 1           SIU2017      18.1400         -4.76              5.13         0.37
#
#    hedge
# 0   0.20
# 1  -0.37

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='NGJ18H18VCS',broker='abn')

# %%
import ta.man_position_reconciler as mpr
mpr.reconcile_position()
# Out:
# Empty DataFrame
# Columns: [generalized_ticker, qty_x, ticker, option_type, strike_price, instrument, qty_y, qty_diff]
# Index: []

# %%
import ta.strategy_greeks as sg
greeks_out = sg.get_greeks_4strategy_4date(alias='LCZ16V16VCS',as_of_date=20160614)
greeks_out['ticker_portfolio']
# Out:
#     ticker  total_oev      theta  dollar_vega
# 0  LCV2016 -19.988474  157.53088 -2050.367122
# 1  LCZ2016  19.999996 -120.84700  2517.126992

# %%
# EXPIRATION REPORT:

import ta.expiration_followup as ef
ef.get_expiration_report(report_date=report_date)
# Out:
#                         alias generalized_ticker instrument option_type  \
# 2      RBF2018H2018X2017F2018                NaN    futures        None
# 95                  Portfolio            RBX2017    futures        None
# 0         EDX2017_EDZ2017_ocs                NaN    futures        None
# 43                  Portfolio            EDX2017    futures        None
# 33                  Portfolio  CLZ2017-P-50.5000    options           P
# 5                 CLZ17H18VCS                NaN    options           P
# 4                 CLZ17H18VCS                NaN    options           C
# 32                  Portfolio  CLZ2017-C-50.5000    options           C
# 7          spreadCarrySep17_2                NaN    futures        None
# 52                  Portfolio            FCX2017    futures        None
# 31                  Portfolio            CLZ2017    futures        None
# 5                 delta_sep17                NaN    futures        None
# 3                 CLZ17H18VCS                NaN    futures        None
# 105                 Portfolio            SIZ2017    futures        None
# 12                delta_sep17                NaN    futures        None
# 61                  Portfolio            HOZ2017    futures        None
# 1       RBZ2017_RBF2018_ocs_8                NaN    futures        None
# 97                  Portfolio            RBZ2017    futures        None
# 2    HOF2018G2018Z2017F2018_3                NaN    futures        None
# 2    CTH2018K2018Z2017H2018_4                NaN    futures        None
# 37                  Portfolio            CTZ2017    futures        None
# 13                  Portfolio            BOZ2017    futures        None
# 39                  Portfolio             CZ2017    futures        None
# 5                 LNG18Z17VCS                NaN    options           P
# 2      CCH2018K2018Z2017H2018                NaN    futures        None
# 2    BOF2018H2018Z2017F2018_2                NaN    futures        None
# 9                 delta_sep17                NaN    futures        None
# 2                 CLG18F18VCS                NaN    options           P
# 21                  Portfolio  CLF2018-C-49.5000    options           C
# 3                 LNG18Z17VCS                NaN    futures        None
# ..                        ...                ...        ...         ...
# 1           BZ2018_BF2019_ocs                NaN    futures        None
# 14                  Portfolio             BZ2018    futures        None
# 2    CLH2019M2019Z2018H2019_2                NaN    futures        None
# 34                  Portfolio            CLZ2018    futures        None
# 0                   Portfolio             BF2019    futures        None
# 0           BZ2018_BF2019_ocs                NaN    futures        None
# 45                  Portfolio            EDZ2018    futures        None
# 5          spreadCarrySep17_2                NaN    futures        None
# 2      EDZ2018H2019U2018Z2018                NaN    futures        None
# 1                   Portfolio             BH2019    futures        None
# 0       BH2019J2019J2019K2019                NaN    futures        None
# 0                 B_pca_Sep17                NaN    futures        None
# 0    CLH2019M2019Z2018H2019_2                NaN    futures        None
# 29                  Portfolio            CLH2019    futures        None
# 1                 B_pca_Sep17                NaN    futures        None
# 2                   Portfolio             BJ2019    futures        None
# 1       BH2019J2019J2019K2019                NaN    futures        None
# 0      EDZ2018H2019U2018Z2018                NaN    futures        None
# 40                  Portfolio            EDH2019    futures        None
# 4                   Portfolio             BK2019    futures        None
# 2                 B_pca_Sep17                NaN    futures        None
# 2       BH2019J2019J2019K2019                NaN    futures        None
# 6                   Portfolio             BM2019    futures        None
# 0     BZ2019M2020M2019Z2019_3                NaN    futures        None
# 30                  Portfolio            CLM2019    futures        None
# 1    CLH2019M2019Z2018H2019_2                NaN    futures        None
# 15                  Portfolio             BZ2019    futures        None
# 2     BZ2019M2020M2019Z2019_3                NaN    futures        None
# 7                   Portfolio             BM2020    futures        None
# 1     BZ2019M2020M2019Z2019_3                NaN    futures        None
#
#          qty strike_price   ticker  tr_days_2roll
# 2         -2          NaN  RBX2017             17
# 95     -2.00         None  RBX2017             17
# 0         -5          NaN  EDX2017             26
# 43     -5.00         None  EDX2017             26
# 33     47.00      50.5000  CLZ2017             28
# 5         47         50.5  CLZ2017             28
# 4         47         50.5  CLZ2017             28
# 32     47.00      50.5000  CLZ2017             28
# 7         -5          NaN  FCX2017             28
# 52     -5.00         None  FCX2017             28
# 31     -4.00         None  CLZ2017             31
# 5      -0.07          NaN  CLZ2017             31
# 3      -3.93          NaN  CLZ2017             31
# 105     1.00         None  SIZ2017             34
# 12         1          NaN  SIZ2017             34
# 61    -56.00         None  HOZ2017             37
# 1         -9          NaN  RBZ2017             37
# 97     -9.00         None  RBZ2017             37
# 2        -56          NaN  HOZ2017             37
# 2        -30          NaN  CTZ2017             42
# 37    -30.00         None  CTZ2017             42
# 13   -165.00         None  BOZ2017             47
# 39   -125.00         None   CZ2017             47
# 5        -50           58  LNZ2017             47
# 2        -22          NaN  CCZ2017             47
# 2       -168          NaN  BOZ2017             47
# 9      -0.66          NaN  LNZ2017             47
# 2        -25         49.5  CLF2018             47
# 21    -25.00      49.5000  CLF2018             47
# 3      22.66          NaN  LNZ2017             47
# ..       ...          ...      ...            ...
# 1          1          NaN   BZ2018            271
# 14      1.00         None   BZ2018            271
# 2        -40          NaN  CLZ2018            282
# 34    -40.00         None  CLZ2018            282
# 0      -1.00         None   BF2019            290
# 0         -1          NaN   BF2019            290
# 45    650.00         None  EDZ2018            303
# 5         25          NaN  EDZ2018            303
# 2        625          NaN  EDZ2018            303
# 1      71.00         None   BH2019            333
# 0         61          NaN   BH2019            333
# 0         10          NaN   BH2019            333
# 0         84          NaN  CLH2019            345
# 29     84.00         None  CLH2019            345
# 1        -20          NaN   BJ2019            353
# 2    -144.00         None   BJ2019            353
# 1       -124          NaN   BJ2019            353
# 0       -317          NaN  EDH2019            366
# 40   -317.00         None  EDH2019            366
# 4      73.00         None   BK2019            373
# 2         10          NaN   BK2019            373
# 2         63          NaN   BK2019            373
# 6     -20.00         None   BM2019            396
# 0        -20          NaN   BM2019            396
# 30    -44.00         None  CLM2019            407
# 1        -44          NaN  CLM2019            407
# 15     43.00         None   BZ2019            524
# 2         43          NaN   BZ2019            524
# 7     -23.00         None   BM2020            650
# 1        -23          NaN   BM2020            650
#
# [269 rows x 8 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryOct17_2',strategy_to='spreadCarryDec17_2')

# %%
import shared.calendar_utilities as cu
import ta.strategy as tas
wuhu  = tas.get_net_position_4strategy_alias(alias='spreadCarryDec17',as_of_date=cu.get_doubledate())
#wuhu  = tas.get_net_position_4strategy_alias(alias='LCJ2018_LCM2018_ocs')
wuhu

# sell 1 Z futures after

# W_KW_ifs_2_Aug-2017
# HO FG, 10
# Out:
#      ticker option_type  strike_price instrument  qty
# 0   FCK2018        None           NaN          F   10
# 1   FCQ2018        None           NaN          F  -10
# 2   KWH2019        None           NaN          F   10
# 3   KWZ2018        None           NaN          F  -10
# 4   LCV2018        None           NaN          F   19
# 5   LCZ2018        None           NaN          F  -19
# 6   LNK2018        None           NaN          F   11
# 7   LNM2018        None           NaN          F  -11
# 8   NGV2018        None           NaN          F  -27
# 9   NGX2018        None           NaN          F   27
# 10  RBH2018        None           NaN          F   11
# 11  RBJ2018        None           NaN          F  -11
# 12  SBK2018        None           NaN          F   22
# 13  SBN2018        None           NaN          F  -22
# 14  SMK2018        None           NaN          F  -22
# 15  SMN2018        None           NaN          F   22
# 16   SQ2018        None           NaN          F   -9
# 17   SU2018        None           NaN          F    9

# %%
import ta.position_close_helper as pch

#pch.calc_intrday_pnl_from_prices(alias='GCZ17J18VCS',structure_price=38.6,GCZ2017=1288.9,GCJ2018=1297)
#pch.calc_intrday_pnl_from_prices(alias='BOF18Z17VCS',structure_price=0.23,BOZ2017=32.61,BOF2018=32.78)
pch.calc_intrday_pnl_from_prices(alias='NGJ18H18VCS',structure_price=-0.159,NGH2018=2.741,NGJ2018=2.645)

# sell 3 CLF
# Out:
# {'futures_pnl': 1052.9999999999966,
#  'structure_pnl': 32199.999999999996,
#  'structure_settle': 0.16299999999999995}

# %%
import ta.position_close_helper as pch
pch.calc_intrday_pnl_from_prices(alias='ESH2018_short_scv',structure_price=169.25,ESH2018=2602.25)
# sell 2 WH futures
# Out:
# {'futures_pnl': 170.75, 'structure_pnl': -0.0, 'structure_settle': 169.25}

# %%
0.8125*64
# Out:
# 52.0

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNM2017'],
                                            structure_price = 10.275,
                                            strike_list=[68],
                                            underlying_price_list=[78.025],
                                            qty = -7,
                                            structure_type='straddle')


# sell 2 LNM futures
# Out:
# {'delta_pnl': 185.49394290000703,
#  'structure_pnl': 70.000000000001,
#  'structure_price_yesterday': 10.3,
#  'total_pnl': 255.49394290000802}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['NGH2018','NGJ2018'],
                                            structure_price =-0.156,
                                            strike_list=[3.2,2.95],
                                            underlying_price_list=[2.915,2.759],
                                            qty =10,
                                            structure_type='straddle_spread')

# sell 7 ZSN futures
# Out:
# {'delta_pnl': 690.30482999999037,
#  'structure_pnl': 1300.0000000000039,
#  'structure_price_yesterday': -0.16900000000000004,
#  'total_pnl': 1990.3048299999941}

# %%
import ta.position_close_helper as pch
pch.calc_intraday_structure_pnl_from_prices(ticker_list=['LNV2017','LNZ2017'],
                                            structure_price =-0.6,
                                            strike_list=[71,64],
                                            underlying_price_list=[62.85,58.2],
                                            qty =15,
                                            structure_type='straddle_spread')
# Out:
# {'delta_pnl': 1370.0762159999849,
#  'structure_pnl': -1349.9999999999998,
#  'structure_price_yesterday': -0.375,
#  'total_pnl': 20.076215999985152}
