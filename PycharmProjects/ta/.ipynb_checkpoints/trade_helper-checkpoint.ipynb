# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()

# %%
# Create DB Strategy

import ta.strategy as ts
ts.generate_db_strategy_from_strategy_sheet(id=56,strategy_class='futures_butterfly',report_date=report_date)
# Out:
# 75

# %%
# Create Misc Strategy
import ta.strategy as ts
ts.generate_db_strategy_from_alias(alias='delta',description_string='strategy_class=delta')
# Out:
# 68

# %%
import ta.trade_fill_loader as tfl
import datetime as dt
#wuhu = tfl.assign_trades_2strategies()
#wuhu
tfl.load_tt_trades()
#tfl.load_cme_direct_trades()
#wuhu = tfl.get_formatted_tt_fills()
#wuhu

#tfl.load_latest_tt_fills()
#dt.datetime.strptime(wuhu['Contract'].values[40],'%y-%b')


#tfl.load_cme__fills()

# %%
import ta.trade_fill_loader as tfl
import pandas as pd
formatted_output = tfl.get_formatted_cme_direct_fills()
formatted_output['aggregate_trades']
# Out:
#                          trade_price  trade_quantity  ticker ticker_head  \
# generalized_ticker side
# WN2016             Sell      494.250              -2  WN2016           W
# WU2016             Buy       503.500               2  WU2016           W
# WU2016-C-490.0     Buy        38.250               3  WU2016           W
# WU2016-P-490.0     Buy        28.250               3  WU2016           W
# WZ2016-C-500.0     Sell       48.000              -3  WZ2016           W
# WZ2016-P-500.0     Sell       32.625              -3  WZ2016           W
#
#                         instrument option_type  strike_price real_tradeQ
# generalized_ticker side
# WN2016             Sell          F        None           NaN        True
# WU2016             Buy           F        None           NaN        True
# WU2016-C-490.0     Buy           O           C           490        True
# WU2016-P-490.0     Buy           O           P           490        True
# WZ2016-C-500.0     Sell          O           C           500        True
# WZ2016-P-500.0     Sell          O           P           500        True

# %%
#Daily Hedge

import ta.strategy_hedger as sh
import shared.calendar_utilities as cu
import ta.strategy as tas
sh.strategy_hedge_report()
import ta.strategy as tas

wuhu  = tas.get_net_position_4strategy_alias(alias='Delta',as_of_date=cu.get_doubledate())
wuhu
# Out:
#    ticker option_type strike_price instrument   qty
# 0  WN2016        None         None          F  2.22
# 1  WU2016        None         None          F -1.72

# %%
sh.get_hedge_4strategy(alias='WN16U16VCS')
# Out:
#   underlying_ticker  hedge_price  option_delta  underlying_delta  \
# 0            WN2016      492.375          4.22             -4.22
# 1            WU2016      501.375         -2.72              2.72
#
#     total_delta         hedge
# 0  0.000000e+00 -0.000000e+00
# 1 -4.440892e-16  4.440892e-16

# %%
import ta.strategy_hedger as sh
sh.get_hedge_4strategy(alias='WZ16U16VCS')
# Out:
#   underlying_ticker  underlying_delta             cme_code  bid_price  \
# 0            WU2016     -2.775558e-17  1|G|XCBT:F:W:201609     501.25
# 1            WZ2016     -5.551115e-17  1|G|XCBT:F:W:201612     516.75
#
#    ask_price  hedge_price         hedge
# 0      501.5      501.375  2.775558e-17
# 1      517.0      516.875  5.551115e-17

# %%
import get_price.presave_price as psp
psp.generate_and_update_futures_data_file_4tickerhead(ticker_head='B')

# %%
import ta.pnl as tapnl
alias = 'HON2016Q2016Q2016U2016'
tapnl.close_strategy(alias='WZ16U16VCS')

# %%
import ta.abn_position_reconciler as pr
pr.reconcile_position()
# Out:
#     generalized_ticker  qty_x   qty_y  qty_diff
# 4              BOK2016      0     NaN       NaN
# 5              BON2016      0     NaN       NaN
# 6              BOQ2016      0     NaN       NaN
# 25       WN2016-C-4.65     10     NaN       NaN
# 26       WN2016-P-4.65     10     NaN       NaN
# 28        WU2016-C-4.8    -10     NaN       NaN
# 29        WU2016-P-4.8    -10     NaN       NaN
# 30        WU2016-C-4.9      0     NaN       NaN
# 31        WU2016-P-4.9      0     NaN       NaN
# 33        WZ2016-C-5.0      0     NaN       NaN
# 34        WZ2016-P-5.0      0     NaN       NaN
# 84             KCH2017      0     NaN       NaN
# 85             KCK2017      0     NaN       NaN
# 106     WN2016-C-465.0    NaN   10.00       NaN
# 107     WN2016-P-465.0    NaN   10.00       NaN
# 108     WU2016-C-480.0    NaN  -10.00       NaN
# 109     WU2016-P-480.0    NaN  -10.00       NaN

# %%
import ta.abn_position_reconciler as apr
wuhu = apr.load_and_convert_abn_position_file()

wuhu
# Out:
#     generalized_ticker  qty
# 1              SMV2016   -3
# 2              SMZ2016   -2
# 3              SMH2017   10
# 4              SMN2017   -5
# 5              BOK2016    0
# 6              BON2016    0
# 7              BOQ2016    0
# 8              BOU2016    6
# 9              BOV2016  -12
# 10             BOZ2016    6
# 11             BOF2017   -6
# 12             BOH2017    6
# 13              CU2016   -4
# 14              CH2017   -8
# 15              CK2017   15
# 16              CZ2017   -3
# 17             KWU2016    6
# 18             KWZ2016  -13
# 19             KWH2017    7
# 20              SN2016    1
# 21              SX2016  -16
# 22              SF2017   10
# 23              SH2017   10
# 24              SN2017   -5
# 25              WN2016   -9
# 26       WN2016-C-4.65   10
# 27       WN2016-P-4.65   10
# 28              WU2016    3
# 29        WU2016-C-4.8  -10
# 30        WU2016-P-4.8  -10
# ..                 ...  ...
# 77             CTZ2016   -2
# 78             CTH2017    5
# 79             CTK2017   -3
# 80             CCN2016   -1
# 81             CCU2016   -1
# 82             CCZ2016    2
# 83             KCU2016   -2
# 84             KCZ2016    2
# 85             KCH2017    0
# 86             KCK2017    0
# 87             SBH2017   -2
# 88             SBK2017    2
# 89             SBN2017  -13
# 90             SBV2017   26
# 91             SBH2018  -13
# 92              BQ2016   -7
# 93              BV2016   15
# 94              BX2016   68
# 95              BZ2016 -149
# 96              BF2017   73
# 97              BM2017   20
# 98              BN2017  -20
# 99              BU2017   -3
# 100             BV2017  -23
# 101             BX2017   23
# 102             BZ2017    6
# 103             BH2018   -3
# 104             BM2018   -5
# 105             BZ2018   11
# 106             BM2019   -6
#
# [106 rows x 2 columns]

# %%
import ta.portfolio_manager as tpm
db_position = tpm.get_position_4portfolio(trade_date_to=20160419)
db_position
# Out:
#       ticker      qty
# 0     BF2017    73.00
# 3     BH2018    -3.00
# 7     BM2017    20.00
# 8     BM2018    -5.00
# 9     BM2019    -6.00
# 11    BN2017   -20.00
# 12   BOF2017    -6.00
# 13   BOH2017     6.00
# 17   BOU2016     6.00
# 18   BOV2016   -12.00
# 19   BOZ2016     6.00
# 20    BQ2016    -7.00
# 21    BU2017    -3.00
# 22    BV2016    15.00
# 23    BV2017   -23.00
# 24    BX2016    68.00
# 25    BX2017    23.00
# 26    BZ2016  -149.00
# 27    BZ2017     6.00
# 28    BZ2018    11.00
# 30   CCN2016    -1.00
# 31   CCU2016    -1.00
# 32   CCZ2016     2.00
# 34    CH2017    -8.00
# 36    CK2017    15.00
# 37   CLF2017   -12.00
# 41   CLN2016    -2.00
# 42   CLQ2016     2.00
# 43   CLU2016   -10.00
# 44   CLX2016    22.00
# ..       ...      ...
# 104  NGQ2016   -25.00
# 105  NGU2016    12.00
# 107  NGV2017    -3.00
# 109  NGX2017     6.00
# 111  NGZ2017    -3.00
# 112  RBF2017    -9.00
# 113  RBG2017    15.00
# 114  RBH2017    -7.00
# 119  RBQ2016    -1.00
# 120  RBU2016     1.00
# 123  RBZ2016     1.00
# 124  SBH2017    -2.00
# 125  SBH2018   -13.00
# 126  SBK2017     2.00
# 127  SBN2017   -13.00
# 129  SBV2017    26.00
# 130   SF2017    10.00
# 131   SH2017    10.00
# 133  SMH2017    10.00
# 134  SMN2017    -5.00
# 135  SMV2016    -3.00
# 136  SMZ2016    -2.00
# 137   SN2016     1.00
# 138   SN2017    -5.00
# 141   SX2016   -16.00
# 142   WH2017    -1.00
# 143   WK2017    -3.00
# 144   WN2016    11.00
# 145   WU2016   -17.00
# 146   WZ2016     9.00
#
# [93 rows x 2 columns]

# %%
import ta.portfolio_manager as pm
pm.get_position_4portfolio()
# Out:
#     generalized_ticker      qty
# 0               BF2017    73.00
# 3               BH2018    -3.00
# 7               BM2017    20.00
# 8               BM2018    -5.00
# 9               BM2019    -6.00
# 11              BN2017   -20.00
# 12             BOF2017    -6.00
# 13             BOH2017     6.00
# 17             BOU2016     6.00
# 18             BOV2016   -12.00
# 19             BOZ2016     6.00
# 20              BQ2016    -7.00
# 21              BU2017    -3.00
# 22              BV2016    15.00
# 23              BV2017   -23.00
# 24              BX2016    68.00
# 25              BX2017    23.00
# 26              BZ2016  -149.00
# 27              BZ2017     6.00
# 28              BZ2018    11.00
# 30             CCN2016    -1.00
# 31             CCU2016    -1.00
# 32             CCZ2016     2.00
# 34              CH2017    -8.00
# 36              CK2017    15.00
# 37             CLF2017   -12.00
# 41             CLN2016    -2.00
# 42             CLQ2016     2.00
# 43             CLU2016   -10.00
# 44             CLX2016    22.00
# ..                 ...      ...
# 111            NGZ2017    -3.00
# 112            RBF2017    -9.00
# 113            RBG2017    15.00
# 114            RBH2017    -7.00
# 119            RBQ2016    -1.00
# 120            RBU2016     1.00
# 123            RBZ2016     1.00
# 124            SBH2017    -2.00
# 125            SBH2018   -13.00
# 126            SBK2017     2.00
# 127            SBN2017   -13.00
# 129            SBV2017    26.00
# 130             SF2017    10.00
# 131             SH2017    10.00
# 133            SMH2017    10.00
# 134            SMN2017    -5.00
# 135            SMV2016    -3.00
# 136            SMZ2016    -2.00
# 137             SN2016     1.00
# 138             SN2017    -5.00
# 141             SX2016   -16.00
# 142             WH2017    -1.00
# 143             WK2017    -3.00
# 144             WN2016    -9.00
# 145     WN2016-C-465.0    10.00
# 146     WN2016-P-465.0    10.00
# 147             WU2016     3.00
# 148     WU2016-C-480.0   -10.00
# 150     WU2016-P-480.0   -10.00
# 152             WZ2016     9.00
#
# [97 rows x 2 columns]

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='spreadCarryFeb16',strategy_to='spreadCarryApril16')

# %%
import ta.strategy as ts
ts.move_position_from_strategy_2_strategy(strategy_from='CL-Jan16-Carry',strategy_to='spreadCarryFeb16')
# Out:
# [('CLN2016',
#   None,
#   None,
#   37,
#   37.04,
#   -2,
#   20160222,
#   'F',
#   True,
#   datetime.datetime(2016, 2, 23, 16, 19, 12, 695074),
#   datetime.datetime(2016, 2, 23, 16, 19, 12, 695074)),
#  ('CLQ2016',
#   None,
#   None,
#   37,
#   37.73,
#   2,
#   20160222,
#   'F',
#   True,
#   datetime.datetime(2016, 2, 23, 16, 19, 12, 695074),
#   datetime.datetime(2016, 2, 23, 16, 19, 12, 695074))]

# %%
import ta.strategy as ts
wuhu = ts.get_net_position_4strategy_alias(alias='spreadCarryJan16')
wuhu


[wuhu['ticker'].iloc[x] if wuhu['instrument'].iloc[x]=='F' else
 wuhu['ticker'].iloc[x] + '_' + wuhu['option_type'].iloc[x] + str(wuhu['strike_price'].iloc[x])
 for x in range(len(wuhu.index))]
# Out:
# ['CK2016',
#  'CN2016',
#  'SK2016',
#  'SN2016',
#  'LNG2017',
#  'LNZ2016',
#  'SMV2016',
#  'SMZ2016',
#  'KCK2016',
#  'KCN2016',
#  'FCK2016',
#  'FCQ2016',
#  'BOF2017',
#  'BOZ2016',
#  'KWH2017',
#  'KWZ2016',
#  'CK2016',
#  'CN2016',
#  'NGQ2016',
#  'NGU2016',
#  'FCK2016',
#  'FCQ2016',
#  'SBH2017',
#  'SBV2016',
#  'CH2017',
#  'CZ2016',
#  'CCN2016',
#  'CCU2016',
#  'EDU2017',
#  'EDZ2017',
#  'KCK2016',
#  'KCN2016',
#  'KCU2016',
#  'KCZ2016',
#  'SK2016',
#  'SN2016',
#  'SQ2016',
#  'RBX2016',
#  'RBZ2016',
#  'SBH2017',
#  'SBV2016']

# %%
import ta.strategy as ts
import shared.calendar_utilities as cu
wuhu = ts.get_net_position_4strategy_alias(alias='SBV2017H2018N2017V2017')
wuhu
# Out:
#     ticker option_type strike_price instrument  qty
# 0  SBH2018        None         None          F  -13
# 1  SBN2017        None         None          F  -13
# 2  SBV2017        None         None          F   26
