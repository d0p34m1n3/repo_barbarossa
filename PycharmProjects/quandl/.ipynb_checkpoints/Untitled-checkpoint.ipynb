# %%
import signals.futures_signals as fs
import signals.utils as su
signals_output = fs.get_futures_butterfly_signals(ticker_list=['LNJ2016','LNN2016','LNV2016'],date_to=20160217)

price_ratio = signals_output['price_ratio']
price_ratio

# %%
import opportunity_constructs.utilities as ocu
aligned_output = ocu.get_aligned_futures_data(contract_list=['NGU2016','NGX2016','NGF2017'],aggregation_method=12,contracts_back=10,date_to=20160218)
#aligned_output = ocu.get_aligned_futures_data(contract_list=['HOV2007','HOX2007'],aggregation_method=12,contracts_back=10,date_to=20070420)
aligned_data = aligned_output['aligned_data']
bf_price = aligned_data['c1']['close_price']+aligned_data['c3']['close_price']-2*aligned_data['c2']['close_price']
#bf_price = aligned_data['c1']['close_price']-aligned_data['c2']['close_price']
#bf_price_recent = bf_price[1:]
#aligned_data_recent = aligned_data[1:]
import matplotlib.pyplot as plt
plt.plot(bf_price)
plt.grid()         
         
plt.show()

# %%
aligned_data[bf_price<0.1]
# Out:
#                   c1                                                      \
#               ticker ticker_head ticker_month ticker_year cal_dte tr_dte
# settle_date
# 2006-12-06   NGU2007          NG            9        2007     266    183
# 2006-12-08   NGU2007          NG            9        2007     264    181
# 2006-12-12   NGU2007          NG            9        2007     260    179
# 2006-12-27   NGU2007          NG            9        2007     245    169
# 2006-12-29   NGU2007          NG            9        2007     243    167
# 2007-01-04   NGU2007          NG            9        2007     237    164
# 2007-01-24   NGU2007          NG            9        2007     217    151
# 2007-02-27   NGU2007          NG            9        2007     183    128
# 2009-12-03   NGU2010          NG            9        2010     267    184
# 2009-12-04   NGU2010          NG            9        2010     266    183
# 2009-12-07   NGU2010          NG            9        2010     263    182
# 2009-12-08   NGU2010          NG            9        2010     262    181
# 2009-12-09   NGU2010          NG            9        2010     261    180
# 2009-12-10   NGU2010          NG            9        2010     260    179
# 2009-12-11   NGU2010          NG            9        2010     259    178
# 2009-12-14   NGU2010          NG            9        2010     256    177
#
#                                                      ...            c3  \
#             close_price volume cont_indx change1     ...     cont_indx
# settle_date                                          ...
# 2006-12-06        7.893    201    200709   0.027     ...        200801
# 2006-12-08        7.996     92    200709  -0.060     ...        200801
# 2006-12-12        7.790    106    200709   0.075     ...        200801
# 2006-12-27        6.918      0    200709   0.048     ...        200801
# 2006-12-29        7.018    245    200709  -0.092     ...        200801
# 2007-01-04        7.039    188    200709   0.133     ...        200801
# 2007-01-24        7.554    330    200709   0.066     ...        200801
# 2007-02-27        7.890    416    200709   0.090     ...        200801
# 2009-12-03        5.016   5143    201009   0.344     ...        201101
# 2009-12-04        5.128   6947    201009   0.073     ...        201101
# 2009-12-07        5.472   1632    201009  -0.165     ...        201101
# 2009-12-08        5.545   1434    201009   0.331     ...        201101
# 2009-12-09        5.380   3213    201009  -0.104     ...        201101
# 2009-12-10        5.711   1804    201009   0.150     ...        201101
# 2009-12-11        5.607   2091    201009   0.116     ...        201101
# 2009-12-14        5.757   1347    201009  -0.073     ...        201101
#
#                                                                          \
#             change1 change2 change5 change10 change20 change_5 change_1
# settle_date
# 2006-12-06    0.016  -0.087   0.031   -0.309   -0.629      NaN    0.149
# 2006-12-08    0.098   0.120  -0.142   -0.622   -0.347   -0.195    0.016
# 2006-12-12   -0.002  -0.118  -0.347   -0.802   -0.600    0.239    0.098
# 2006-12-27    0.168   0.053   0.037    0.202    0.252   -0.507   -0.095
# 2006-12-29    0.014  -0.018   0.212      NaN    0.518   -0.292    0.168
# 2007-01-04    0.103   0.228   0.165    0.353    0.503    0.070   -0.032
# 2007-01-24    0.246   0.182   0.480    0.784    0.828      NaN   -0.170
# 2007-02-27    0.024   0.009   0.125    0.005    0.470   -0.118   -0.176
# 2009-12-03    0.314   0.345   0.349    0.543      NaN   -0.545   -0.093
# 2009-12-04    0.031  -0.126   0.158    0.132    0.252   -0.440    0.107
# 2009-12-07   -0.157   0.082   0.198    0.122    0.130    0.080    0.314
# 2009-12-08    0.239   0.161   0.282    0.343    0.275    0.178    0.031
# 2009-12-09   -0.078   0.045   0.132    0.053   -0.136    0.202   -0.157
# 2009-12-10    0.123   0.194   0.194    0.270    0.009    0.534    0.239
# 2009-12-11    0.071  -0.002  -0.026    0.046    0.000    0.349   -0.078
# 2009-12-14   -0.073   0.016  -0.076   -0.104   -0.151    0.158    0.123
#
#             tr_dte_match settle_date
#
# settle_date
# 2006-12-06            49  2006-12-06
# 2006-12-08            47  2006-12-08
# 2006-12-12            45  2006-12-12
# 2006-12-27            35  2006-12-27
# 2006-12-29            33  2006-12-29
# 2007-01-04            30  2007-01-04
# 2007-01-24            17  2007-01-24
# 2007-02-27             6  2007-02-27
# 2009-12-03            50  2009-12-03
# 2009-12-04            49  2009-12-04
# 2009-12-07            48  2009-12-07
# 2009-12-08            47  2009-12-08
# 2009-12-09            46  2009-12-09
# 2009-12-10            45  2009-12-10
# 2009-12-11            44  2009-12-11
# 2009-12-14            43  2009-12-14
#
# [16 rows x 50 columns]

# %%
import opportunity_constructs.spread_carry as sc

#spread_carry_output = sc.generate_spread_carry_sheet_4date(report_date=20160218)
#spread_report = spread_carry_output['spread_report']
#ticker_head_list = list(spread_report['tickerHead'].unique())
# Compare BO and S sizing

spread_report[spread_report['tickerHead']==ticker_head_list[19]]
#spread_report[spread_report['tickerHead']=='S']
# Out:
#     ticker1  ticker2 tickerHead  front_tr_dte  carry  q_carry  reward_risk  \
# 0   EDH2016  EDJ2016         ED            17    NaN      NaN          NaN
# 1   EDJ2016  EDK2016         ED            41  -6.25       -5        -0.03
# 2   EDK2016  EDM2016         ED            61   0.00        3         0.00
# 3   EDM2016  EDN2016         ED            80  25.00       19         0.09
# 4   EDN2016  EDU2016         ED           104 -62.50      -11        -0.15
# 5   EDU2016  EDZ2016         ED           148 -37.50        9        -0.07
# 6   EDZ2016  EDH2017         ED           212  25.00        7         0.02
# 7   EDH2017  EDM2017         ED           270 -37.50        0        -0.05
# 8   EDM2017  EDU2017         ED           338 -12.50        5        -0.02
# 9   EDU2017  EDZ2017         ED           401 -37.50        1        -0.05
# 10  EDZ2017  EDH2018         ED           465  12.50        7         0.01
# 11  EDH2018  EDM2018         ED           528 -25.00        2        -0.03
#
#      price   q  upside  downside  change5  change10  change20
# 0   0.0125  51   34.38    -35.81      NaN       NaN       NaN
# 1   0.0150  56   37.50    -37.50      NaN       NaN       NaN
# 2   0.0150  53   31.25    -37.50      NaN       NaN       NaN
# 3   0.0050  34   31.25    -71.25      NaN       NaN       NaN
# 4   0.0300  45   88.75    -53.44      NaN       NaN       NaN
# 5   0.0450  36   59.06    -84.06      NaN       NaN       NaN
# 6   0.0350  29   71.62    -87.50      NaN       NaN       NaN
# 7   0.0500  29   62.50    -87.50      NaN       NaN       NaN
# 8   0.0550  24   56.25    -81.25      NaN       NaN       NaN
# 9   0.0700  23   59.06    -75.00      NaN       NaN       NaN
# 10  0.0650  16   62.50    -71.56      NaN       NaN       NaN
# 11  0.0750  14   59.06    -65.31      NaN       NaN       NaN

# %%
import read_exchange_files.process_cme_futures as pcf
import datetime as dt
wuhu = pcf.process_cme_futures_4tickerhead(ticker_head='ED',report_date=20160218)

wuhu['settle_frame']
# Out:
#     ticker_year  ticker_month   ticker   settle    open     high     low  \
# 0          2016             3  EDH2016  99.3575  99.355  99.3625  99.355
# 1          2016             4  EDJ2016  99.3450  99.340  99.3500  99.335
# 2          2016             5  EDK2016  99.3300  99.320  99.3300  99.320
# 3          2016             6  EDM2016  99.3150  99.315  99.3300  99.300
# 4          2016             7  EDN2016  99.3100   0.000  99.3100     NaN
# 5          2016             8  EDQ2016  99.3000   0.000  99.3050     NaN
# 6          2016             9  EDU2016  99.2800  99.275  99.2950  99.255
# 7          2016            12  EDZ2016  99.2350  99.220  99.2550  99.200
# 8          2017             3  EDH2017  99.2000   0.000  99.2200  99.155
# 9          2017             6  EDM2017  99.1500  99.120  99.1700  99.095
# 10         2017             9  EDU2017  99.0950   0.000  99.1200  99.030
# 11         2017            12  EDZ2017  99.0250   0.000  99.0500  98.945
# 12         2018             3  EDH2018  98.9600   0.000  98.9850  98.875
# 13         2018             6  EDM2018  98.8850  98.825  98.9150  98.795
# 14         2018             9  EDU2018  98.8100  98.745  98.8400  98.715
# 15         2018            12  EDZ2018  98.7250  98.660  98.7550  98.625
# 16         2019             3  EDH2019  98.6550  98.585  98.6850  98.555
# 17         2019             6  EDM2019  98.5750  98.510  98.6100  98.480
# 18         2019             9  EDU2019  98.5000  98.435  98.5300  98.400
# 19         2019            12  EDZ2019  98.4150  98.350  98.4500  98.320
# 20         2020             3  EDH2020  98.3450  98.280  98.3800  98.250
# 21         2020             6  EDM2020  98.2700  98.205  98.3050  98.175
# 22         2020             9  EDU2020  98.2000  98.140  98.2350  98.105
# 23         2020            12  EDZ2020  98.1300  98.070  98.1650  98.035
# 24         2021             3  EDH2021  98.0700  98.035  98.1050  97.980
# 25         2021             6  EDM2021  98.0100  97.960  98.0450  97.920
# 26         2021             9  EDU2021  97.9550  97.895  97.9950  97.865
# 27         2021            12  EDZ2021  97.9000  97.870  97.9400  97.815
# 28         2022             3  EDH2022  97.8600   0.000  97.8850  97.780
# 29         2022             6  EDM2022  97.8200  97.785  97.8450  97.745
# 30         2022             9  EDU2022  97.7800  97.705  97.8050  97.700
# 31         2022            12  EDZ2022  97.7450  97.690  97.7700  97.670
# 32         2023             3  EDH2023  97.7150  97.660  97.7400  97.645
# 33         2023             6  EDM2023  97.6850   0.000  97.7100  97.620
# 34         2023             9  EDU2023  97.6600  97.595  97.6750  97.575
# 35         2023            12  EDZ2023  97.6350   0.000  97.6550  97.575
# 36         2024             3  EDH2024  97.6200   0.000  97.6350  97.560
# 37         2024             6  EDM2024  97.6000   0.000  97.6200     NaN
# 38         2024             9  EDU2024  97.5800   0.000  97.5950  97.520
# 39         2024            12  EDZ2024  97.5600   0.000  97.5800     NaN
# 40         2025             3  EDH2025  97.5500   0.000  97.5600     NaN
# 41         2025             6  EDM2025  97.5350   0.000  97.5500     NaN
# 42         2025             9  EDU2025  97.5200   0.000  97.5250     NaN
# 43         2025            12  EDZ2025  97.5000   0.000  97.5100     NaN
#
#     volume  interest
# 0   144450   1027652
# 1     9687     67499
# 2        1       478
# 3   206939   1292199
# 4        0       252
# 5        0         0
# 6   215460   1164776
# 7   215403   1261671
# 8   181093    973912
# 9   171903    710001
# 10  127994    665839
# 11  164336    716332
# 12  103484    489842
# 13   85170    420313
# 14   64528    343124
# 15   74902    398641
# 16   41168    276795
# 17   34045    208607
# 18   28984    151928
# 19   27956    121128
# 20   17832     82565
# 21   19225     61996
# 22   13233     56817
# 23   11882     52571
# 24    1478     29070
# 25    1233     23407
# 26     756     15908
# 27     879      8562
# 28       7      4163
# 29     132      4851
# 30      10      4903
# 31      54      1933
# 32       7      2132
# 33       0       791
# 34      10       974
# 35       0       932
# 36       0       982
# 37       0       979
# 38       0       802
# 39       0       740
# 40       0       268
# 41       0       246
# 42       0        75
# 43       0        75

# %%
import my_sql_routines.futures_price_loader as fpl
import pandas as pd
wuhu = fpl.update_futures_price_database_from_cme_file()

contract_list = wuhu['contract_list']
settle_frame = wuhu['settle_frame']


contract_frame = pd.DataFrame(contract_list,columns=['symbol_id','ticker','expiration_date'])

contract_frame

settle_frame

pd.merge(contract_frame,settle_frame,how='inner',on='ticker')
# Out:
#     symbol_id   ticker expiration_date  ticker_year  ticker_month   settle  \
# 0       19010  EDH2016      2016-03-14         2016             3  99.3575
# 1       19011  EDH2017      2017-03-13         2017             3  99.2000
# 2       19012  EDH2018      2018-03-19         2018             3  98.9600
# 3       19013  EDH2019      2019-03-18         2019             3  98.6550
# 4       19139  EDJ2016      2016-04-18         2016             4  99.3450
# 5       19268  EDK2016      2016-05-16         2016             5  99.3300
# 6       19397  EDM2016      2016-06-13         2016             6  99.3150
# 7       19398  EDM2017      2017-06-19         2017             6  99.1500
# 8       19399  EDM2018      2018-06-18         2018             6  98.8850
# 9       19400  EDM2019      2019-06-17         2019             6  98.5750
# 10      19526  EDN2016      2016-07-18         2016             7  99.3100
# 11      19655  EDQ2016      2016-08-15         2016             8  99.3000
# 12      19784  EDU2016      2016-09-19         2016             9  99.2800
# 13      19785  EDU2017      2017-09-18         2017             9  99.0950
# 14      19786  EDU2018      2018-09-17         2018             9  98.8100
# 15      19787  EDU2019      2019-09-16         2019             9  98.5000
# 16      20171  EDZ2016      2016-12-19         2016            12  99.2350
# 17      20172  EDZ2017      2017-12-18         2017            12  99.0250
# 18      20173  EDZ2018      2018-12-17         2018            12  98.7250
# 19      20174  EDZ2019      2019-12-16         2019            12  98.4150
#
#       open     high     low  volume  interest
# 0   99.355  99.3625  99.355  144450   1027652
# 1    0.000  99.2200  99.155  181093    973912
# 2    0.000  98.9850  98.875  103484    489842
# 3   98.585  98.6850  98.555   41168    276795
# 4   99.340  99.3500  99.335    9687     67499
# 5   99.320  99.3300  99.320       1       478
# 6   99.315  99.3300  99.300  206939   1292199
# 7   99.120  99.1700  99.095  171903    710001
# 8   98.825  98.9150  98.795   85170    420313
# 9   98.510  98.6100  98.480   34045    208607
# 10   0.000  99.3100     NaN       0       252
# 11   0.000  99.3050     NaN       0         0
# 12  99.275  99.2950  99.255  215460   1164776
# 13   0.000  99.1200  99.030  127994    665839
# 14  98.745  98.8400  98.715   64528    343124
# 15  98.435  98.5300  98.400   28984    151928
# 16  99.220  99.2550  99.200  215403   1261671
# 17   0.000  99.0500  98.945  164336    716332
# 18  98.660  98.7550  98.625   74902    398641
# 19  98.350  98.4500  98.320   27956    121128

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-db64b223da98> in <module>()
# ----> 1 matchObj.group(3)
#
# IndexError: no such group

# %%
import contract_utilities.expiration as exp
wuhu = exp.get_options_expiration('GCQ2016')
bu_dts = wuhu['bu_dts']
dts = wuhu['dts']

bu_dts = bu_dts[bu_dts<dts[-1]]
bu_dts[-4]

dts = dts[bu_dts[-4]<dts]

dts[0] in bu_dts
# Out:
# True

# %%
import contract_utilities.expiration as exp
exp.get_options_expiration('GCZ2016')

# GCZ2016: I am calculating 23 Nov it should be 22 Nov
# Out:
# {'bu_dts': DatetimeIndex(['2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                 '2016-11-07', '2016-11-08', '2016-11-09', '2016-11-10',
#                 '2016-11-11', '2016-11-14', '2016-11-15', '2016-11-16',
#                 '2016-11-17', '2016-11-18', '2016-11-21', '2016-11-22',
#                 '2016-11-23', '2016-11-25', '2016-11-28', '2016-11-29',
#                 '2016-11-30'],
#                dtype='datetime64[ns]', freq='C', tz=None),
#  'dts': DatetimeIndex(['2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                 '2016-11-05', '2016-11-06', '2016-11-07', '2016-11-08',
#                 '2016-11-09', '2016-11-10', '2016-11-11', '2016-11-12',
#                 '2016-11-13', '2016-11-14', '2016-11-15', '2016-11-16',
#                 '2016-11-17', '2016-11-18', '2016-11-19', '2016-11-20',
#                 '2016-11-21', '2016-11-22', '2016-11-23', '2016-11-24',
#                 '2016-11-25', '2016-11-26', '2016-11-27', '2016-11-28',
#                 '2016-11-29', '2016-11-30'],
#                dtype='datetime64[ns]', freq='D', tz=None)}

# %%
import contract_utilities.contract_lists as cl
cl.get_option_contract_list_4year_range(start_year=2016,end_year=2017)
# Out:
# [('LNG2016',
#   'LN',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 12, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LNJ2016',
#   'LN',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 14, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LNK2016',
#   'LN',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 13, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LNM2016',
#   'LN',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 14, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LNN2016',
#   'LN',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 15, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LNQ2016',
#   'LN',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 12, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LNV2016',
#   'LN',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 14, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LNZ2016',
#   'LN',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 14, 0, 0),
#   'options',
#   'Lean Hog',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCF2016',
#   'LC',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 8, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCG2016',
#   'LC',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 5, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCH2016',
#   'LC',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 4, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCJ2016',
#   'LC',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 1, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCK2016',
#   'LC',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 6, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCM2016',
#   'LC',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 3, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCN2016',
#   'LC',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 1, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCQ2016',
#   'LC',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 5, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCU2016',
#   'LC',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 2, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCV2016',
#   'LC',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 7, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCX2016',
#   'LC',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 4, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('LCZ2016',
#   'LC',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 2, 0, 0),
#   'options',
#   'Live Cattle',
#   'Livestock',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESF2016',
#   'ES',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 15, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESG2016',
#   'ES',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESH2016',
#   'ES',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 18, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESJ2016',
#   'ES',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 15, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESK2016',
#   'ES',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESM2016',
#   'ES',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 17, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESN2016',
#   'ES',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 15, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESQ2016',
#   'ES',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 19, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESU2016',
#   'ES',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 16, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESV2016',
#   'ES',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESX2016',
#   'ES',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 18, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ESZ2016',
#   'ES',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 16, 0, 0),
#   'options',
#   'E-mini S&P 500',
#   'Index',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECF2016',
#   'EC',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 8, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECG2016',
#   'EC',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 5, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECH2016',
#   'EC',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 4, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECJ2016',
#   'EC',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 8, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECK2016',
#   'EC',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 6, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECM2016',
#   'EC',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 3, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECN2016',
#   'EC',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 8, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECQ2016',
#   'EC',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 5, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECU2016',
#   'EC',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 9, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECV2016',
#   'EC',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 7, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECX2016',
#   'EC',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 4, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ECZ2016',
#   'EC',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 9, 0, 0),
#   'options',
#   'Euro FX',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYF2016',
#   'JY',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 8, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYG2016',
#   'JY',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 5, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYH2016',
#   'JY',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 4, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYJ2016',
#   'JY',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 8, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYK2016',
#   'JY',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 6, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYM2016',
#   'JY',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 3, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYN2016',
#   'JY',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 8, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYQ2016',
#   'JY',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 5, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYU2016',
#   'JY',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 9, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYV2016',
#   'JY',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 7, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYX2016',
#   'JY',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 4, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('JYZ2016',
#   'JY',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 9, 0, 0),
#   'options',
#   'Japanese Yen',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADF2016',
#   'AD',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 8, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADG2016',
#   'AD',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 5, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADH2016',
#   'AD',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 4, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADJ2016',
#   'AD',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 8, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADK2016',
#   'AD',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 6, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADM2016',
#   'AD',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 3, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADN2016',
#   'AD',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 8, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADQ2016',
#   'AD',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 5, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADU2016',
#   'AD',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 9, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADV2016',
#   'AD',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 7, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADX2016',
#   'AD',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 4, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('ADZ2016',
#   'AD',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 9, 0, 0),
#   'options',
#   'Australian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDF2016',
#   'CD',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 8, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDG2016',
#   'CD',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 5, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDH2016',
#   'CD',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 4, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDJ2016',
#   'CD',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 8, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDK2016',
#   'CD',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 6, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDM2016',
#   'CD',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 3, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDN2016',
#   'CD',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 8, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDQ2016',
#   'CD',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 5, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDU2016',
#   'CD',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 9, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDV2016',
#   'CD',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 7, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDX2016',
#   'CD',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 4, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CDZ2016',
#   'CD',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 9, 0, 0),
#   'options',
#   'Canadian Dollar',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPF2016',
#   'BP',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 8, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPG2016',
#   'BP',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 5, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPH2016',
#   'BP',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 4, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPJ2016',
#   'BP',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 8, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPK2016',
#   'BP',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 6, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPM2016',
#   'BP',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 3, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPN2016',
#   'BP',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 8, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPQ2016',
#   'BP',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 5, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPU2016',
#   'BP',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 9, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPV2016',
#   'BP',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 7, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPX2016',
#   'BP',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 4, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BPZ2016',
#   'BP',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 9, 0, 0),
#   'options',
#   'British Pound',
#   'FX',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCF2016',
#   'GC',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 28, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCG2016',
#   'GC',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 26, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCH2016',
#   'GC',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 24, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCJ2016',
#   'GC',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 28, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCK2016',
#   'GC',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 26, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCM2016',
#   'GC',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 25, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCN2016',
#   'GC',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 27, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCQ2016',
#   'GC',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 26, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCU2016',
#   'GC',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 25, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCV2016',
#   'GC',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 27, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCX2016',
#   'GC',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 26, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('GCZ2016',
#   'GC',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 22, 0, 0),
#   'options',
#   'Gold',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIF2016',
#   'SI',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 28, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIG2016',
#   'SI',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 26, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIH2016',
#   'SI',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 24, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIJ2016',
#   'SI',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 28, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIK2016',
#   'SI',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 26, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIM2016',
#   'SI',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 25, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIN2016',
#   'SI',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 27, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIQ2016',
#   'SI',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 26, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIU2016',
#   'SI',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 25, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIV2016',
#   'SI',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 27, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIX2016',
#   'SI',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 26, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SIZ2016',
#   'SI',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 22, 0, 0),
#   'options',
#   'Silver',
#   'Metal',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYF2016',
#   'TY',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYG2016',
#   'TY',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYH2016',
#   'TY',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYJ2016',
#   'TY',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYK2016',
#   'TY',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYM2016',
#   'TY',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYN2016',
#   'TY',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYQ2016',
#   'TY',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYU2016',
#   'TY',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 26, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYV2016',
#   'TY',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 23, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYX2016',
#   'TY',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TYZ2016',
#   'TY',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 25, 0, 0),
#   'options',
#   '10-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USF2016',
#   'US',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USG2016',
#   'US',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USH2016',
#   'US',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USJ2016',
#   'US',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USK2016',
#   'US',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USM2016',
#   'US',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USN2016',
#   'US',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USQ2016',
#   'US',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USU2016',
#   'US',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 26, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USV2016',
#   'US',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 23, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USX2016',
#   'US',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('USZ2016',
#   'US',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 25, 0, 0),
#   'options',
#   'US Treasury Bond',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVF2016',
#   'FV',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVG2016',
#   'FV',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVH2016',
#   'FV',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVJ2016',
#   'FV',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVK2016',
#   'FV',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVM2016',
#   'FV',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVN2016',
#   'FV',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVQ2016',
#   'FV',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVU2016',
#   'FV',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 26, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVV2016',
#   'FV',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 23, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVX2016',
#   'FV',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('FVZ2016',
#   'FV',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 25, 0, 0),
#   'options',
#   '5-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUF2016',
#   'TU',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUG2016',
#   'TU',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUH2016',
#   'TU',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUJ2016',
#   'TU',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUK2016',
#   'TU',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUM2016',
#   'TU',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUN2016',
#   'TU',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUQ2016',
#   'TU',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUU2016',
#   'TU',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 26, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUV2016',
#   'TU',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 23, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUX2016',
#   'TU',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('TUZ2016',
#   'TU',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 25, 0, 0),
#   'options',
#   '2-Year T-Note',
#   'Treasury',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CF2016',
#   'C',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CG2016',
#   'C',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CH2016',
#   'C',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CJ2016',
#   'C',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CK2016',
#   'C',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CM2016',
#   'C',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CN2016',
#   'C',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CQ2016',
#   'C',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CU2016',
#   'C',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 26, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CV2016',
#   'C',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 23, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CX2016',
#   'C',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('CZ2016',
#   'C',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 25, 0, 0),
#   'options',
#   'Corn',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SF2016',
#   'S',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SG2016',
#   'S',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SH2016',
#   'S',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SJ2016',
#   'S',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SK2016',
#   'S',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SM2016',
#   'S',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SN2016',
#   'S',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SQ2016',
#   'S',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SU2016',
#   'S',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 26, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SV2016',
#   'S',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 23, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SX2016',
#   'S',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SZ2016',
#   'S',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 25, 0, 0),
#   'options',
#   'Soybean',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMF2016',
#   'SM',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMG2016',
#   'SM',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMH2016',
#   'SM',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMJ2016',
#   'SM',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMK2016',
#   'SM',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMM2016',
#   'SM',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMN2016',
#   'SM',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMQ2016',
#   'SM',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMU2016',
#   'SM',
#   2016,
#   9,
#   datetime.datetime(2016, 8, 26, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMV2016',
#   'SM',
#   2016,
#   10,
#   datetime.datetime(2016, 9, 23, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMX2016',
#   'SM',
#   2016,
#   11,
#   datetime.datetime(2016, 10, 21, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('SMZ2016',
#   'SM',
#   2016,
#   12,
#   datetime.datetime(2016, 11, 25, 0, 0),
#   'options',
#   'Soybean Meal',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOF2016',
#   'BO',
#   2016,
#   1,
#   datetime.datetime(2015, 12, 24, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOG2016',
#   'BO',
#   2016,
#   2,
#   datetime.datetime(2016, 1, 22, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOH2016',
#   'BO',
#   2016,
#   3,
#   datetime.datetime(2016, 2, 19, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOJ2016',
#   'BO',
#   2016,
#   4,
#   datetime.datetime(2016, 3, 24, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOK2016',
#   'BO',
#   2016,
#   5,
#   datetime.datetime(2016, 4, 22, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOM2016',
#   'BO',
#   2016,
#   6,
#   datetime.datetime(2016, 5, 20, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BON2016',
#   'BO',
#   2016,
#   7,
#   datetime.datetime(2016, 6, 24, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOQ2016',
#   'BO',
#   2016,
#   8,
#   datetime.datetime(2016, 7, 22, 0, 0),
#   'options',
#   'Soybean Oil',
#   'Ag',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('BOU2016',
#   'BO',
#   2016,
#   9,
# ...
#  ('EDV2016',
#   'ED',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 14, 0, 0),
#   'options',
#   'Eurodollar',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('EDX2016',
#   'ED',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 11, 0, 0),
#   'options',
#   'Eurodollar',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('EDZ2016',
#   'ED',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 19, 0, 0),
#   'options',
#   'Eurodollar',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0F2016',
#   'E0',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 15, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0G2016',
#   'E0',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 12, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0H2016',
#   'E0',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 11, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0J2016',
#   'E0',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 15, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0K2016',
#   'E0',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 13, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0M2016',
#   'E0',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 10, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0N2016',
#   'E0',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 15, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0Q2016',
#   'E0',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 12, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0U2016',
#   'E0',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 16, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0V2016',
#   'E0',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 14, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0X2016',
#   'E0',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 11, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E0Z2016',
#   'E0',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 16, 0, 0),
#   'options',
#   'Eurodollar 1 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2F2016',
#   'E2',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 15, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2G2016',
#   'E2',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 12, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2H2016',
#   'E2',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 11, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2J2016',
#   'E2',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 15, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2K2016',
#   'E2',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 13, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2M2016',
#   'E2',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 10, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2N2016',
#   'E2',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 15, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2Q2016',
#   'E2',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 12, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2U2016',
#   'E2',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 16, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2V2016',
#   'E2',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 14, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2X2016',
#   'E2',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 11, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E2Z2016',
#   'E2',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 16, 0, 0),
#   'options',
#   'Eurodollar 2 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3F2016',
#   'E3',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 15, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3G2016',
#   'E3',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 12, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3H2016',
#   'E3',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 11, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3J2016',
#   'E3',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 15, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3K2016',
#   'E3',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 13, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3M2016',
#   'E3',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 10, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3N2016',
#   'E3',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 15, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3Q2016',
#   'E3',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 12, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3U2016',
#   'E3',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 16, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3V2016',
#   'E3',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 14, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3X2016',
#   'E3',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 11, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E3Z2016',
#   'E3',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 16, 0, 0),
#   'options',
#   'Eurodollar 3 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4F2016',
#   'E4',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 15, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4G2016',
#   'E4',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 12, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4H2016',
#   'E4',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 11, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4J2016',
#   'E4',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 15, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4K2016',
#   'E4',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 13, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4M2016',
#   'E4',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 10, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4N2016',
#   'E4',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 15, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4Q2016',
#   'E4',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 12, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4U2016',
#   'E4',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 16, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4V2016',
#   'E4',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 14, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4X2016',
#   'E4',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 11, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E4Z2016',
#   'E4',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 16, 0, 0),
#   'options',
#   'Eurodollar 4 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5F2016',
#   'E5',
#   2016,
#   1,
#   datetime.datetime(2016, 1, 15, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5G2016',
#   'E5',
#   2016,
#   2,
#   datetime.datetime(2016, 2, 12, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5H2016',
#   'E5',
#   2016,
#   3,
#   datetime.datetime(2016, 3, 11, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5J2016',
#   'E5',
#   2016,
#   4,
#   datetime.datetime(2016, 4, 15, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5K2016',
#   'E5',
#   2016,
#   5,
#   datetime.datetime(2016, 5, 13, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5M2016',
#   'E5',
#   2016,
#   6,
#   datetime.datetime(2016, 6, 10, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5N2016',
#   'E5',
#   2016,
#   7,
#   datetime.datetime(2016, 7, 15, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5Q2016',
#   'E5',
#   2016,
#   8,
#   datetime.datetime(2016, 8, 12, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5U2016',
#   'E5',
#   2016,
#   9,
#   datetime.datetime(2016, 9, 16, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5V2016',
#   'E5',
#   2016,
#   10,
#   datetime.datetime(2016, 10, 14, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5X2016',
#   'E5',
#   2016,
#   11,
#   datetime.datetime(2016, 11, 11, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817)),
#  ('E5Z2016',
#   'E5',
#   2016,
#   12,
#   datetime.datetime(2016, 12, 16, 0, 0),
#   'options',
#   'Eurodollar 5 Year Mid-Curve Options',
#   'STIR',
#   'USD',
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817),
#   datetime.datetime(2016, 2, 17, 20, 3, 34, 881817))]

# %%
import contract_utilities.contract_lists as cl
cl.get_db_contract_list_filtered(ticker_head='LN',ticker_year_from=2016,ticker_year_to=2017,instrument='futures')
# Out:
# [(47, 'LNG2016', datetime.date(2016, 2, 12)),
#  (48, 'LNG2017', datetime.date(2017, 2, 14)),
#  (176, 'LNJ2016', datetime.date(2016, 4, 14)),
#  (177, 'LNJ2017', datetime.date(2017, 4, 17)),
#  (305, 'LNK2016', datetime.date(2016, 5, 13)),
#  (306, 'LNK2017', datetime.date(2017, 5, 12)),
#  (434, 'LNM2016', datetime.date(2016, 6, 14)),
#  (435, 'LNM2017', datetime.date(2017, 6, 14)),
#  (563, 'LNN2016', datetime.date(2016, 7, 15)),
#  (564, 'LNN2017', datetime.date(2017, 7, 17)),
#  (692, 'LNQ2016', datetime.date(2016, 8, 12)),
#  (693, 'LNQ2017', datetime.date(2017, 8, 14)),
#  (821, 'LNV2016', datetime.date(2016, 10, 14)),
#  (822, 'LNV2017', datetime.date(2017, 10, 13)),
#  (950, 'LNZ2016', datetime.date(2016, 12, 14)),
#  (951, 'LNZ2017', datetime.date(2017, 12, 14))]

# %%
import contract_utilities.expiration_test


# april 30 is a saturday
# Out:
# TEST PASSED!

# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()
import futures_charts.futures_curve as fc
bf_signals_output = fc.get_butterfly_scatter_plot(report_date=report_date,id=195)

# %%
aligned_output = bf_signals_output['aligned_output']
aligned_data = aligned_output['aligned_data']
bf_price = aligned_data['c1']['close_price']+aligned_data['c3']['close_price']-2*aligned_data['c2']['close_price']

# %%
import matplotlib.pyplot as plt
plt.plot(bf_price)
plt.grid()         
         
plt.show()

# %%
bad_data = aligned_data[bf_price<-0.004]   #<-0.03
bad_data

# HOV2007,HOX2007, HOZ2007 20070213 to 20070413

# %%
aligned_data.iloc[1047]

# %%
import shared.directory_names as dn
options_data_dir = dn.get_dated_directory_extension(folder_date=20160208,ext='comex_options_csv_address')
options_data_dir

# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()
report_date

# %%
import scheduled_jobs.options_data_load_job as odlj
import shared.downloads as sd
sd.download_csv_from_web(web_address=odlj.comex_options_csv_address)

# %%
import scheduled_jobs.options_data_load_job

# %%
with open(r'C:\Research\data\options_data_raw\2016\201602\20160208\interest_rate.pkl','rb') as handle:
    wuhu = pickle.load(handle)

# %%
scatter_matrix = np.zeros((3,3))

for i in range(all_samples.shape[1]):
    scatter_matrix +=(all_samples[:,i].reshape(3,1)).dot(
    (all_samples[:,i].reshape(3,1)-mean_vector).T)
print('Scatter Matrix\n',scatter_matrix)

# %%
cov_mat = np.cov([all_samples[0,:], all_samples[1,:],all_samples[2,:]])
print('Covariance Matrix:\n', cov_mat)

# %%
for i in range(len(eig_val_sc)):
    eigv = eig_vec_sc[:,i].reshape(1,3).T
    np.testing.assert_array_almost_equal(scatter_matrix.dot(eigv),
                                         eig_val_sc[i] * eigv,
                                         decimal=6, err_msg='', verbose=True)

# %%
transformed = matrix_w.T.dot(all_samples)
assert transformed.shape == (2,40), "The matrix is not 2x40 dimensional."
transformed
matrix_w

# %%
import matplotlib.pyplot as plt
plt.plot(merged_dataframe.index,(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-
         merged_dataframe['BOK2016']['close_price'])
         
         
plt.show()

# %%
(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-merged_dataframe['BOK2016']['close_price']

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(aligned_dataframe.index)),aligned_dataframe['c1']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c2']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c3']['tr_dte'])
plt.grid()         
         
plt.show()

# %%
merged_dataframe['c1']['tr_dte'].isnull().sum()
merged_dataframe['c3']['tr_dte'].isnull().sum()

# %%
futures_dataframe

# %%
print(trDte1)
print(trDte2)
print(trDte3)

# %%
bf_price = (aligned_dataframe['c1']['close_price']+aligned_dataframe['c3']['close_price'])/2-aligned_dataframe['c2']['close_price']

# %%
plt.plot(range(len(aligned_dataframe.index)),bf_price)
plt.grid()         
         
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(price_ratio)
plt.grid()
plt.show()

# %%
import numpy as np
nan_matrix = np.empty((2,2))
nan_matrix[:] = np.NAN
nan_matrix
