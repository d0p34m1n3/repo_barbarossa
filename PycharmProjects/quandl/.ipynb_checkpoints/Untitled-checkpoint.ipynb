# %%
import my_sql_routines.options_signal_loader as osl
osl.load_atm_vols_4settle_date(settle_date=20160322)

# %%
import signals.option_signals as ops
ops.get_vcs_signals(ticker1='ESM2016',ticker2='ESU2016',settle_date=20160322)

# %%
import futures_charts.options_curve as oc
oc.get_vcs_panel_plot(ticker_list=['LCQ2016','LCV2016'],report_date=20160322)

# %%
import matplotlib.pyplot as plt
plt.plot(imp_vol_ratio)
plt.grid()         
         
plt.show()

# %%
import opportunity_constructs.utilities as ocu
aligned_output = ocu.get_aligned_futures_data(contract_list=['NGU2016','NGX2016','NGF2017'],aggregation_method=12,contracts_back=10,date_to=20160218)
#aligned_output = ocu.get_aligned_futures_data(contract_list=['HOV2007','HOX2007'],aggregation_method=12,contracts_back=10,date_to=20070420)
aligned_data = aligned_output['aligned_data']
bf_price = aligned_data['c1']['close_price']+aligned_data['c3']['close_price']-2*aligned_data['c2']['close_price']
#bf_price = aligned_data['c1']['close_price']-aligned_data['c2']['close_price']
#bf_price_recent = bf_price[1:]
#aligned_data_recent = aligned_data[1:]
import matplotlib.pyplot as plt
plt.plot(bf_price)
plt.grid()         
         
plt.show()

# %%
import ta.abn_position_reconciler as apr
wuhu = apr.reconcile_position()
wuhu

# %%
import opportunity_constructs.spread_carry as sc

#Carry Spread Bet Size: 442
spread_carry_output = sc.generate_spread_carry_sheet_4date(report_date=20160420)
spread_report = spread_carry_output['spread_report']
ticker_head_list = list(spread_report['tickerHead'].unique())
# Compare BO and S sizing

spread_report[spread_report['tickerHead']==ticker_head_list[19]]
#spread_report[spread_report['tickerHead']=='LC']

# %%
import futures_charts.options_curve as ocr
# %matplotlib inline
ocr.get_vcs_panel_plot(ticker_list=['WN2016','WU2016'],report_date = 20160407,diagnostics_q=True)

# %%
import formats.futures_strategy_formats as fsf
fsf.generate_futures_butterfly_formatted_output()

# %%
import ta.prepare_daily as prep
prep.prepare_strategy_daily(strategy_class='vcs')

# %%
import technical_indicators as tai

# %%
import formats.risk_pnl_formats as rpf
import ta.prepare_daily as prep
import my_sql_routines.my_sql_utilities as msu
import formats.strategy_followup_formats as sff
report_date  =20160414
con = msu.get_my_sql_connection()
#rpf.generate_portfolio_pnl_report(as_of_date=report_date, con=con)
#prep.move_from_dated_folder_2daily_folder(ext='ta', file_name='pnl', folder_date=report_date)
writer_out = sff.generate_futures_butterfly_followup_report(as_of_date=report_date, con=con)
sff.generate_spread_carry_followup_report(as_of_date=report_date, con=con, writer=writer_out)
prep.move_from_dated_folder_2daily_folder(ext='ta', file_name='followup', folder_date=report_date)

# %%
import ta.email_reports as er
er.send_hrsn_report(report_date=20160414)

# %%
import my_sql_routines.my_sql_utilities as msu
#con = msu.get_my_sql_connection()
import my_sql_routines.options_greek_loader as ogl
import my_sql_routines.options_signal_loader as osl
import opportunity_constructs.vcs as vcs
import formats.options_strategy_formats as osf
import ta.prepare_daily as prep
#osl.load_ticker_signals_4settle_date(con=con, settle_date=20160411)
#as_of_date=20160411
#settle_date=20170214
#vcs.generate_vcs_sheet_4date(con=con,date_to=20160411)
folder_date=20160411
osf.generate_vcs_formatted_output(report_date=folder_date)
prep.prepare_strategy_daily(strategy_class='vcs', report_date=folder_date)

# %%
import ta.strategy as tas
tas.get_net_position_4strategy_alias(alias='LCV2016Z2016Q2016V2016')

# %%
import ta.strategy_hedger as sh
sh.hedge_strategy_against_delta(alias='WN16U16VCS')

# %%
import contract_utilities.expiration as exp
wuhu = exp.get_days2_expiration(ticker='ADU2016',date_to=20160411,instrument='options')

datetime_to = wuhu['datetime_to']
expiration_datetime = wuhu['expiration_datetime']

kuzu = wuhu['expiration_datetime']-wuhu['datetime_to'].date()
kuzu.days

# %%
import ta.strategy_hedger as sh
import pandas as pd
import option_models.utils as omu
import get_price.get_options_price as gop
kuzu = sh.get_hedge_4strategy(alias='WN16U16VCS')
kuzu

# %%
import ta.strategy_hedger as sh
sh.hedge_strategy_against_delta(alias='WN16U16VCS')

# %%
import ta.strategy_hedger as sh
wuhu = sh.get_hedge_4strategy(alias='WN16U16VCS')
wuhu

# %%
import ta.strategy_hedger as sh
sh.strategy_hedge_report()

# %%
import contract_utilities.contract_meta_info as cmi
import get_price.get_futures_price as gfp

futures_data_dictionary = {x: gfp.get_futures_price_preloaded(ticker_head=x) for x in cmi.cme_futures_tickerhead_list}

# %%
import signals.realized_vol_until_expiration as rve
wuhu = rve.get_past_realized_vol_until_expiration(ticker='ADU2016',contracts_back=100,aggregation_method=1,date_to=20160411,futures_data_dictionary=futures_data_dictionary)
wuhu

# %%
import opportunity_constructs.curve_pca as cpc
curve_pca_output = cpc.get_curve_pca_report(ticker_head='B', date_to=20160420)
curve_pca_output

# %%
date_to = 20160420
import shared.calendar_utilities as cu
import get_price.curve_data as cd
date10_years_ago = cu.doubledate_shift(date_to, 10*365)

num_monthly_contracts = 18
num_semiannual_contracts = 8
ticker_head = 'B'


rolling_data_monthly = cd.get_rolling_curve_data(ticker_head=ticker_head, num_contracts=num_monthly_contracts,
                                         front_tr_dte_limit=10,
                                        date_from=date10_years_ago,
                                        date_to=date_to)

rolling_data_semiannual = cd.get_rolling_curve_data(ticker_head=ticker_head, num_contracts=7,
                                         front_tr_dte_limit=10,
                                        date_from=date10_years_ago,
                                        month_separation=6,
                                        date_to=date_to)

# %%
rolling_data_semiannual

# %%
import ta.pnl as tpnl
import pandas as pd
wuhu = tpnl.get_strategy_pnl_4day(alias='WZ16U16VCS',pnl_date=20160401)
wuhu

# %%
import get_price.get_options_price as gop
wuhu = gop.get_options_price_from_db(ticker='WU2016',settle_date=20160401,strike=490,option_type='C')
wuhu['close_price']

# %%
import ta.tt_fill_loader as tfl
aggregate_trades = tfl.get_formatted_tt_fills()

aggregate_trades.loc[(slice(None),'S'),'trade_quantity']=-aggregate_trades.loc[(slice(None),'S'),'trade_quantity']

aggregate_trades

# %%
import signals.option_signals as ops
wuhu = ops.get_aligned_option_indicators(ticker_list=['ESK2016','ESM2016'],settle_date=20160331)

wuhu

# %%
tr_dte1 = 36
tr_dte2 = 55
import contract_utilities.contract_meta_info as cmi
import numpy as np
import signals.option_signals as ops

tr_dte_list = [36,55]
ref_tr_dte_list = []

selection_matrix = []

for i in range(2):
    ref_tr_dte_list.append([y for y in cmi.aligned_data_tr_dte_list if y <= tr_dte_list[i]+15 and y>=tr_dte_list[i]-15])

    
ops.get_ranked_contract_selection_4vol_strategies(ref_tr_dte_list=ref_tr_dte_list,tr_dte_list=tr_dte_list)

# %%
print(ref_tr_dte_list)

print(tr_dte_list)

# %%
import signals.realized_vol_until_expiration as rvue
wuhu = rvue.get_past_realized_vol_until_expiration(ticker = 'SX2016',
                                           contracts_back = 20,
                                           aggregation_method = 12,
                                           date_to=20160418)

wuhu

# %%
import matplotlib.pyplot as plt
plt.scatter(wuhu['real_vol20'],wuhu['real_vol_till_expiration'])
plt.grid()         
         
plt.show()

# %%
import signals.realized_vol_until_expiration as rvue
forecast_output = rvue.forecast_realized_vol_until_expiration(ticker = 'SX2016',
                                           contracts_back = 20,
                                           aggregation_method = 12,
                                           date_to=20160418)

forecast_output

# %%
clean_indx = (past_realized_vol_frame['real_vol_till_expiration'].notnull())&(past_realized_vol_frame['real_vol20'].notnull())
clean_indx.sum()>10

# %%
past_realized_vol_frame['real_vol_diff'] = abs(past_realized_vol_frame['real_vol20']-real_vol20_current)

past_realized_vol_frame['forecast_multiplier'] = past_realized_vol_frame['real_vol_till_expiration']/past_realized_vol_frame['real_vol20']

past_realized_vol_frame.sort('real_vol_diff',ascending=True,inplace=True)

num_relevant_obs = max(round(len(past_realized_vol_frame.index)/5),10)

past_realized_vol_frame


sum([past_realized_vol_frame['forecast_multiplier'].iloc[i]*(num_relevant_obs-i) for i in range(num_relevant_obs)])/sum([(num_relevant_obs-i) for i in range(num_relevant_obs)])

# %%
past_realized_vol_frame['forecast_multiplier']

# %%
import matplotlib.pyplot as plt
plt.scatter(past_realized_vol_frame['real_vol20'],past_realized_vol_frame['forecast_multiplier'])
plt.grid()         
         
plt.show()

# %%
import get_price.get_futures_price as gfp 
import numpy as np
data = gfp.get_futures_price_preloaded(ticker='GCM2016')
logreturns  = np.log(data['close_price'][-21:]/data['close_price'][-21:].shift(1))
np.sqrt(252*logreturns.var())

# %%
import signals.option_signals as os
os.calc_realized_vol_4futures_ticker(ticker='GCM2016',settle_date=20160324)

# %%
import signals.option_signals as os
os.calc_realized_vol_4options_ticker(ticker='GCQ2016',settle_date=20160324)

# %%
import signals.option_signals as os
os.calc_realized_vol_4futures_ticker(ticker='GCM2016',settle_date=20160324)

# %%
import copy as cpy
my_dict = {'a':1,'b':2}
my_dict_2 = cpy.deepcopy(my_dict)
my_dict_2.pop('a')

print(my_dict_2)
print(my_dict)

# %%
import read_exchange_files.process_cme_futures as pcf
import read_exchange_files.read_cme_files as rcf
cme_output = pcf.process_cme_futures_4tickerhead(ticker_head='RB', report_date=20160225)
#data_read_out = rcf.read_cme_future_settle_csv_files(file_name='nymex_futures', report_date=20160224)
#title_frame = data_read_out['title_frame']
#title_frame
#title_frame[title_frame['ticker_head']=='LN']

#data_read_out[data_read_out['ticker_head']=='CL']

#data_read_out['month_strike_list'][68]
cme_output['settle_frame']

# %%
import get_price.get_futures_price as gfp
import shared.calendar_utilities as cu
import contract_utilities.expiration as exp
price_frame = gfp.get_futures_price_preloaded(ticker_head='ED',settle_date=20160225)
price_frame.sort('tr_dte',ascending=True,inplace=True)


exp_date = 20170225


exp_datetime = cu.convert_doubledate_2datetime(exp_date)

price_frame['exp_date'] = [exp.get_futures_expiration(x) for x in price_frame['ticker']]
price_frame = price_frame[price_frame['exp_date']<exp_datetime]

price_frame['implied_rate'] = 100-price_frame['close_price']

price_frame[['implied_rate','exp_date','cal_dte']]

# %%
[1+(price_frame['implied_rate'].iloc[x]*(price_frame['cal_dte'].iloc[x+1]-price_frame['cal_dte'].iloc[x])/36500) for x in range(len(price_frame.index)-1)]

1+(price_frame['implied_rate'].iloc[0]*price_frame['cal_dte'].iloc[0]/365000)


1+((price_frame['implied_rate'].iloc[-1]*((exp_datetime-price_frame['exp_date'].iloc[-1].to_datetime()).days))/365000)

# %%
import interest_curve.get_rate_from_stir as grfs
wuhu = grfs.get_simple_rate(as_of_date=20160216,date_to=20160718)

print(wuhu['rate_output'])

wuhu['price_frame']

# %%
import ta.position_close_helper as pch
wuhu = pch.calc_intrday_pnl_from_prices(alias='WN16U16VCS',structure_price=14.75,WN2016=507,WU2016=516)
wuhu

# %%
wuhu

# %%
import get_price.get_futures_price as gfp
import pandas as pd

[gfp.get_futures_price_preloaded(ticker=x, settle_date=20160419) for x in futures_frame['ticker']]

# %%
import get_price.get_options_price as gop
gop.get_options_price_from_db(ticker='WN2016',settle_date=20160419,strike_price=465,option_type='C')

# %%
import get_price.presave_price as pp
pp.generate_and_update_futures_data_files(ticker_head_list='cme_futures')
#data_out = pp.generate_and_update_futures_data_file_4tickerhead(ticker_head='B')
#data_out[data_out['ticker']=='BZ2016']

# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()
import futures_charts.futures_curve as fc
bf_signals_output = fc.get_butterfly_scatter_plot(report_date=report_date,id=195)

# %%
aligned_output = bf_signals_output['aligned_output']
aligned_data = aligned_output['aligned_data']
bf_price = aligned_data['c1']['close_price']+aligned_data['c3']['close_price']-2*aligned_data['c2']['close_price']

# %%
import matplotlib.pyplot as plt
plt.plot(wuhu['c1']['atm_vol']/wuhu['c2']['atm_vol'])
plt.grid()         
         
plt.show()

# %%
bad_data = aligned_data[bf_price<-0.004]   #<-0.03
bad_data

# HOV2007,HOX2007, HOZ2007 20070213 to 20070413

# %%
aligned_data.iloc[1047]

# %%
import shared.directory_names as dn
options_data_dir = dn.get_dated_directory_extension(folder_date=20160208,ext='comex_options_csv_address')
options_data_dir

# %%
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()
report_date

# %%
import scheduled_jobs.options_data_load_job as odlj
import shared.downloads as sd
sd.download_csv_from_web(web_address=odlj.comex_options_csv_address)

# %%
import scheduled_jobs.options_data_load_job

# %%
with open(r'C:\Research\data\options_data_raw\2016\201602\20160208\interest_rate.pkl','rb') as handle:
    wuhu = pickle.load(handle)

# %%
scatter_matrix = np.zeros((3,3))

for i in range(all_samples.shape[1]):
    scatter_matrix +=(all_samples[:,i].reshape(3,1)).dot(
    (all_samples[:,i].reshape(3,1)-mean_vector).T)
print('Scatter Matrix\n',scatter_matrix)

# %%
cov_mat = np.cov([all_samples[0,:], all_samples[1,:],all_samples[2,:]])
print('Covariance Matrix:\n', cov_mat)

# %%
for i in range(len(eig_val_sc)):
    eigv = eig_vec_sc[:,i].reshape(1,3).T
    np.testing.assert_array_almost_equal(scatter_matrix.dot(eigv),
                                         eig_val_sc[i] * eigv,
                                         decimal=6, err_msg='', verbose=True)

# %%
transformed = matrix_w.T.dot(all_samples)
assert transformed.shape == (2,40), "The matrix is not 2x40 dimensional."
transformed
matrix_w

# %%
import matplotlib.pyplot as plt
plt.plot(merged_dataframe.index,(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-
         merged_dataframe['BOK2016']['close_price'])
         
         
plt.show()

# %%
(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-merged_dataframe['BOK2016']['close_price']

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(aligned_dataframe.index)),aligned_dataframe['c1']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c2']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c3']['tr_dte'])
plt.grid()         
         
plt.show()

# %%
merged_dataframe['c1']['tr_dte'].isnull().sum()
merged_dataframe['c3']['tr_dte'].isnull().sum()

# %%
futures_dataframe

# %%
print(trDte1)
print(trDte2)
print(trDte3)

# %%
bf_price = (aligned_dataframe['c1']['close_price']+aligned_dataframe['c3']['close_price'])/2-aligned_dataframe['c2']['close_price']

# %%
plt.plot(range(len(aligned_dataframe.index)),bf_price)
plt.grid()         
         
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(price_ratio)
plt.grid()
plt.show()

# %%
import get_price.get_futures_price as gfp
import signals.technical_indicators as ti
futures_dataframe = gfp.get_futures_price_preloaded(ticker_head='LC')

data_selected = futures_dataframe[futures_dataframe['ticker']=='LCZ2014']
data_selected

data_out = ti.rsi(data_frame_input=data_selected,change_field = 'change_1',period=3)

# %%
data_out
# Out:
#     settle_date   ticker ticker_head  ticker_month  ticker_year  cal_dte  \
# 0    2013-08-30  LCZ2014          LC            12         2014      488
# 1    2013-09-03  LCZ2014          LC            12         2014      484
# 2    2013-09-04  LCZ2014          LC            12         2014      483
# 3    2013-09-05  LCZ2014          LC            12         2014      482
# 4    2013-09-06  LCZ2014          LC            12         2014      481
# 5    2013-09-09  LCZ2014          LC            12         2014      478
# 6    2013-09-10  LCZ2014          LC            12         2014      477
# 7    2013-09-11  LCZ2014          LC            12         2014      476
# 8    2013-09-12  LCZ2014          LC            12         2014      475
# 9    2013-09-13  LCZ2014          LC            12         2014      474
# 10   2013-09-16  LCZ2014          LC            12         2014      471
# 11   2013-09-17  LCZ2014          LC            12         2014      470
# 12   2013-09-18  LCZ2014          LC            12         2014      469
# 13   2013-09-19  LCZ2014          LC            12         2014      468
# 14   2013-09-20  LCZ2014          LC            12         2014      467
# 15   2013-09-23  LCZ2014          LC            12         2014      464
# 16   2013-09-24  LCZ2014          LC            12         2014      463
# 17   2013-09-25  LCZ2014          LC            12         2014      462
# 18   2013-09-26  LCZ2014          LC            12         2014      461
# 5       2.150     3.450    -0.100     0.200   33.333333
# 6       2.100     2.800     0.050     0.150   46.666667
# 7       1.950     2.300     0.200     0.250  100.000000
# 8       1.450     1.700     0.700     0.500  100.000000
# 9       1.500     2.000     1.800     0.700  100.000000
# 10      1.650     2.150     1.550    -0.050   96.000000
# 11      1.400     1.650     1.250    -0.150   77.777778
# 12      1.400     0.900     1.500     0.500   71.428571
# 13      2.475     1.500     1.200     0.200   82.352941
# 14      1.700     1.200    -0.100    -0.600   53.846154
# 15      1.300     1.300     0.400     0.450   52.000000
# 16      0.700     1.200     0.900     0.350   57.142857
# 17      0.350     0.600     0.600     0.200  100.000000
# 18      0.250     0.050     0.750     0.350  100.000000
# 19      0.500     0.450     1.550     0.200  100.000000
# 20      0.500     0.450     1.100     0.000  100.000000
# 21      0.250    -0.500     0.750     0.000  100.000000
# 22     -0.500    -0.800     0.800     0.250  100.000000
# 23     -0.975    -1.575     0.650     0.200  100.000000
# 24     -0.500    -1.250     0.925     0.475  100.000000
# 25      0.000    -0.950     0.600    -0.325   67.500000
# 26      0.500    -0.700     0.550    -0.050   55.882353
# 27      0.250    -0.900    -0.100    -0.400    0.000000
# 28     -0.200    -1.350    -0.300     0.000    0.000000
# 29     -0.050    -1.050    -0.675     0.100   20.000000
# ..        ...       ...       ...       ...         ...
# 307    -4.375   -12.125     3.575    -0.175   88.524590
# 308    -5.800    -9.500     3.075     0.000   82.051282
# 309    -9.450    -9.050     0.600    -0.575    0.000000
# 310    -7.100    -7.650     0.700     0.650   53.061224
# 311    -7.675    -7.650    -1.500    -1.400   24.761905
# 312    -6.850    -4.500    -0.675     0.650   48.148148
# 313    -6.825    -2.375    -1.575    -0.900   22.033898
# 314    -7.975    -4.075    -1.375    -0.375   33.766234
# 315    -9.650    -2.925    -0.950     1.075   45.744681
# 316   -10.425       NaN    -0.875    -1.325   38.738739
# 317    -7.750       NaN    -3.300    -1.775   25.748503
# 318    -3.700       NaN    -2.800    -0.400    0.000000
# 319     0.400       NaN    -4.425    -2.000    0.000000
# 320    -0.550       NaN    -8.500    -3.000    0.000000
# 321     0.025       NaN    -6.225     0.950   15.966387
# 322     2.350       NaN    -4.375     0.075   25.465839
# 323     4.450       NaN    -4.050    -0.075   93.181818
# 324     3.900       NaN    -2.400    -0.350   15.000000
# 325     6.725       NaN     0.525    -0.075    0.000000
# 326       NaN       NaN    -3.425    -3.000    0.000000
# 327       NaN       NaN    -6.050    -2.550    0.000000
# 328       NaN       NaN    -3.700     2.275   29.073482
# 329       NaN       NaN    -1.300     2.050   62.909091
# 330       NaN       NaN    -0.125     1.100  100.000000
# 331       NaN       NaN     2.875     0.000  100.000000
# 332       NaN       NaN     6.075     0.650  100.000000
# 333       NaN       NaN     6.050     2.250  100.000000
# 334       NaN       NaN     5.750     1.750  100.000000
# 335       NaN       NaN     4.025    -0.625   86.486486
# 336       NaN       NaN     3.850    -0.175   68.627451
#
# [337 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(data_out['rsi'])
plt.grid()
plt.show()

# %%
import pandas as pd
pd.rolling_mean(data_out['gains'],window=10)
