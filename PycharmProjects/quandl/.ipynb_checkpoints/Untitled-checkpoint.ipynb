# %%
import get_price.get_futures_price as gfp
panel_data = gfp.get_futures_price_preloaded(ticker_head='CL')
unique_dates = panel_data['settle_date'].unique()

data4day = panel_data[panel_data['settle_date']==unique_dates[4000]]

# %%
import get_price.curve_data as cd
rollin_data = cd.get_rolling_curve_data(ticker_head='CL',num_contracts=12,
                                         front_tr_dte_limit=10,
                                        date_from=20050101,
                                        date_to=20160101)

rollin_data
# Out:
#               ticker                                                        \
# no                1        2        3        4        5        6        7
# settle_date
# 2005-01-03   CLG2005  CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005
# 2005-01-04   CLG2005  CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005
# 2005-01-05   CLG2005  CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005
# 2005-01-06   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-07   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-10   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-11   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-12   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-13   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-14   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-18   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-19   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-20   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-21   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-24   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-25   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-26   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-27   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-28   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-01-31   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-02-01   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-02-02   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-02-03   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-02-04   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-02-07   CLH2005  CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005
# 2005-02-08   CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005  CLV2005
# 2005-02-09   CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005  CLV2005
# 2005-02-10   CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005  CLV2005
# 2005-02-11   CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005  CLV2005
# 2005-02-14   CLJ2005  CLK2005  CLM2005  CLN2005  CLQ2005  CLU2005  CLV2005
# ...              ...      ...      ...      ...      ...      ...      ...
# 2015-11-18   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-11-19   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-11-20   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-11-23   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-11-24   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-11-25   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-11-27   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-11-30   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-12-01   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-12-02   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-12-03   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-12-04   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-12-07   CLF2016  CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016
# 2015-12-08   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-09   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-10   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-11   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-14   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-15   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-16   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-17   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-18   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-21   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-22   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-23   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-24   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-28   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-29   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-30   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
# 2015-12-31   CLG2016  CLH2016  CLJ2016  CLK2016  CLM2016  CLN2016  CLQ2016
#
#                                         ...  change_1                          \
# no                8        9        10  ...        3     4     5     6     7
# settle_date                             ...
# 2005-01-03   CLU2005  CLV2005  CLX2005  ...     -1.20 -1.13 -1.07 -1.02 -0.97
# 2005-01-04   CLU2005  CLV2005  CLX2005  ...      1.68  1.62  1.57  1.52  1.48
# 2005-01-05   CLU2005  CLV2005  CLX2005  ...     -0.50 -0.52 -0.54 -0.56 -0.58
# 2005-01-06   CLV2005  CLX2005  CLZ2005  ...      2.01  1.94  1.87  1.79  1.71
# 2005-01-07   CLV2005  CLX2005  CLZ2005  ...     -0.19 -0.21 -0.23 -0.24 -0.26
# 2005-01-10   CLV2005  CLX2005  CLZ2005  ...     -0.14 -0.15 -0.17 -0.33 -0.20
# 2005-01-11   CLV2005  CLX2005  CLZ2005  ...      0.30  0.30  0.31  0.45  0.32
# 2005-01-12   CLV2005  CLX2005  CLZ2005  ...      0.59  0.56  0.54  0.52  0.51
# 2005-01-13   CLV2005  CLX2005  CLZ2005  ...      1.53  1.50  1.47  1.44  1.40
# 2005-01-14   CLV2005  CLX2005  CLZ2005  ...      0.39  0.40  0.40  0.40  0.40
# 2005-01-18   CLV2005  CLX2005  CLZ2005  ...      0.15  0.18  0.20  0.21  0.23
# 2005-01-19   CLV2005  CLX2005  CLZ2005  ...     -0.53 -0.51 -0.49 -0.47 -0.46
# 2005-01-20   CLV2005  CLX2005  CLZ2005  ...     -0.40 -0.38 -0.35 -0.33 -0.32
# 2005-01-21   CLV2005  CLX2005  CLZ2005  ...      1.37  1.38  1.36  1.34  1.31
# 2005-01-24   CLV2005  CLX2005  CLZ2005  ...      0.39  0.42  0.41  0.40  0.38
# 2015-12-02   46.57  47.01  47.44
# 2015-12-03   47.41  47.83  48.25
# 2015-12-04   46.55  46.99  47.43
# 2015-12-07   44.77  45.26  45.75
# 2015-12-08   44.91  45.41  45.79
# 2015-12-09   44.80  45.30  45.69
# 2015-12-10   45.11  45.62  46.01
# 2015-12-11   44.01  44.54  44.95
# 2015-12-14   43.59  44.08  44.46
# 2015-12-15   44.26  44.74  45.10
# 2015-12-16   43.10  43.62  44.02
# 2015-12-17   42.85  43.38  43.79
# 2015-12-18   42.48  43.00  43.41
# 2015-12-21   41.90  42.41  42.81
# 2015-12-22   41.65  42.13  42.51
# 2015-12-23   42.68  43.13  43.48
# 2015-12-24   43.61  44.06  44.41
# 2015-12-28   42.52  43.00  43.39
# 2015-12-29   43.38  43.85  44.23
# 2015-12-30   42.41  42.90  43.29
# 2015-12-31   43.34  43.83  44.21
#
# [2769 rows x 12 columns]

# %%
data4day = data4day.iloc[:12]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-db32d8a316d3> in <module>()
# ----> 1 data4day = data4day.iloc[:12]
#
# NameError: name 'data4day' is not defined

# %%
import numpy as np
np.random.seed()

# %%
butterflies['trDte1']

# %%
sellpnls = [butterfly_pnl[i] for i in range(num_butterflies) \
            if butterflies['Q'][i]>=85 and butterflies['QF'][i]>=60]
buypnls = [butterfly_pnl[i] for i in range(num_butterflies) \
           if butterflies['Q'][i]<=15 and butterflies['QF'][i]<=40]




import numpy as np
np.nanmean(buypnls)

buy_mean_pnl = [0]*len(ticker_head_list)
sell_mean_pnl = [0]*len(ticker_head_list)

buy_total_pnl = [0]*len(ticker_head_list)
sell_total_pnl = [0]*len(ticker_head_list)


for i in range(len(ticker_head_list)):
    
    sellpnls = [butterfly_pnl[j] for j in range(num_butterflies) \
            if butterflies['Q'][j]>=85 and butterflies['QF'][j]>=60 \
                and butterflies['tickerHead'][j]==ticker_head_list[i] \
               and butterflies['trDte1'][j]>=35]
    buypnls = [butterfly_pnl[j] for j in range(num_butterflies) \
           if butterflies['Q'][j]<=15 and butterflies['QF'][j]<=40 \
               and butterflies['tickerHead'][j]==ticker_head_list[i] \
               and butterflies['trDte1'][j]>=35]
    if len(buypnls)>0:
        buy_mean_pnl[i] = np.nanmean(buypnls)
        buy_total_pnl[i] = np.nansum(buypnls)
    if len(sellpnls)>0:
        sell_mean_pnl[i] = -np.nanmean(sellpnls)
        sell_total_pnl[i] = -np.nansum(sellpnls)

# %%
i=10
sellpnls = [butterfly_pnl[j] for j in range(num_butterflies) \
            if butterflies['Q'][j]>=85 and butterflies['QF'][j]>=60 and butterflies['tickerHead'][j]==ticker_head_list[i]]
buypnls = [butterfly_pnl[j] for j in range(num_butterflies) \
           if butterflies['Q'][j]<=15 and butterflies['QF'][j]<=40 and butterflies['tickerHead'][j]==ticker_head_list[i]]

sellpnls

# %%
import pandas as pd
pd.DataFrame({'tickerHead': ticker_head_list,
              'totalLong': buy_total_pnl,
              'totalShort': sell_total_pnl,
              'meanLong': buy_mean_pnl,
              'meanShort': sell_mean_pnl})

sellpnls = [butterfly_pnl[i] for i in range(num_butterflies) \
            if butterflies['Q'][i]>=85 and butterflies['QF'][i]>=60]
buypnls = [butterfly_pnl[i] for i in range(num_butterflies) \
           if butterflies['Q'][i]<=15 and butterflies['QF'][i]<=40]
print(-np.nansum(sellpnls))
print(np.nansum(buypnls))

pd.DataFrame({'tickerHead': ticker_head_list,
              'totalLong': buy_total_pnl,
              'totalShort': sell_total_pnl,
              'meanLong': buy_mean_pnl,
              'meanShort': sell_mean_pnl})

# %%
ticker_head_dictionary['BO'][(ticker_head_dictionary['BO']['tr_dte']<60)&(ticker_head_dictionary['BO']['tr_dte']>50)]

# %%
import sys
sys.path.append(r'C:\Users\kocat_000\quantFinance\PycharmProjects')
import opportunity_constructs.utilities as ut

aligned_output = ut.get_aligned_futures_data({'contract_list': [ticker1, ticker2, ticker3],
                            'tr_dte_list': [trDte1, trDte2, trDte3],
                             'aggregation_method': agggreation_method,
                             'contracts_back': contracts_back,
                             'date_to': 20151026})

# %%
import sys
sys.path.append(r'C:\Users\kocat_000\quantFinance\PycharmProjects')
import get_price.get_futures_price as gfp
import get_price.presave_price as psp

psp.generate_and_update_futures_data_files()

# %%
import pandas as pd
wuhu = pd.read_pickle(r'C:\Users\kocat_000\quantFinance\data\futures_data\CL.pkl')
wuhu

# %%
import numpy as np

x = price_ratio_current
y = price_ratio

import shared.statistics as stats

print(stats.get_quantile({'x': price_ratio_current, 'y': price_ratio }))

print(stats.get_quantile({'x': price_ratio_current, 'y': price_ratio[-40:]}))

# %%
import pandas as pd
merged_dataframe = pd.concat([data_1, data_2, data_3], axis=1, join='inner',keys=['c1', 'c2', 'c3'])
merged_dataframe['c1']['close_price']
merged_dataframe['c2']['close_price']
merged_dataframe['c3']['close_price']

# %%
merged_dataframe_list[1]

# %%
import sys
sys.path.append(r'C:\Users\kocat_000\quantFinance\PycharmProjects')
import contract_utilities.contract_lists as cl
cl.generate_futures_list_dataframe({'date_to': 20151026})

# %%
merged_dataframe

multi_columns = pd.MultiIndex.from_product([[ticker1, ticker2, ticker3],data_1.columns.values], names=['first', 'second'])

# %%
import matplotlib.pyplot as plt
plt.plot(aligned_dataframe.index,aligned_dataframe['c1']['close_price'],
         aligned_dataframe.index,aligned_dataframe['c2']['close_price'],
         aligned_dataframe.index,aligned_dataframe['c3']['close_price'])
         
         
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(merged_dataframe.index,(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-
         merged_dataframe['BOK2016']['close_price'])
         
         
plt.show()

# %%
(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-merged_dataframe['BOK2016']['close_price']

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(aligned_dataframe.index)),aligned_dataframe['c1']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c2']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c3']['tr_dte'])
plt.grid()         
         
plt.show()

# %%
merged_dataframe['c1']['tr_dte'].isnull().sum()
merged_dataframe['c3']['tr_dte'].isnull().sum()

# %%
futures_dataframe

# %%
print(trDte1)
print(trDte2)
print(trDte3)

# %%
bf_price = (aligned_dataframe['c1']['close_price']+aligned_dataframe['c3']['close_price'])/2-aligned_dataframe['c2']['close_price']

# %%
plt.plot(range(len(aligned_dataframe.index)),bf_price)
plt.grid()         
         
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(price_ratio)
plt.grid()
plt.show()
