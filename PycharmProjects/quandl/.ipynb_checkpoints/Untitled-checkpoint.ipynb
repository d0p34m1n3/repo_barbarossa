# %%
import signals.futures_signals as fs
import signals.utils as su
signals_output = fs.get_futures_butterfly_signals(ticker_list=['LNJ2016','LNN2016','LNV2016'],date_to=20160114)

price_ratio = signals_output['price_ratio']
price_ratio
# Out:
# array([ 0.86200964,  0.85750766,  0.8602261 ,  0.85745394,  0.85608856,
#         0.85531629,  0.85361345,  0.85719178,  0.85223426,  0.85784636,
#         0.85960265,  0.86857905,  0.86705491,  0.86693548,  0.86248753,
#         0.86350099,  0.86252479,  0.86559843,  0.86420157,  0.8575172 ,
#         0.85272965,  0.83825481,  0.83829365,  0.83783333,  0.84105298,
#         0.83927404,  0.84165593,  0.84314039,  0.84382022,  0.84532605,
#         0.84489403,  0.84512705,  0.84705317,  0.84937238,  0.85191808,
#         0.84986988,  0.8516537 ,  0.86154835,  0.86219081,  0.86453674])

# %%
import opportunity_constructs.futures_butterfly as fb
fb.generate_futures_butterfly_sheet_4date(date_to=20160114)
# Out:
# {'butterflies':      ticker1  ticker2  ticker3 tickerHead tickerClass  trDte1  trDte2  trDte3  \
#  0     BK2016   BM2016   BN2016          B      Energy      54      75      96
#  1     BM2016   BN2016   BQ2016          B      Energy      75      96     118
#  2     BN2016   BQ2016   BU2016          B      Energy      96     118     138
#  3     BQ2016   BU2016   BV2016          B      Energy     118     138     160
#  4     BU2016   BV2016   BX2016          B      Energy     138     160     182
#  5     BV2016   BX2016   BZ2016          B      Energy     160     182     203
#  6     BX2016   BZ2016   BF2017          B      Energy     182     203     224
#  7     BZ2016   BF2017   BG2017          B      Energy     203     224     244
#  8     BF2017   BG2017   BH2017          B      Energy     224     244     266
#  9     BG2017   BH2017   BJ2017          B      Energy     244     266     286
#  10    BH2017   BJ2017   BK2017          B      Energy     266     286     309
#  11    BJ2017   BK2017   BM2017          B      Energy     286     309     328
#  12    BK2017   BM2017   BN2017          B      Energy     309     328     350
#  13    BM2017   BN2017   BQ2017          B      Energy     328     350     372
#  14    BN2017   BQ2017   BU2017          B      Energy     350     372     392
#  15    BQ2017   BU2017   BV2017          B      Energy     372     392     414
#  16    BU2017   BV2017   BX2017          B      Energy     392     414     435
#  17    BV2017   BX2017   BZ2017          B      Energy     414     435     457
#  18    BX2017   BZ2017   BF2018          B      Energy     435     457     478
#  19    BK2016   BN2016   BU2016          B      Energy      54      96     138
#  20    BM2016   BQ2016   BV2016          B      Energy      75     118     160
#  21    BN2016   BU2016   BX2016          B      Energy      96     138     182
#  22    BQ2016   BV2016   BZ2016          B      Energy     118     160     203
#  23    BU2016   BX2016   BF2017          B      Energy     138     182     224
#  24    BV2016   BZ2016   BG2017          B      Energy     160     203     244
#  25    BX2016   BF2017   BH2017          B      Energy     182     224     266
#  26    BZ2016   BG2017   BJ2017          B      Energy     203     244     286
#  27    BF2017   BH2017   BK2017          B      Energy     224     266     309
#  28    BG2017   BJ2017   BM2017          B      Energy     244     286     328
#  29    BH2017   BK2017   BN2017          B      Energy     266     309     350
#  ..       ...      ...      ...        ...         ...     ...     ...     ...
#  14                     22.14                   True
#  15                     14.26                   True
#  16                     11.83                   True
#  17                     14.89                   True
#  18                     12.45                   True
#  19                      2.45                   True
#  20                      7.42                   True
#  21                     13.51                   True
#  22                     13.21                   True
#  23                     11.76                   True
#  24                      5.79                   True
#  25                     10.01                   True
#  26                     10.44                   True
#  27                      5.91                   True
#  28                      5.86                   True
#  29                     14.39                   True
#  ..                       ...                    ...
#  289                     0.61                   True
#  290                     0.01                  False
#  291                     0.59                   True
#  292                     2.01                   True
#  293                    16.25                   True
#  294                     3.60                   True
#  295                     5.98                   True
#  296                      NaN                  False
#  297                     4.24                   True
#  298                     2.15                   True
#  299                      NaN                  False
#  300                      NaN                  False
#  301                     4.10                   True
#  302                     6.46                   True
#  303                    12.10                   True
#  304                     4.36                   True
#  305                     9.61                   True
#  306                     5.37                   True
#  307                     2.63                   True
#  308                     0.37                   True
#  309                     0.91                   True
#  310                     6.19                   True
#  311                     1.59                   True
#  312                     0.03                  False
#  313                     5.59                   True
#  314                     7.10                   True
#  315                     6.92                   True
#  316                    11.93                   True
#  317                     8.05                   True
#  318                     5.58                   True
#
#  [319 rows x 54 columns], 'success': True}

# %%
import signals.utils as su
import shared.statistics as stats
starting_quantile=26
favorable_quantile_move_list=[5,10,15,20,25]
stats.get_number_from_quantile(y=price_ratio,quantile_list=[89,10])
# Out:
# array([ 0.86443954,  0.84087509])

# %%
import opportunity_constructs.spread_carry as sc
#spread_carry_output = sc.generate_spread_carry_sheet_4date(report_date=20160126)
#spread_report = spread_carry_output['spread_report']
#ticker_head_list = list(spread_report['tickerHead'].unique())
#

#spread_report[spread_report['tickerHead']==ticker_head_list[20]]
spread_report[spread_report['tickerHead']=='ED']
# Out:
#     ticker1  ticker2 tickerHead  front_tr_dte  carry  q_carry  reward_risk  \
# 0   EDG2016  EDH2016         ED            14    NaN      NaN          NaN
# 1   EDH2016  EDJ2016         ED            34  -12.5        0        -0.12
# 2   EDJ2016  EDK2016         ED            58    0.0        2         0.00
# 3   EDK2016  EDM2016         ED            78  100.0       64         0.80
# 4   EDM2016  EDN2016         ED            97  -75.0      -45        -0.34
# 5   EDN2016  EDU2016         ED           121  -50.0        5        -0.08
# 6   EDU2016  EDZ2016         ED           165 -112.5        4        -0.16
# 7   EDZ2016  EDH2017         ED           229    0.0        7         0.00
# 8   EDH2017  EDM2017         ED           287  -37.5        1        -0.04
# 9   EDM2017  EDU2017         ED           355   12.5       11         0.01
# 10  EDU2017  EDZ2017         ED           418  -12.5        1        -0.01
# 11  EDZ2017  EDH2018         ED           482   50.0        8         0.05
#
#     price   q  upside  downside  change5  change10  change20
# 0   0.030  79   68.75    -46.88      NaN       NaN       NaN
# 1   0.035  79   26.28    -25.00      NaN       NaN       NaN
# 2   0.035  77   37.50    -31.25      NaN       NaN       NaN
# 3  -0.005  13   31.25    -31.25      NaN       NaN       NaN
# 4   0.025  58   57.50   -137.50      NaN       NaN       NaN
# 5   0.045  53  131.25    -87.50      NaN       NaN       NaN
# 6   0.090  49   81.25   -104.88      NaN       NaN       NaN
# 7   0.090  42   77.44    -96.19      NaN       NaN       NaN
# 8   0.105  41   75.00    -89.94      NaN       NaN       NaN
# 9   0.100  30   75.00    -86.13      NaN       NaN       NaN
# 10  0.105  29   67.37    -81.25      NaN       NaN       NaN
# 11  0.085  21   52.44    -77.44      NaN       NaN       NaN

# %%
import formats.risk_pnl_formats as rpf
rpf.generate_historic_risk_report()

# %%
import risk.historical_risk as hr
wuhu = hr.get_historical_risk_4open_strategies(as_of_date=20160122)
wuhu
# Out:
# {'historical_risk_output': [{'downside': 0, 'pnl_5_change': []},
#   {'downside': -3015.0, 'pnl_5_change': settle_date
#    2011-01-24     187.5
#    2011-01-25    -375.0
#    2011-01-26    -187.5
#    2011-01-27    -562.5
#    2011-01-28    -187.5
#    2011-01-31     187.5
#    2011-02-01     375.0
#    2011-02-02     187.5
#    2011-02-03     562.5
#    2011-02-04     375.0
#    2011-02-07    -187.5
#    2011-02-08   -1312.5
#    2011-02-09     187.5
#    2011-02-10     562.5
#    2011-02-11     187.5
#    2011-02-14     562.5
#    2011-02-15    2250.0
#    2011-02-16     750.0
#    2011-02-17    -187.5
#    2011-02-18     187.5
#    2011-02-22     187.5
#    2011-02-23    -937.5
#    2011-02-24    -562.5
#    2011-02-25    -937.5
#    2011-02-28       0.0
#    2011-03-01    -562.5
#    2011-03-02   -1687.5
#    2011-03-03   -2062.5
#    2011-03-04   -2437.5
#    2011-03-07   -3375.0
#                   ...
#    2015-12-09     187.5
#    2015-12-10       0.0
#    2015-12-11     187.5
#    2015-12-14     187.5
#    2015-12-15    -375.0
#    2015-12-16    -187.5
#    2015-12-17       0.0
#    2015-12-18    -187.5
#    2015-12-21    -375.0
#    2015-12-22     187.5
#    2015-12-23       0.0
#    2015-12-24    -187.5
#    2015-12-28     375.0
#    2015-12-29     375.0
#    2015-12-30    -187.5
#    2015-12-31    -375.0
#    2016-01-04    -375.0
#    2016-01-05   -1125.0
#    2016-01-06    -937.5
#    2016-01-07    -375.0
#    2016-01-08    -187.5
#    2016-01-11       0.0
#    2016-01-12     187.5
#    2016-01-13    -187.5
#    2016-01-14    -187.5
#    2016-01-15    -375.0
#    2016-01-19    -375.0
#    2016-01-20    -187.5
#    2016-01-21     562.5
#    2016-01-22     187.5
#    Name: change_5, dtype: float64},
#   {'downside': -684.70500000001698, 'pnl_5_change': settle_date
#    2011-01-24   -9.094947e-13
#    2011-01-25   -4.200000e+01
#    2011-01-26    3.570000e+02
#    2011-01-27    8.400000e+01
#    2011-01-28    3.150000e+02
#    2011-01-31    1.050000e+02
#    2011-02-01    1.890000e+02
#    2011-02-02    2.100000e+01
#    2011-02-03    2.310000e+02
#    2011-02-04    1.260000e+02
#    2011-02-07    2.940000e+02
#    2011-02-08    2.100000e+02
#    2011-02-09   -1.050000e+02
#    2011-02-10    1.260000e+02
#    2011-02-11    2.310000e+02
#    2011-02-14   -4.200000e+01
#    2011-02-15   -1.890000e+02
#    2011-02-18   -9.000000e+01
#    2011-02-22    2.100000e+02
#    2011-02-23   -4.800000e+02
#    2011-02-24   -3.300000e+02
#    2011-02-25   -9.300000e+02
#    2011-02-28   -9.000000e+02
#    2011-03-01   -1.140000e+03
#    2011-03-02   -1.500000e+02
#    2011-03-03   -3.300000e+02
#    2011-03-04    8.100000e+02
#    2011-03-07    9.600000e+02
#                      ...
#    2015-12-09    1.500000e+02
#    2015-12-10   -1.800000e+02
#    2015-12-11   -1.800000e+02
#    2015-12-14   -2.182787e-11
#    2015-12-15   -1.800000e+02
#    2015-12-16   -1.200000e+02
#    2015-12-17    6.000000e+01
#    2015-12-18    1.500000e+02
#    2015-12-21    2.182787e-11
#    2015-12-22    2.400000e+02
#    2015-12-23    2.700000e+02
#    2015-12-24    2.400000e+02
#    2015-12-28    3.000000e+02
#    2015-12-29    3.600000e+02
#    2015-12-30    1.800000e+02
#    2015-12-31   -1.500000e+02
#    2016-01-04   -6.000000e+01
#    2016-01-05   -2.400000e+02
#    2016-01-06   -3.600000e+02
#    2016-01-07   -1.800000e+02
#    2016-01-08    3.000000e+01
#    2016-01-11    9.000000e+01
#    2016-01-12    9.000000e+01
#    2016-01-13    9.000000e+01
#    2016-01-14    6.000000e+01
#    2016-01-15    3.000000e+01
#    2016-01-19    6.000000e+01
#    2016-01-20    9.000000e+01
#    2016-01-21    6.000000e+01
#    2016-01-22   -1.500000e+02
#    Name: change_5, dtype: float64}],
#  'portfolio_risk_frame':                      alias   downside
#  1    CK2016N2016H2016K2016 -3015.0000
#  3   LCV2016G2017M2016V2016 -2250.7000
#  11   BG2017H2017F2017G2017 -2003.5500
#  4   LNZ2016G2017V2016Z2016 -1787.2500
#  12   SX2016F2017F2017H2017 -1200.3750
#  9    SN2016Q2016K2016N2016  -915.6875
#  5    BX2016Z2016Z2016F2017  -846.6500
#  2   RBX2016Z2016V2016X2016  -684.7050
#  14  CLU2016Z2016Z2016H2017  -651.1500
#  10        spreadCarryJan16  -644.1250
#  8   NGX2016F2017U2016X2016  -630.7500
#  7   NGM2016N2016N2016Q2016  -550.0000
#  13  CCK2016N2016N2016U2016  -512.4000
#  6           CL-Jan16-Carry  -438.2000
#  0   HON2016Q2016Q2016U2016     0.0000}

# %%
import formats.futures_strategy_formats as fsf

fsf.generate_curve_pca_formatted_output()

# %%
import contract_utilities.expiration as exp
import formats.risk_pnl_formats as rpf
import ta.prepare_daily as prep
report_date = exp.doubledate_shift_bus_days()

rpf.generate_portfolio_pnl_report(as_of_date=report_date)
prep.move_from_dated_folder_2daily_folder(ext='ta', file_name='pnl', folder_date=report_date)

# %%
import formats.strategy_followup_formats as sff
import my_sql_routines.my_sql_utilities as msu
import contract_utilities.expiration as exp
report_date = exp.doubledate_shift_bus_days()
con = msu.get_my_sql_connection()
wuhu = sff.generate_futures_butterfly_followup_report(as_of_date=report_date,con=con)
wuhu
# Out:
#                      alias  holding_tr_dte  short_tr_dte  z1_initial    z1  \
# 14  FCK2016Q2016J2016K2016               1            65        0.86  0.93
# 6   NGX2016F2017U2016X2016               7           150        2.04  2.23
# 2   LCV2016G2017M2016V2016              11           109        1.43  1.45
# 1   RBX2016Z2016V2016X2016              12           173        2.68  3.48
# 8    BG2017H2017F2017G2017               4           216        1.64  1.59
# 7    SN2016Q2016K2016N2016               7            76        1.13  1.04
# 3   LNZ2016G2017V2016Z2016               9           183        1.86  1.77
# 0    CK2016N2016H2016K2016              12            33        1.28  0.91
# 9    SX2016F2017F2017H2017               4           204       -0.71 -0.23
# 5   NGM2016N2016N2016Q2016               7            85       -2.48 -1.87
# 11  CLU2016Z2016Z2016H2017               3           145       -0.82 -0.55
# 12  RBJ2017K2017K2017M2017               2           298       -2.42 -2.06
# 4    BX2016Z2016Z2016F2017              10           174       -4.18 -3.81
# 10  CCK2016N2016N2016U2016               3            76       -0.77 -0.74
# 13  HOM2016N2016N2016Q2016               1            87       -0.75 -0.78
# 15  SBV2016H2017H2017K2017               1           173       -1.06 -1.11
#
#     QF_initial  QF  total_pnl  downside
# 14          97  99         10      -629
# 6           64  93       -128      -631
# 2           77  90       -106     -2262
# 1           92  80      -1885      -685
# 8           92  79       -242     -2002
# 7           72  75          3      -986
# 3           90  69         42     -1788
# 0           95  49        115         0
# 9            8  43        378     -1204
# 5            1  36        384      -550
# 11          10  31         81      -666
# 12           5  12        194      -585
# 4            2  11       -379      -820
# 10           5  10         10      -482
# 13           1   1        -59      -480
# 15           1   1        -78      -605

# %%
import formats.risk_pnl_formats as rpf
import formats.strategy_followup_formats as sff
import ta.prepare_daily as prep
import contract_utilities.expiration as exp

try:
    report_date = exp.doubledate_shift_bus_days()
    sff.generate_futures_butterfly_followup_report(as_of_date=report_date,con=con)
    prep.move_from_dated_folder_2daily_folder(ext='ta', file_name='followup', folder_date=report_date)
except Exception:
    pass

# %%
import my_sql_routines.my_sql_utilities as msu
con = msu.get_my_sql_connection()
con

# %%
import my_sql_routines.futures_price_loader as fpl
fpl.update_futures_price_database()
# Out:
# No : 0, RBF2017 loaded
# No : 1, RBF2018 loaded
# No : 2, RBG2016 loaded
# No : 3, RBG2017 loaded
# No : 4, RBH2016 loaded
# No : 5, RBH2017 loaded
# No : 6, RBJ2016 loaded
# No : 7, RBJ2017 loaded
# No : 8, RBK2016 loaded
# No : 9, RBK2017 loaded
# No : 10, RBM2016 loaded
# No : 11, RBM2017 loaded
# No : 12, RBN2016 loaded
# No : 13, RBN2017 loaded
# No : 14, RBQ2016 loaded
# No : 15, RBQ2017 loaded
# No : 16, RBU2016 loaded
# No : 17, RBU2017 loaded
# No : 18, RBV2016 loaded
# No : 19, RBV2017 loaded
# No : 20, RBX2016 loaded
# No : 21, RBX2017 loaded
# No : 22, RBZ2016 loaded
# No : 23, RBZ2017 loaded
# No : 24, SF2016 loaded
# No : 25, SF2017 loaded
# No : 26, SF2018 loaded
# No : 27, SH2016 loaded
# No : 28, SH2017 loaded
# No : 29, SK2016 loaded
# No : 30, SK2017 loaded
# No : 31, SN2016 loaded
# No : 32, SN2017 loaded
# No : 33, SQ2016 loaded
# No : 34, SQ2017 loaded
# No : 35, SU2016 loaded
# No : 36, SU2017 loaded
# No : 37, SX2016 loaded
# No : 38, SX2017 loaded
# No : 39, FCF2016 loaded
# Error Loading CME/FCF2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 40, FCF2017 loaded
# No : 41, FCH2016 loaded
# Error Loading CME/FCH2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 42, FCH2017 loaded
# No : 43, FCJ2016 loaded
# Error Loading CME/FCJ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 44, FCJ2017 loaded
# No : 45, FCK2016 loaded
# Error Loading CME/FCK2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 46, FCK2017 loaded
# No : 47, FCQ2016 loaded
# Error Loading CME/FCQ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 48, FCQ2017 loaded
# No : 49, FCU2016 loaded
# Error Loading CME/FCU2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 50, FCU2017 loaded
# No : 51, FCV2016 loaded
# Error Loading CME/FCV2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 52, FCV2017 loaded
# No : 53, FCX2016 loaded
# Error Loading CME/FCX2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 54, FCX2017 loaded
# No : 55, CH2016 loaded
# No : 56, CH2017 loaded
# No : 57, CK2016 loaded
# No : 58, CK2017 loaded
# No : 59, CN2016 loaded
# No : 60, CN2017 loaded
# No : 61, CU2016 loaded
# No : 62, CU2017 loaded
# No : 63, CZ2016 loaded
# No : 64, CZ2017 loaded
# No : 65, OJF2017 loaded
# No : 66, OJF2018 loaded
# No : 67, OJH2016 loaded
# No : 68, OJH2017 loaded
# No : 69, OJK2016 loaded
# No : 70, OJK2017 loaded
# No : 71, OJN2016 loaded
# No : 72, OJN2017 loaded
# No : 73, OJU2016 loaded
# No : 74, OJU2017 loaded
# No : 75, OJX2016 loaded
# No : 76, OJX2017 loaded
# No : 77, HOF2017 loaded
# No : 78, HOF2018 loaded
# No : 79, HOG2016 loaded
# No : 80, HOG2017 loaded
# No : 81, HOH2016 loaded
# No : 82, HOH2017 loaded
# No : 83, HOJ2016 loaded
# No : 84, HOJ2017 loaded
# No : 85, HOK2016 loaded
# No : 86, HOK2017 loaded
# No : 87, HOM2016 loaded
# No : 88, HOM2017 loaded
# No : 89, HON2016 loaded
# No : 90, HON2017 loaded
# No : 91, HOQ2016 loaded
# No : 92, HOQ2017 loaded
# No : 93, HOU2016 loaded
# No : 94, HOU2017 loaded
# No : 95, HOV2016 loaded
# No : 96, HOV2017 loaded
# No : 97, HOX2016 loaded
# No : 98, HOX2017 loaded
# No : 99, HOZ2016 loaded
# No : 100, HOZ2017 loaded
# No : 101, KWH2016 loaded
# No : 102, KWH2017 loaded
# No : 103, KWK2016 loaded
# No : 104, KWK2017 loaded
# No : 105, KWN2016 loaded
# No : 106, KWN2017 loaded
# No : 107, KWU2016 loaded
# No : 108, KWU2017 loaded
# No : 109, KWZ2016 loaded
# No : 110, KWZ2017 loaded
# No : 111, SBH2016 loaded
# No : 112, SBH2017 loaded
# No : 113, SBK2016 loaded
# No : 114, SBK2017 loaded
# No : 115, SBN2016 loaded
# No : 116, SBN2017 loaded
# No : 117, SBV2016 loaded
# No : 118, SBV2017 loaded
# No : 119, KCH2016 loaded
# No : 120, KCH2017 loaded
# No : 121, KCK2016 loaded
# No : 122, KCK2017 loaded
# No : 123, KCN2016 loaded
# No : 124, KCN2017 loaded
# No : 125, KCU2016 loaded
# No : 126, KCU2017 loaded
# No : 127, KCZ2016 loaded
# No : 128, KCZ2017 loaded
# No : 129, CCH2016 loaded
# No : 130, CCH2017 loaded
# No : 131, CCK2016 loaded
# No : 132, CCK2017 loaded
# No : 133, CCN2016 loaded
# No : 134, CCN2017 loaded
# No : 135, CCU2016 loaded
# No : 136, CCU2017 loaded
# No : 137, CCZ2016 loaded
# No : 138, CCZ2017 loaded
# No : 139, BF2017 loaded
# No : 140, BF2018 loaded
# No : 141, BG2016 loaded
# No : 142, BG2017 loaded
# No : 143, BG2018 loaded
# No : 144, BH2016 loaded
# No : 145, BH2017 loaded
# No : 146, BJ2016 loaded
# No : 147, BJ2017 loaded
# No : 148, BK2016 loaded
# No : 149, BK2017 loaded
# No : 150, BM2016 loaded
# No : 151, BM2017 loaded
# No : 152, BM2018 loaded
# No : 153, BM2019 loaded
# No : 154, BN2016 loaded
# No : 155, BN2017 loaded
# No : 156, BQ2016 loaded
# No : 157, BQ2017 loaded
# No : 158, BU2016 loaded
# No : 159, BU2017 loaded
# No : 160, BV2016 loaded
# No : 161, BV2017 loaded
# No : 162, BX2016 loaded
# No : 163, BX2017 loaded
# No : 164, BZ2016 loaded
# No : 165, BZ2017 loaded
# No : 166, BZ2018 loaded
# No : 167, BZ2019 loaded
# No : 168, SMF2016 loaded
# No : 169, SMF2017 loaded
# No : 170, SMF2018 loaded
# No : 171, SMH2016 loaded
# No : 172, SMH2017 loaded
# No : 173, SMK2016 loaded
# No : 174, SMK2017 loaded
# No : 175, SMN2016 loaded
# No : 176, SMN2017 loaded
# No : 177, SMQ2016 loaded
# No : 178, SMQ2017 loaded
# No : 179, SMU2016 loaded
# No : 180, SMU2017 loaded
# No : 181, SMV2016 loaded
# No : 182, SMV2017 loaded
# No : 183, SMZ2016 loaded
# No : 184, SMZ2017 loaded
# No : 185, CTH2016 loaded
# No : 186, CTH2017 loaded
# No : 187, CTK2016 loaded
# No : 188, CTK2017 loaded
# No : 189, CTN2016 loaded
# No : 190, CTN2017 loaded
# No : 191, CTV2016 loaded
# No : 192, CTV2017 loaded
# No : 193, CTZ2016 loaded
# No : 194, CTZ2017 loaded
# No : 195, LNG2016 loaded
# No : 196, LNG2017 loaded
# No : 197, LNJ2016 loaded
# No : 198, LNJ2017 loaded
# No : 199, LNK2016 loaded
# No : 200, LNK2017 loaded
# No : 201, LNM2016 loaded
# No : 202, LNM2017 loaded
# No : 203, LNN2016 loaded
# Error Loading CME/LNN2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 204, LNN2017 loaded
# No : 205, LNQ2016 loaded
# Error Loading CME/LNQ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 206, LNQ2017 loaded
# No : 207, LNV2016 loaded
# Error Loading CME/LNV2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 208, LNV2017 loaded
# No : 209, LNZ2016 loaded
# Error Loading CME/LNZ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 210, LNZ2017 loaded
# No : 211, BOF2016 loaded
# No : 212, BOF2017 loaded
# No : 213, BOF2018 loaded
# No : 214, BOH2016 loaded
# No : 215, BOH2017 loaded
# No : 216, BOK2016 loaded
# No : 217, BOK2017 loaded
# No : 218, BON2016 loaded
# No : 219, BON2017 loaded
# No : 220, BOQ2016 loaded
# No : 221, BOQ2017 loaded
# No : 222, BOU2016 loaded
# No : 223, BOU2017 loaded
# No : 224, BOV2016 loaded
# No : 225, BOV2017 loaded
# No : 226, BOZ2016 loaded
# No : 227, BOZ2017 loaded
# No : 228, WH2016 loaded
# No : 229, WH2017 loaded
# No : 230, WK2016 loaded
# No : 231, WK2017 loaded
# No : 232, WN2016 loaded
# No : 233, WN2017 loaded
# No : 234, WU2016 loaded
# No : 235, WU2017 loaded
# No : 236, WZ2016 loaded
# No : 237, WZ2017 loaded
# No : 238, EDF2016 loaded
# Error Loading CME/EDF2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 239, EDF2017 loaded
# Error Loading CME/EDF2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 240, EDF2018 loaded
# Error Loading CME/EDF2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 241, EDF2019 loaded
# No : 242, EDG2016 loaded
# Error Loading CME/EDG2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 243, EDG2017 loaded
# Error Loading CME/EDG2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 244, EDG2018 loaded
# Error Loading CME/EDG2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 245, EDG2019 loaded
# No : 246, EDH2016 loaded
# No : 247, EDH2017 loaded
# No : 248, EDH2018 loaded
# No : 249, EDH2019 loaded
# No : 250, EDJ2016 loaded
# Error Loading CME/EDJ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 251, EDJ2017 loaded
# Error Loading CME/EDJ2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 252, EDJ2018 loaded
# Error Loading CME/EDJ2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 253, EDJ2019 loaded
# No : 254, EDK2016 loaded
# Error Loading CME/EDK2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 255, EDK2017 loaded
# Error Loading CME/EDK2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 256, EDK2018 loaded
# Error Loading CME/EDK2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 257, EDK2019 loaded
# No : 258, EDM2016 loaded
# No : 259, EDM2017 loaded
# No : 260, EDM2018 loaded
# No : 261, EDM2019 loaded
# No : 262, EDN2016 loaded
# Error Loading CME/EDN2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 263, EDN2017 loaded
# Error Loading CME/EDN2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 264, EDN2018 loaded
# Error Loading CME/EDN2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 265, EDN2019 loaded
# Error Loading CME/EDQ2016: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 266, EDQ2016 loaded
# Error Loading CME/EDQ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 267, EDQ2017 loaded
# Error Loading CME/EDQ2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 268, EDQ2018 loaded
# Error Loading CME/EDQ2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 269, EDQ2019 loaded
# No : 270, EDU2016 loaded
# No : 271, EDU2017 loaded
# No : 272, EDU2018 loaded
# No : 273, EDU2019 loaded
# Error Loading CME/EDV2016: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 274, EDV2016 loaded
# Error Loading CME/EDV2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 275, EDV2017 loaded
# Error Loading CME/EDV2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 276, EDV2018 loaded
# Error Loading CME/EDV2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 277, EDV2019 loaded
# Error Loading CME/EDX2016: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 278, EDX2016 loaded
# Error Loading CME/EDX2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 279, EDX2017 loaded
# Error Loading CME/EDX2018: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 280, EDX2018 loaded
# Error Loading CME/EDX2019: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 281, EDX2019 loaded
# No : 282, EDZ2016 loaded
# No : 283, EDZ2017 loaded
# No : 284, EDZ2018 loaded
# No : 285, EDZ2019 loaded
# No : 286, CLF2017 loaded
# No : 287, CLF2018 loaded
# No : 288, CLG2016 loaded
# No : 289, CLG2017 loaded
# No : 290, CLH2016 loaded
# No : 291, CLH2017 loaded
# No : 292, CLJ2016 loaded
# No : 293, CLJ2017 loaded
# No : 294, CLK2016 loaded
# No : 295, CLK2017 loaded
# No : 296, CLM2016 loaded
# No : 297, CLM2017 loaded
# No : 298, CLM2018 loaded
# No : 299, CLN2016 loaded
# No : 300, CLN2017 loaded
# No : 301, CLQ2016 loaded
# No : 302, CLQ2017 loaded
# No : 303, CLU2016 loaded
# No : 304, CLU2017 loaded
# No : 305, CLV2016 loaded
# No : 306, CLV2017 loaded
# No : 307, CLX2016 loaded
# No : 308, CLX2017 loaded
# No : 309, CLZ2016 loaded
# No : 310, CLZ2017 loaded
# No : 311, CLZ2018 loaded
# No : 312, LCG2016 loaded
# No : 313, LCG2017 loaded
# No : 314, LCJ2016 loaded
# No : 315, LCJ2017 loaded
# No : 316, LCM2016 loaded
# Error Loading CME/LCM2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 317, LCM2017 loaded
# No : 318, LCQ2016 loaded
# Error Loading CME/LCQ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 319, LCQ2017 loaded
# No : 320, LCV2016 loaded
# Error Loading CME/LCV2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 321, LCV2017 loaded
# No : 322, LCZ2016 loaded
# Error Loading CME/LCZ2017: <class 'Quandl.Quandl.DatasetNotFound'>
# No : 323, LCZ2017 loaded
# No : 324, NGF2017 loaded
# No : 325, NGF2018 loaded
# No : 326, NGG2016 loaded
# No : 327, NGG2017 loaded
# No : 328, NGH2016 loaded
# No : 329, NGH2017 loaded
# No : 330, NGJ2016 loaded
# No : 331, NGJ2017 loaded
# No : 332, NGK2016 loaded
# No : 333, NGK2017 loaded
# No : 334, NGM2016 loaded
# No : 335, NGM2017 loaded
# No : 336, NGN2016 loaded
# No : 337, NGN2017 loaded
# No : 338, NGQ2016 loaded
# No : 339, NGQ2017 loaded
# No : 340, NGU2016 loaded
# No : 341, NGU2017 loaded
# No : 342, NGV2016 loaded
# No : 343, NGV2017 loaded
# No : 344, NGX2016 loaded
# No : 345, NGX2017 loaded
# No : 346, NGZ2016 loaded
# No : 347, NGZ2017 loaded

# %%
import get_price.presave_price as pp
pp.generate_and_update_futures_data_file_4tickerhead(ticker_head='CL')

# %%
import get_price.curve_data as cd
wuhu = cd.get_rolling_curve_data(ticker_head='CL',num_contracts=12,front_tr_dte_limit=12,date_from=20160125,date_to=20160126)

# %%
wuhu
# Out:
# [             cal_dte  change1  change10  change2  change20  change5  change_1  \
#  settle_date
#  2016-01-25        28     0.85       NaN      NaN       NaN      NaN     -1.85
#  2016-01-26        27      NaN       NaN      NaN       NaN      NaN      1.11
#
#               change_5  close_price  cont_indx   ticker ticker_head  \
#  settle_date
#  2016-01-25      -0.05        30.34     201603  CLH2016          CL
#  2016-01-26       1.88        31.45     201603  CLH2016          CL
#
#               ticker_month  ticker_year  tr_dte  volume
#  settle_date
#  2016-01-25              3         2016      19  598054
#  2016-01-26              3         2016      18  637657  ,
#               cal_dte  change1  change10  change2  change20  change5  change_1  \
#  settle_date
#  2016-01-25        56     0.86       NaN      NaN       NaN      NaN     -1.71
#  2016-01-26        55      NaN       NaN      NaN       NaN      NaN      1.10
#
#               change_5  close_price  cont_indx   ticker ticker_head  \
#  settle_date
#  2016-01-25       0.42         31.8     201604  CLJ2016          CL
#  2016-01-26       2.23         32.9     201604  CLJ2016          CL
#
#               ticker_month  ticker_year  tr_dte  volume
#  settle_date
#  2016-01-
CL
#
#               ticker_month  ticker_year  tr_dte  volume
#  settle_date
#  2016-01-25              1         2017     230    1765
#  2016-01-26              1         2017     229    1661  ,
#               cal_dte  change1  change10  change2  change20  change5  change_1  \
#  settle_date
#  2016-01-25       361     0.89       NaN      NaN       NaN      NaN     -1.05
#  2016-01-26       360      NaN       NaN      NaN       NaN      NaN      0.98
#
#               change_5  close_price  cont_indx   ticker ticker_head  \
#  settle_date
#  2016-01-25       1.38        38.46     201702  CLG2017          CL
#  2016-01-26       3.03        39.44     201702  CLG2017          CL
#
#               ticker_month  ticker_year  tr_dte  volume
#  settle_date
#  2016-01-25              2         2017     250    1026
#  2016-01-26              2         2017     249     883  ]

# %%
import contract_utilities.contract_lists as cl
import my_sql_routines.my_sql_utilities as msu
con = msu.get_my_sql_connection()

cl.get_db_contract_list_filtered(expiration_date_from=20160125,
                                                            expiration_date_to=20200101,
                                                            ticker_head='CL', con=con,ticker_month=6)
# Out:
# [(11657, 'CLM2016', datetime.date(2016, 5, 20)),
#  (11658, 'CLM2017', datetime.date(2017, 5, 22)),
#  (11659, 'CLM2018', datetime.date(2018, 5, 22)),
#  (11660, 'CLM2019', datetime.date(2019, 5, 21))]

# %%
import contract_utilities.contract_meta_info as cmi
cmi.futures_contract_months.keys()
# Out:
# dict_keys(['CL', 'SB', 'FC', 'OJ', 'LC', 'KC', 'B', 'RB', 'W', 'LN', 'S', 'C', 'ED', 'KW', 'HO', 'BO', 'CT', 'CC', 'NG', 'SM'])

# %%
np.mean(pnl_path)

# %%
# %pylab inline
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10
ax.plot(class1_sample[0,:], class1_sample[1,:], class1_sample[2,:],
        'o', markersize=8, color='blue', alpha=0.5, label='class1')
ax.plot(class2_sample[0,:], class2_sample[1,:], class2_sample[2,:],
        '^', markersize=8, alpha=0.5, color='red', label='class2')

plt.title('Samples for class 1 and class 2')
ax.legend(loc='upper right')

plt.show()

# %%
all_samples = np.concatenate((class1_sample, class2_sample), axis=1)
assert all_samples.shape ==(3,40), "The matrix has not the dimensions 3x40"

# %%
mean_x = np.mean(all_samples[0,:])
mean_y = np.mean(all_samples[1,:])
mean_z = np.mean(all_samples[2,:])

mean_vector = np.array([[mean_x],[mean_y],[mean_z]])
print('Mean Vector:\n', mean_vector)

# %%
scatter_matrix = np.zeros((3,3))

for i in range(all_samples.shape[1]):
    scatter_matrix +=(all_samples[:,i].reshape(3,1)).dot(
    (all_samples[:,i].reshape(3,1)-mean_vector).T)
print('Scatter Matrix\n',scatter_matrix)

# %%
cov_mat = np.cov([all_samples[0,:], all_samples[1,:],all_samples[2,:]])
print('Covariance Matrix:\n', cov_mat)

# %%
# eigenvectors and eigenvalues for the from the scatter matrix
eig_val_sc, eig_vec_sc = np.linalg.eig(scatter_matrix)

# eigenvectors and eigenvalues for the from the covariance matrix
eig_val_cov, eig_vec_cov = np.linalg.eig(cov_mat)

for i in range(len(eig_val_sc)):
    eigvec_sc = eig_vec_sc[:,i].reshape(1,3).T
    eigvec_cov = eig_vec_cov[:,i].reshape(1,3).T
    assert eigvec_sc.all() == eigvec_cov.all(), 'Eigenvectors are not identical'

    print('Eigenvector {}: \n{}'.format(i+1, eigvec_sc))
    print('Eigenvalue {} from scatter matrix: {}'.format(i+1, eig_val_sc[i]))
    print('Eigenvalue {} from covariance matrix: {}'.format(i+1, eig_val_cov[i]))
    print('Scaling factor: ', eig_val_sc[i]/eig_val_cov[i])
    print(40 * '-')

# %%
for i in range(len(eig_val_sc)):
    eigv = eig_vec_sc[:,i].reshape(1,3).T
    np.testing.assert_array_almost_equal(scatter_matrix.dot(eigv),
                                         eig_val_sc[i] * eigv,
                                         decimal=6, err_msg='', verbose=True)

# %%
# %matplotlib inline

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
from matplotlib.patches import FancyArrowPatch


class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection='3d')

ax.plot(all_samples[0,:], all_samples[1,:], all_samples[2,:],
        'o', markersize=8, color='green', alpha=0.2)
ax.plot([mean_x], [mean_y], [mean_z],
        'o', markersize=10, color='red', alpha=0.5)
for v in eig_vec_sc.T:
    a = Arrow3D([mean_x, v[0]+mean_x],
                [mean_y, v[1]+mean_y],
                [mean_z, v[2]+mean_z],
                mutation_scale=20, lw=3, arrowstyle="-|>", color="r")

    ax.add_artist(a)
ax.set_xlabel('x_values')
ax.set_ylabel('y_values')
ax.set_zlabel('z_values')

plt.title('Eigenvectors')

plt.show()
multi_columns = pd.MultiIndex.from_product([[ticker1, ticker2, ticker3],data_1.columns.values], names=['first', 'second'])

# %%
transformed = matrix_w.T.dot(all_samples)
assert transformed.shape == (2,40), "The matrix is not 2x40 dimensional."
transformed
matrix_w

# %%
import matplotlib.pyplot as plt
plt.plot(merged_dataframe.index,(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-
         merged_dataframe['BOK2016']['close_price'])
         
         
plt.show()

# %%
(merged_dataframe['BOH2016']['close_price']+merged_dataframe['BON2016']['close_price'])/2-merged_dataframe['BOK2016']['close_price']

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(aligned_dataframe.index)),aligned_dataframe['c1']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c2']['tr_dte'],
         range(len(aligned_dataframe.index)),aligned_dataframe['c3']['tr_dte'])
plt.grid()         
         
plt.show()

# %%
merged_dataframe['c1']['tr_dte'].isnull().sum()
merged_dataframe['c3']['tr_dte'].isnull().sum()

# %%
futures_dataframe

# %%
print(trDte1)
print(trDte2)
print(trDte3)

# %%
bf_price = (aligned_dataframe['c1']['close_price']+aligned_dataframe['c3']['close_price'])/2-aligned_dataframe['c2']['close_price']

# %%
plt.plot(range(len(aligned_dataframe.index)),bf_price)
plt.grid()         
         
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(price_ratio)
plt.grid()
plt.show()

# %%
import numpy as np
nan_matrix = np.empty((2,2))
nan_matrix[:] = np.NAN
nan_matrix
