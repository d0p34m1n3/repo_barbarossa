# %%
import backtesting.utilities as bu
backtest_dates_out = bu.get_backtesting_dates(date_to=20180131,years_back=4)
double_dates = backtest_dates_out['double_dates']
backtesting_dates = double_dates[0::4]
backtesting_dates.reverse()
backtesting_dates
# Out:
# [20180131,
#  20180103,
#  20171206,
#  20171108,
#  20171011,
#  20170913,
#  20170816,
#  20170719,
#  20170621,
#  20170524,
#  20170426,
#  20170329,
#  20170301,
#  20170201,
#  20170104,
#  20161207,
#  20161109,
#  20161012,
#  20160914,
#  20160817,
#  20160720,
#  20160622,
#  20160525,
#  20160427,
#  20160330,
#  20160302,
#  20160203,
#  20160106,
#  20151209,
#  20151111,
#  20151014,
#  20150916,
#  20150819,
#  20150722,
#  20150624,
#  20150527,
#  20150429,
#  20150401,
#  20150304,
#  20150204,
#  20150107,
#  20141210,
#  20141112,
#  20141015,
#  20140917,
#  20140820,
#  20140723,
#  20140625,
#  20140528,
#  20140430,
#  20140402,
#  20140305,
#  20140205]

# %%
import opportunity_constructs.intraday_futures_experimental as ife
import boto3 as bt3
import get_price.quantgo_data as qgd
boto_client = qgd.get_boto_client()

ticker_frame_list = []

for i in range(len(backtesting_dates)):
    print(backtesting_dates[i])
    output = ife.get_result_sheet_4date(date_to=backtesting_dates[i],boto_client=boto_client)
    ticker_frame_list.append(output['ticker_frame'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 20180131
# 20180103
# 20171206
# 20171108
# 20171011
# 20170913
# 20170816
# 20170719
# 20170621
# 20170524
# 20170426
# 20170329
# 20170301
# 20170201
# 20170104
# 20161207
# 20161109
# 20161012
# 20160914
# 20160817
# 20160720
# 20160622
# 20160525
# 20160427
# 20160330
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _ixs(self, i, axis)
#     573             values = self._values
# --> 574             if isinstance(values, np.ndarray):
#     575                 return _index.get_value_at(values, i)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-762e5f4edb53> in <module>()
#       8 for i in range(len(backtesting_dates)):
#       9     print(backtesting_dates[i])
# ---> 10     output = ife.get_result_sheet_4date(date_to=backtesting_dates[i],boto_client=boto_client)
#      11     ticker_frame_list.append(output['ticker_frame'])
#      12
#
# D:\Research\PycharmProjects\opportunity_constructs\intraday_futures_experimental.py in get_result_sheet_4date(**kwargs)
#      42     ticker_frame = get_tickers_4date(**kwargs)
#      43
# ---> 44     summary_stats_list = [ife.get_crossover_duration(ticker=x, date_to=kwargs['date_to'], boto_client=boto_client) for x in ticker_frame['ticker']]
#      45
#      46     ticker_frame['mean_duration'] = [x['mean_duration'] for x in summary_stats_list]
#
# D:\Research\PycharmProjects\opportunity_constructs\intraday_futures_experimental.py in <listcomp>(.0)
#      42     ticker_frame = get_tickers_4date(**kwargs)
#      43
# ---> 44     summary_stats_list = [ife.get_crossover_duration(ticker=x, date_to=kwargs['date_to'], boto_client=boto_client) for x in ticker_frame['ticker']]
#      45
#      46     ticker_frame['mean_duration'] = [x['mean_duration'] for x in summary_stats_list]
#
# D:\Research\PycharmProjects\signals\intraday_futures_experimental.py in get_crossover_duration(**kwargs)
#      11         boto_client = qgd.get_boto_client()
#      12
# ---> 13     data_out = qgd.get_continuous_bar_data(ticker=kwargs['ticker'], date_to=kwargs['date_to'], num_days_back=20, boto_client=boto_client)
#      14
#      15     data_out['ema10'] = data_out['close'].ewm(span=10, min_periods=6, adjust=False).mean()
#
# D:\Research\PycharmProjects\get_price\quantgo_data.py in get_continuous_bar_data(**kwargs)
#     233     date_list.append(date_to)
#     234
# --> 235     bar_data_list = [get_book_snapshot(ticker=ticker,utc_doubledate=x,boto_client=boto_client) for x in date_list]
#     236     bar_data = pd.concat(bar_data_list)
#     237
#
# D:\Research\PycharmProjects\get_price\quantgo_data.py in <listcomp>(.0)
#     233     date_list.append(date_to)
#     234
# --> 235     bar_data_list = [get_book_snapshot(ticker=ticker,utc_doubledate=x,boto_client=boto_client) for x in date_list]
#     236     bar_data = pd.concat(bar_data_list)
#     237
#
# D:\Research\PycharmProjects\get_price\quantgo_data.py in get_book_snapshot(**kwargs)
#     156                         int(data_out['hour_utc'].iloc[x]), int(data_out['minute'].iloc[x]), int(data_out['second'].iloc[x]),
#     157                         tzinfo=pytz.utc).astimezone(pytz.timezone('US/Central')).replace(tzinfo=None)
# --> 158             for x in range(len(data_out.index))]
#     159
#     160     merged_index = pd.date_range(start=data_out['date_time'].iloc[0].replace(second=0), end=data_out['date_time'].iloc[-1].replace(second=0), freq='S')
#
# D:\Research\PycharmProjects\get_price\quantgo_data.py in <listcomp>(.0)
#     156                         int(data_out['hour_utc'].iloc[x]), int(data_out['minute'].iloc[x]), int(data_out['second'].iloc[x]),
#     157                         tzinfo=pytz.utc).astimezone(pytz.timezone('US/Central')).replace(tzinfo=None)
# --> 158             for x in range(len(data_out.index))]
#     159
#     160     merged_index = pd.date_range(start=data_out['date_time'].iloc[0].replace(second=0), end=data_out['date_time'].iloc[-1].replace(second=0), freq='S')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1628                 self._is_valid_integer(key, axis)
#    1629
# -> 1630             return self._get_loc(key, axis=axis)
#    1631
#    1632     def _convert_to_indexer(self, obj, axis=0, is_setter=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_loc(self, key, axis)
#     103
#     104     def _get_loc(self, key, axis=0):
# --> 105         return self.obj._ixs(key, axis=axis)
#     106
#     107     def _slice(self, obj, axis=0, kind=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _ixs(self, i, axis)
#     587                     return self.take(i, axis=axis, convert=True)
#     588                 else:
# --> 589                     return _index.get_value_at(self, i)
#     590
#     591     @property
#
# TypeError: Argument 'arr' has incorrect type (expected numpy.ndarray, got Series)

# %%
import get_price.quantgo_data as qd 
data_out = qd.get_continuous_bar_data(ticker='ECH2017',date_to=20161231,num_days_back=5)
# Out:
# ECH2017, 20161231
# An error occurred (404) when calling the HeadObject operation: Not Found

# %%
data_out[data_out['close']>50]
# Out:
#                      buy_volume       close        high  hour_minute  \
# 2016-12-22 18:00:00        33.0  104.796333  104.807500       1800.0
# 2016-12-22 18:05:00        22.0  104.808103  104.811667       1805.0
# 2016-12-22 18:10:00        14.0  104.803571  104.811471       1810.0
# 2016-12-22 18:15:00        15.0  104.798333  104.814615       1815.0
# 2016-12-22 18:20:00        34.0  104.820455  104.820909       1820.0
# 51308   287.0         NaN         NaN    89190.0    ...      1010.0
# 52450   350.0         NaN         NaN    89815.0    ...      1015.0
# 53568   413.0         NaN         NaN        NaN    ...      1020.0
# 54581   477.0         NaN         NaN        NaN    ...      1020.0
# 55574     NaN         NaN         NaN        NaN    ...         NaN
#
#        change1_instant  high1_instant  low1_instant  change2  change5  \
# 47302           -545.0        87540.0       86785.0   1790.0   1590.0
# 48205           -550.0        87685.0       87225.0   1780.0   1550.0
# 49176           -555.0            NaN       87710.0   1760.0   1515.0
# 50210           -555.0            NaN       88215.0   1760.0   1505.0
# 51308           -560.0            NaN       88765.0   1760.0   1495.0
# 52450           -575.0            NaN       89425.0   1760.0   1485.0
# 53568           -585.0            NaN           NaN   1760.0   1475.0
# 54581           -595.0            NaN           NaN   1755.0   1460.0
# 55574              NaN            NaN           NaN      NaN      NaN
#
#        change10  change20  change_5  change_1
# 47302    1215.0    1635.0     325.0    -575.0
# 48205    1185.0    1595.0     310.0    -580.0
# 49176    1145.0    1550.0     290.0    -590.0
# 50210    1135.0    1535.0     275.0    -600.0
# 51308    1110.0    1515.0     290.0    -595.0
# 52450    1095.0    1520.0     265.0    -590.0
# 53568    1080.0    1515.0     260.0    -585.0
# 54581    1060.0    1515.0     255.0    -580.0
# 55574       NaN       NaN       NaN       NaN
#
# [9 rows x 23 columns]

# %%
import get_price.quantgo_data as qd
data_out = qd.get_tick_data(ticker='TUH2017',utc_doubledate=20170126)
data_out
# Out:
#          UTCDate    UTCTime  LocalDate  LocalTime Ticker  SecurityID  \
# 0       20170126          0   20170125  180000000   ZTH7      596182
# 1       20170126          0   20170125  180000000   ZTH7      596182
# 2       20170126          0   20170125  180000000   ZTH7      596182
# 3       20170126          0   20170125  180000000   ZTH7      596182
# 4       20170126          4   20170125  180000004   ZTH7      596182
# 5       20170126         10   20170125  180000010   ZTH7      596182
# 6       20170126         27   20170125  180000027   ZTH7      596182
# 7       20170126         27   20170125  180000027   ZTH7      596182
# 8       20170126       5787   20170125  180005787   ZTH7      596182
# 9       20170126       5806   20170125  180005806   ZTH7      596182
# 10      20170126       5817   20170125  180005817   ZTH7      596182
# 11      20170126      10467   20170125  180010467   ZTH7      596182
# 12      20170126      13080   20170125  180013080   ZTH7      596182
# 13      20170126      33170   20170125  180033170   ZTH7      596182
# 14      20170126      33171   20170125  180033171   ZTH7      596182
# 15      20170126      33176   20170125  180033176   ZTH7      596182
# 16      20170126      33177   20170125  180033177   ZTH7      596182
# 17      20170126      33189   20170125  180033189   ZTH7      596182
# 18      20170126      33199   20170125  180033199   ZTH7      596182
# 19      20170126      33200   20170125  180033200   ZTH7      596182
# 20      20170126      33200   20170125  180033200   ZTH7      596182
# 21      20170126      33200   20170125  180033200   ZTH7      596182
# 22      20170126      33446   20170125  180033446   ZTH7      596182
# 23      20170126      33635   20170125  180033635   ZTH7      596182
# 24      20170126      33643   20170125  180033643   ZTH7      596182
# 25      20170126      33645   20170125  180033645   ZTH7      596182
# 26      20170126      33645   20170125  180033645   ZTH7      596182
# 20             1           QUOTE BID  108.335937      1277      30      0
# 21             1          QUOTE SELL  108.343750        98       4      0
# 22             1           QUOTE BID  108.335937      1290      31      0
# 23             1          QUOTE SELL  108.343750       158       5      0
# 24             1          QUOTE SELL  108.343750       347       6      0
# 25             1           QUOTE BID  108.335937      1255      31      0
# 26             1           QUOTE BID  108.335937      1244      31      0
# 27             1           QUOTE BID  108.335937      1233      31      0
# 28             1          QUOTE SELL  108.343750       447       7      0
# 29             1           QUOTE BID  108.335937      1234      32      0
# ...          ...                 ...         ...       ...     ...    ...
# 257845         1  IMPLIED QUOTE SELL  108.367188         6       0      1
# 257846         1  IMPLIED QUOTE SELL  108.367188         4       0      1
# 257847         1  IMPLIED QUOTE SELL  108.367188        10       0      1
# 257848         1  IMPLIED QUOTE SELL  108.367188         1       0      1
# 257849         1  IMPLIED QUOTE SELL  108.375000        10       0      1
# 257850         1  IMPLIED QUOTE SELL  108.367188         7       0      1
# 257851         1  IMPLIED QUOTE SELL  108.367188         6       0      1
# 257852         1  IMPLIED QUOTE SELL  108.375000        10       0      1
# 257853         1           QUOTE BID  108.351563       992      21      0
# 257854         1   IMPLIED QUOTE BID  108.351563         3       0      1
# 257855         1   IMPLIED QUOTE BID  108.351563         9       0      1
# 257856         1   IMPLIED QUOTE BID  108.351563        15       0      1
# 257857         1   IMPLIED QUOTE BID  108.351563        14       0      1
# 257858         1   IMPLIED QUOTE BID  108.351563         2       0      1
# 257859         1   IMPLIED QUOTE BID  108.351563         1       0      1
# 257860         1   IMPLIED QUOTE BID  108.343750        14       0      1
# 257861         1  IMPLIED QUOTE SELL  108.367188        10       0      1
# 257862         1          QUOTE SELL  108.359375       704      12      0
# 257863         1           QUOTE BID  108.351563       985      21      0
# 257864         1           QUOTE BID  108.351563       922      21      0
# 257865         1           QUOTE BID  108.351563       914      20      0
# 257866         1           QUOTE BID  108.351563       911      19      0
# 257867         1           QUOTE BID  108.351563       858      18      0
# 257868         1           QUOTE BID  108.351563       821      17      0
# 257869         1          QUOTE SELL  108.359375       804      13      0
# 257870         1           QUOTE BID  108.351563       815      16      0
# 257871         1           QUOTE BID  108.351563       805      15      0
# 257872         1           QUOTE BID  108.351563       755      14      0
# 257873         1          QUOTE SELL  108.359375       561      12      0
# 257874         1          QUOTE SELL  108.359375       461      11      0
#
# [257875 rows x 12 columns]

# %%
import matplotlib.pyplot as plt


plt.plot(range(len(data_out.index)),data_out['close'])
plt.grid()         
         
plt.show()

# %%
import signals.intraday_futures_experimental as ife
summary_stats = ife.get_crossover_duration(ticker='CLH2018',date_to=20180108)
summary_stats
# Out:
# {'duration_25': 5.0,
#  'duration_75': 35.0,
#  'mean_duration': 26.73821989528796,
#  'num_crossovers': 192}

# %%
quantile_out = crossover_data['crossover_duration'].quantile([0.25, 0.75])
quantile_out[0.25]
# Out:
# 5.0

# %%
import get_price.quantgo_data as qd
import warnings
warnings.filterwarnings("ignore")
data_out = qd.get_continuous_bar_data(ticker='LCJ2018',date_to=20180108,num_days_back=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# An error occurred (404) when calling the HeadObject operation: Not Found

# %%
quantgo_api.
