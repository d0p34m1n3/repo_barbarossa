# %%
import contract_utilities.expiration as exp
date_list = exp.get_bus_day_list(date_from=20160701,date_to=20160812)
date_list
# Out:
# [20160701,
#  20160705,
#  20160706,
#  20160707,
#  20160708,
#  20160711,
#  20160712,
#  20160713,
#  20160714,
#  20160715,
#  20160718,
#  20160719,
#  20160720,
#  20160721,
#  20160722,
#  20160725,
#  20160726,
#  20160727,
#  20160728,
#  20160729,
#  20160801,
#  20160802,
#  20160803,
#  20160804,
#  20160805,
#  20160808,
#  20160809,
#  20160810,
#  20160811,
#  20160812]

# %%
import opportunity_constructs.intraday_breakouts as ibo
result_list = []
for i in range(len(date_list)):
    print(date_list[i])
    out_frame = ibo.generate_ibo_sheet_4date(date_to=date_list[i])
    sheet_4date = out_frame['sheet_4date']
    sheet_4date['trade_date'] = date_list[i]
    result_list.append(sheet_4date)
# Out:
# 20160701
# 20160705
# 20160706
# 20160707
# 20160708
# 20160711
# 20160712
# 20160713
# 20160714
# 20160715
# 20160718
# 20160719
# 20160720
# 20160721
# 20160722
# 20160725
# 20160726
# 20160727
# 20160728
# 20160729
# 20160801
# 20160802
# 20160803
# 20160804
# 20160805
# 20160808
# 20160809
# 20160810
# 20160811
# 20160812

# %%
import pandas as pd
merged_frame = pd.concat(result_list)

import matplotlib.pyplot as plt
plt.plot(merged_frame['daily_pnl'].cumsum())
plt.grid()
plt.show()

# %%
i=17
selected_data = merged_frame[merged_frame['ticker_head']==merged_frame['ticker_head'].iloc[i]]
selected_data
# Out:
#      ticker ticker_head  daily_pnl  trade_date
# 17  KCU2016          KC   -309.375    20160701
# 17  KCU2016          KC      0.000    20160705
# 17  KCU2016          KC    534.375    20160706
# 17  KCU2016          KC    346.875    20160707
# 17  KCU2016          KC   -187.500    20160708
# 17  KCU2016          KC    159.375    20160711
# 17  KCU2016          KC    -84.375    20160712
# 17  KCU2016          KC    187.500    20160713
# 17  KCU2016          KC    403.125    20160714
# 17  KCU2016          KC   -571.875    20160715
# 17  KCU2016          KC   1293.750    20160718
# 17  KCU2016          KC    590.625    20160719
# 17  KCU2016          KC    253.125    20160720
# 17  KCU2016          KC   -421.875    20160721
# 17  KCU2016          KC    -75.000    20160722
# 17  KCU2016          KC   -496.875    20160725
# 17  KCU2016          KC      9.375    20160726
# 17  KCU2016          KC   -328.125    20160727
# 17  KCU2016          KC   -215.625    20160728
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(selected_data['daily_pnl'].cumsum())
plt.grid()
plt.show()

# %%
import math as m
m.sqrt(252)*selected_data['daily_pnl'].mean()/(selected_data['daily_pnl'].std())
# Out:
# 4.031939425363214

# %%
import pandas as pd
grouped = merged_frame.groupby('trade_date')

portfolio = pd.DataFrame()
portfolio['pnl'] = grouped['daily_pnl'].sum()

import matplotlib.pyplot as plt
plt.plot(portfolio['pnl'].cumsum())
plt.grid()
plt.show()

# %%
import math as m
m.sqrt(252)*portfolio['pnl'].mean()/(portfolio['pnl'].std())
# Out:
# 6.580754588779235

# %%
merged_frame.sort('daily_pnl')
# Out:
#      ticker  daily_pnl  trade_date
# 14  GCQ2016  -1000.000    20160708
# 12  FCQ2016   -818.750    20160720
# 25   SX2016   -781.250    20160715
# 24  RBQ2016   -678.300    20160701
# 12  FCQ2016   -662.500    20160728
# 12  FCQ2016   -662.500    20160727
# 24  RBQ2016   -648.900    20160706
# 25   SX2016   -643.750    20160720
# 24  RBQ2016   -632.100    20160715
# 12  FCQ2016   -618.750    20160708
# 27  SIU2016   -600.000    20160707
# 27  SIU2016   -600.000    20160722
# 15  HOQ2016   -594.300    20160706
# 24  RBQ2016   -583.800    20160711
# 27  SIU2016   -575.000    20160727
# 17  KCU2016   -571.875    20160715
# 14  GCQ2016   -570.000    20160706
# 12  FCQ2016   -568.750    20160726
# 27  SIU2016   -562.500    20160719
# 14  GCQ2016   -560.000    20160701
# 15  HOQ2016   -537.600    20160714
# 25   SX2016   -537.500    20160706
# 12  FCQ2016   -531.250    20160713
# 14  GCQ2016   -520.000    20160707
# 27  SIU2016   -512.500    20160715
# 15  HOQ2016   -510.300    20160712
# ...

# %%
import futures_charts.intraday_charts as ic
ic.get_intraday_breakout_chart(ticker='RBU2016',trade_date=20160804)

# %%
import signals.intraday_futures_signals as ifs
signals_output = ifs.get_intraday_trend_signals(ticker='RBU2016',date_to=20160804)
signals_output['daily_pnl']
# Out:
# RBU2016
# -989.10000000000764

# %%
import formats.intraday_futures_strategy_formats as ifsf
ifsf.generate_ibo_formatted_output(report_date=20160812)

# %%
import opportunity_constructs.intraday_breakouts as ib
wuhu = ib.generate_ibo_sheet_4date(date_to=20160812)
wuhu['sheet_4date']
# Out:
#      ticker ticker_head  daily_pnl
# 0   ADU2016          AD        NaN
# 1    BV2016           B        NaN
# 2   BOZ2016          BO        NaN
# 3   BPU2016          BP        NaN
# 4    CZ2016           C        NaN
# 5   CCZ2016          CC        NaN
# 6   CDU2016          CD        NaN
# 7   CLU2016          CL        NaN
# 8   CTZ2016          CT        NaN
# 9   ECU2016          EC        NaN
# 10  EDZ2016          ED        NaN
# 11  ESU2016          ES        NaN
# 12  FCU2016          FC        NaN
# 13  FVU2016          FV        NaN
# 14  GCZ2016          GC        NaN
# 15  HOU2016          HO        NaN
# 16  JYU2016          JY        NaN
# 17  KCZ2016          KC        NaN
# 18  KWU2016          KW        NaN
# 19  LCV2016          LC        NaN
# 20  LNV2016          LN        NaN
# 21  NGU2016          NG        NaN
# 22  NQU2016          NQ        NaN
# 23  OJU2016          OJ        NaN
# 24  RBU2016          RB        NaN
# 25   SX2016           S        NaN
# ...

# %%
import contract_utilities.contract_meta_info as cmi
import datetime as dt
dt.time(13,1)>cmi.last_trade_hour_minute['LN']
# Out:
# False

# %%
import opportunity_constructs.utilities as opUtil
ticker = 'LNV2016'
date_list = 20160711
intraday_data = opUtil.get_aligned_futures_data_intraday(contract_list=[ticker],
                                       date_list=[date_list])

#intraday_data.index[0].time<cmi.last_trade_hour_minute['LN'].hour

cmi.last_trade_hour_minute['LN'].hour

intraday_data.index[0].to_datetime().time()>cmi.last_trade_hour_minute['LN']

selection_indx = [x for x in range(len(intraday_data.index)) if intraday_data.index[x].to_datetime().time()<cmi.last_trade_hour_minute['LN']]

# %%
intraday_data.iloc[selection_indx]
# Out:
#                             c1
#                     best_bid_p best_bid_q best_ask_p best_ask_q
# 2016-07-11 04:30:00        NaN        NaN        NaN        NaN
# 2016-07-11 04:31:00     68.300          5     69.550          8
# 2016-07-11 04:32:00     68.300          5     69.550          8
# 2016-07-11 04:33:00     68.300          5     69.550          8
# 2016-07-11 04:34:00     68.300          5     69.550          8
# 2016-07-11 04:35:00     68.300          5     69.550          8
# 2016-07-11 04:36:00     68.300          5     69.550          8
# 2016-07-11 04:37:00     68.300          5     69.550          8
# 2016-07-11 04:38:00     68.300          5     69.550          8
# 2016-07-11 04:39:00     68.300          5     69.550          8
# 2016-07-11 04:40:00     68.300          5     69.550          8
# 2016-07-11 04:41:00     68.300          5     69.550          8
# 2016-07-11 04:42:00     68.300          5     69.550          8
# ...
