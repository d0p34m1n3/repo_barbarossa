# %%
import sys
sys.path.append(r'C:\Users\kocat_000\quantFinance\PycharmProjects')
import backtesting.utilities as bu
dates_output = bu.get_backtesting_dates(date_to=20160219,years_back=10)
double_dates = sorted(dates_output['double_dates'],reverse=True)
selected_dates = double_dates
selected_dates
# Out:
# [20160217,
#  20160210,
#  20160203,
#  20160127,
#  20160120,
#  20160113,
#  20160106,
#  20151230,
#  20151223,
#  20151216,
#  20151209,
#  20151202,
#  20151125,
#  20151118,
#  20151111,
#  20151104,
#  20151028,
#  20151021,
#  20151014,
#  20151007,
#  20150930,
#  20150923,
#  20150916,
#  20150909,
#  20150902,
#  20150826,
#  20150819,
#  20150812,
#  20150805,
#  20150729,
#  20150722,
#  20150715,
#  20150708,
#  20150701,
#  20150624,
#  20150617,
#  20150610,
#  20150603,
#  20150527,
#  20150520,
#  20150513,
#  20150506,
#  20150429,
#  20150422,
#  20150415,
#  20150408,
#  20150401,
#  20150325,
#  20150318,
#  20150311,
#  20150304,
#  20150225,
#  20150218,
#  20150211,
#  20150204,
#  20150128,
#  20150121,
#  20150114,
#  20150107,
#  20141231,
#  20141224,
#  20141217,
#  20141210,
#  20141203,
#  20141126,
#  20141119,
#  20141112,
#  20141105,
#  20141029,
#  20141022,
#  20141015,
#  20141008,
#  20141001,
#  20140924,
#  20140917,
#  20140910,
#  20140903,
#  20140827,
#  20140820,
#  20140813,
#  20140806,
#  20140730,
#  20140723,
#  20140716,
#  20140709,
#  20140702,
#  20140625,
#  20140618,
#  20140611,
#  20140604,
#  20140528,
#  20140521,
#  20140514,
#  20140507,
#  20140430,
#  20140423,
#  20140416,
#  20140409,
#  20140402,
#  20140326,
#  20140319,
#  20140312,
#  20140305,
#  20140226,
#  20140219,
#  20140212,
#  20140205,
#  20140129,
#  20140122,
#  20140115,
#  20140108,
#  20131218,
#  20131211,
#  20131204,
#  20131127,
#  20131120,
#  20131113,
#  20131106,
#  20131030,
#  20131023,
#  20131016,
#  20131009,
#  20131002,
#  20130925,
#  20130918,
#  20130911,
#  20130904,
#  20130828,
#  20130821,
#  20130814,
#  20130807,
#  20130731,
#  20130724,
#  20130717,
#  20130710,
#  20130703,
#  20130626,
#  20130619,
#  20130612,
#  20130605,
#  20130529,
#  20130522,
#  20130515,
#  20130508,
#  20130501,
#  20130424,
#  20130417,
#  20130410,
#  20130403,
#  20130327,
#  20130320,
#  20130313,
#  20130306,
#  20130227,
#  20130220,
#  20130213,
#  20130206,
#  20130130,
#  20130123,
#  20130116,
#  20130109,
#  20130102,
#  20121226,
#  20121219,
#  20121212,
#  20121205,
#  20121128,
#  20121121,
#  20121114,
#  20121107,
#  20121031,
#  20121024,
#  20121017,
#  20121010,
#  20121003,
#  20120926,
#  20120919,
#  20120912,
#  20120905,
#  20120829,
#  20120822,
#  20120815,
#  20120808,
#  20120801,
#  20120725,
#  20120718,
#  20120711,
#  20120627,
#  20120620,
#  20120613,
#  20120606,
#  20120530,
#  20120523,
#  20120516,
#  20120509,
#  20120502,
#  20120425,
#  20120418,
#  20120411,
#  20120404,
#  20120328,
#  20120321,
#  20120314,
#  20120307,
#  20120229,
#  20120222,
#  20120215,
#  20120208,
#  20120201,
#  20120125,
#  20120118,
#  20120111,
#  20120104,
#  20111228,
#  20111221,
#  20111214,
#  20111207,
#  20111130,
#  20111123,
#  20111116,
#  20111109,
#  20111102,
#  20111026,
#  20111019,
#  20111012,
#  20111005,
#  20110928,
#  20110921,
#  20110914,
#  20110907,
#  20110831,
#  20110824,
#  20110817,
#  20110810,
#  20110803,
#  20110727,
#  20110720,
#  20110713,
#  20110706,
#  20110629,
#  20110622,
#  20110615,
#  20110608,
#  20110601,
#  20110525,
#  20110518,
#  20110511,
#  20110504,
#  20110427,
#  20110420,
#  20110413,
#  20110406,
#  20110330,
#  20110323,
#  20110316,
#  20110309,
#  20110302,
#  20110223,
#  20110216,
#  20110209,
#  20110202,
#  20110126,
#  20110119,
#  20110112,
#  20110105,
#  20101229,
#  20101222,
#  20101215,
#  20101208,
#  20101201,
#  20101124,
#  20101117,
#  20101110,
#  20101103,
#  20101027,
#  20101020,
#  20101013,
#  20101006,
#  20100929,
#  20100922,
#  20100915,
#  20100908,
#  20100901,
#  20100825,
#  20100818,
#  20100811,
#  20100804,
#  20100728,
#  20100721,
#  20100714,
#  20100707,
#  20100630,
#  20100623,
#  20100616,
#  20100609,
#  20100602,
#  20100526,
#  20100519,
#  20100512,
#  20100505,
#  20100428,
#  20100421,
#  20100414,
#  20100407,
#  20100331,
#  20100324,
#  20100317,
#  20100310,
#  20100303,
#  20100224,
#  20100217,
#  20100210,
#  20100203,
#  20100127,
#  20100120,
#  20100113,
#  20100106,
#  20091230,
#  20091223,
#  20091216,
#  20091209,
#  20091202,
#  20091125,
#  20091118,
#  20091111,
#  20091104,
#  20091028,
#  20091021,
#  20091014,
#  20091007,
#  20090930,
#  20090923,
#  20090916,
#  20090909,
#  20090902,
#  20090826,
#  20090819,
#  20090812,
#  20090805,
#  20090729,
#  20090722,
#  20090715,
#  20090708,
#  20090701,
#  20090624,
#  20090617,
#  20090610,
#  20090603,
#  20090527,
#  20090520,
#  20090513,
#  20090506,
#  20090429,
#  20090422,
#  20090415,
#  20090408,
#  20090401,
#  20090325,
#  20090318,
#  20090311,
#  20090304,
#  20090225,
#  20090218,
#  20090211,
#  20090204,
#  20090128,
#  20090121,
#  20090114,
#  20090107,
#  20081231,
#  20081224,
#  20081217,
#  20081210,
#  20081203,
#  20081126,
#  20081119,
#  20081112,
#  20081105,
#  20081029,
#  20081022,
#  20081015,
#  20081008,
#  20081001,
#  20080924,
#  20080917,
#  20080910,
#  20080903,
#  20080827,
#  20080820,
#  20080813,
#  20080806,
#  20080730,
#  20080723,
#  20080716,
#  20080709,
#  20080702,
#  20080625,
#  20080618,
#  20080611,
#  20080604,
#  20080528,
#  20080521,
#  20080514,
#  20080507,
#  20080430,
#  20080423,
#  20080416,
#  20080409,
#  20080402,
#  20080326,
#  20080319,
#  20080312,
#  20080305,
#  20080227,
#  20080220,
#  20080213,
#  20080206,
#  20080130,
#  20080123,
#  20080116,
#  20080109,
#  20080102,
#  20071226,
#  20071219,
#  20071212,
#  20071205,
#  20071128,
#  20071121,
#  20071114,
#  20071107,
#  20071031,
#  20071024,
#  20071017,
#  20071010,
#  20071003,
#  20070926,
#  20070919,
#  20070912,
#  20070905,
#  20070829,
#  20070822,
#  20070815,
#  20070808,
#  20070801,
#  20070725,
#  20070718,
#  20070711,
#  20070627,
#  20070620,
#  20070613,
#  20070606,
#  20070530,
#  20070523,
#  20070516,
#  20070509,
#  20070502,
#  20070425,
#  20070418,
#  20070411,
#  20070404,
#  20070328,
#  20070321,
#  20070314,
#  20070307,
#  20070228,
#  20070221,
#  20070214,
#  20070207,
#  20070131,
#  20070124,
#  20070117,
#  20070110,
#  20070103,
#  20061227,
#  20061220,
#  20061213,
#  20061206,
#  20061129,
#  20061122,
#  20061115,
#  20061108,
#  20061101,
#  20061025,
#  20061018,
#  20061011,
#  20061004,
#  20060927,
#  20060920,
#  20060913,
#  20060906,
#  20060830,
#  20060823,
#  20060816,
#  20060809,
#  20060802,
#  20060726,
#  20060719,
#  20060712,
#  20060705,
#  20060628,
#  20060621,
#  20060614,
#  20060607,
#  20060531,
#  20060524,
#  20060517,
#  20060510,
#  20060503,
#  20060426,
#  20060419,
#  20060412,
#  20060405,
#  20060329,
#  20060322,
#  20060315,
#  20060308,
#  20060301,
#  20060222]

# %%
report_results_list = []

# I need to run this again start with B and now CL:

import opportunity_constructs.curve_pca as cpc

for date_to in selected_dates:
    print(date_to)
    cpc.get_curve_pca_report(ticker_head='CL',date_to=date_to,use_existing_filesQ=False)
# Out:
# 20160217
# 20160210
# 20160203
# 20160127
# 20160120
# 20160113
# 20160106
# 20151230
# 20151223
# 20151216
# 20151209
# 20151202
# 20151125
# 20151118
# 20151111
# 20151104
# 20151028
# 20151021
# 20151014
# 20151007
# 20150930
# 20150923
# 20150916
# 20150909
# 20150902
# 20150826
# 20150819
# 20150812
# 20150805
# 20150729
# 20150722
# 20150715
# 20150708
# 20150701
# 20150624
# 20150617
# 20150610
# 20150603
# 20150527
# 20150520
# 20150513
# 20150506
# 20150429
# 20150422
# 20150415
# 20150408
# 20150401
# 20150325
# 20150318
# 20150311
# 20150304
# 20150225
# 20150218
# 20150211
# 20150204
# 20150128
# 20150121
# 20150114
# 20150107
# 20141231
# 20141224
# 20141217
# 20141210
# 20141203
# 20141126
# 20141119
# 20141112
# 20141105
# 20141029
# 20141022
# 20141015
# 20141008
# 20141001
# 20140924
# 20140917
# 20140910
# 20140903
# 20140827
# 20140820
# 20140813
# 20140806
# 20140730
# 20140723
# 20140716
# 20140709
# 20140702
# 20140625
# 20140618
# 20140611
# 20140604
# 20140528
# 20140521
# 20140514
# 20140507
# 20140430
# 20140423
# 20140416
# 20140409
# 20140402
# 20140326
# 20140319
# 20140312
# 20140305
# 20140226
# 20140219
# 20140212
# 20140205
# 20140129
# 20140122
# 20140115
# 20140108
# 20131218
# 20131211
# 20131204
# 20131127
# 20131120
# 20131113
# 20131106
# 20131030
# 20131023
# 20131016
# 20131009
# 20131002
# 20130925
# 20130918
# 20130911
# 20130904
# 20130828
# 20130821
# 20130814
# 20130807
# 20130731
# 20130724
# 20130717
# 20130710
# 20130703
# 20130626
# 20130619
# 20130612
# 20130605
# 20130529
# 20130522
# 20130515
# 20130508
# 20130501
# 20130424
# 20130417
# 20130410
# 20130403
# 20130327
# 20130320
# 20130313
# 20130306
# 20130227
# 20130220
# 20130213
# 20130206
# 20130130
# 20130123
# 20130116
# 20130109
# 20130102
# 20121226
# 20121219
# 20121212
# 20121205
# 20121128
# 20121121
# 20121114
# 20121107
# 20121031
# 20121024
# 20121017
# 20121010
# 20121003
# 20120926
# 20120919
# 20120912
# 20120905
# 20120829
# 20120822
# 20120815
# 20120808
# 20120801
# 20120725
# 20120718
# 20120711
# 20120627
# 20120620
# 20120613
# 20120606
# 20120530
# 20120523
# 20120516
# 20120509
# 20120502
# 20120425
# 20120418
# 20120411
# 20120404
# 20120328
# 20120321
# 20120314
# 20120307
# 20120229
# 20120222
# 20120215
# 20120208
# 20120201
# 20120125
# 20120118
# 20120111
# 20120104
# 20111228
# 20111221
# 20111214
# 20111207
# 20111130
# 20111123
# 20111116
# 20111109
# 20111102
# 20111026
# 20111019
# 20111012
# 20111005
# 20110928
# 20110921
# 20110914
# 20110907
# 20110831
# 20110824
# 20110817
# 20110810
# 20110803
# 20110727
# 20110720
# 20110713
# 20110706
# 20110629
# 20110622
# 20110615
# 20110608
# 20110601
# 20110525
# 20110518
# 20110511
# 20110504
# 20110427
# 20110420
# 20110413
# 20110406
# 20110330
# 20110323
# 20110316
# 20110309
# 20110302
# 20110223
# 20110216
# 20110209
# 20110202
# 20110126
# 20110119
# 20110112
# 20110105
# 20101229
# 20101222
# 20101215
# 20101208
# 20101201
# 20101124
# 20101117
# 20101110
# 20101103
# 20101027
# 20101020
# 20101013
# 20101006
# 20100929
# 20100922
# 20100915
# 20100908
# 20100901
# 20100825
# 20100818
# 20100811
# 20100804
# 20100728
# 20100721
# 20100714
# 20100707
# 20100630
# 20100623
# 20100616
# 20100609
# 20100602
# 20100526
# 20100519
# 20100512
# 20100505
# 20100428
# 20100421
# 20100414
# 20100407
# 20100331
# 20100324
# 20100317
# 20100310
# 20100303
# 20100224
# 20100217
# 20100210
# 20100203
# 20100127
# 20100120
# 20100113
# 20100106
# 20091230
# 20091223
# 20091216
# 20091209
# 20091202
# 20091125
# 20091118
# 20091111
# 20091104
# 20091028
# 20091021
# 20091014
# 20091007
# 20090930
# 20090923
# 20090916
# 20090909
# 20090902
# 20090826
# 20090819
# 20090812
# 20090805
# 20090729
# 20090722
# 20090715
# 20090708
# 20090701
# 20090624
# 20090617
# 20090610
# 20090603
# 20090527
# 20090520
# 20090513
# 20090506
# 20090429
# 20090422
# 20090415
# 20090408
# 20090401
# 20090325
# 20090318
# 20090311
# 20090304
# 20090225
# 20090218
# 20090211
# 20090204
# 20090128
# 20090121
# 20090114
# 20090107
# 20081231
# 20081224
# 20081217
# 20081210
# 20081203
# 20081126
# 20081119
# 20081112
# 20081105
# 20081029
# 20081022
# 20081015
# 20081008
# 20081001
# 20080924
# 20080917
# 20080910
# 20080903
# 20080827
# 20080820
# 20080813
# 20080806
# 20080730
# 20080723
# 20080716
# 20080709
# 20080702
# 20080625
# 20080618
# 20080611
# 20080604
# 20080528
# 20080521
# 20080514
# 20080507
# 20080430
# 20080423
# 20080416
# 20080409
# 20080402
# 20080326
# 20080319
# 20080312
# 20080305
# 20080227
# 20080220
# 20080213
# 20080206
# 20080130
# 20080123
# 20080116
# 20080109
# 20080102
# 20071226
# 20071219
# 20071212
# 20071205
# 20071128
# 20071121
# 20071114
# 20071107
# 20071031
# 20071024
# 20071017
# 20071010
# 20071003
# 20070926
# 20070919
# 20070912
# 20070905
# 20070829
# 20070822
# 20070815
# 20070808
# 20070801
# 20070725
# 20070718
# 20070711
# 20070627
# 20070620
# 20070613
# 20070606
# 20070530
# 20070523
# 20070516
# 20070509
# 20070502
# 20070425
# 20070418
# 20070411
# 20070404
# 20070328
# 20070321
# 20070314
# 20070307
# 20070228
# 20070221
# 20070214
# 20070207
# 20070131
# 20070124
# 20070117
# 20070110
# 20070103
# 20061227
# 20061220
# 20061213
# 20061206
# 20061129
# 20061122
# 20061115
# 20061108
# 20061101
# 20061025
# 20061018
# 20061011
# 20061004
# 20060927
# 20060920
# 20060913
# 20060906
# 20060830
# 20060823
# 20060816
# 20060809
# 20060802
# 20060726
# 20060719
# 20060712
# 20060705
# 20060628
# 20060621
# 20060614
# 20060607
# 20060531
# 20060524
# 20060517
# 20060510
# 20060503
# 20060426
# 20060419
# 20060412
# 20060405
# 20060329
# 20060322
# 20060315
# 20060308
# 20060301
# 20060222

# %%
pd.DataFrame.from_items([('monthSpread',[1]*12+[6]*2),
                        ('ticker_month_front',list(range(1,13))+[6]+[12]),
                        ('z_seasonal_mean',[0]*14)])
# Out:
#     monthSpread  ticker_month_front  z_seasonal_mean
# 0             1                   1                0
# 1             1                   2                0
# 2             1                   3                0
# 3             1                   4                0
# 4             1                   5                0
# 5             1                   6                0
# 6             1                   7                0
# 7             1                   8                0
# 8             1                   9                0
# 9             1                  10                0
# 10            1                  11                0
# 11            1                  12                0
# 12            6                   6                0
# 13            6                  12                0

# %%
import backtesting.backtest_curve_pca as bcp
ticker_head = 'B'

backtest_output = bcp.backtest_curve_pca(ticker_head=ticker_head,
                                         date_to=20160219,
                                        years_back=5,
                                        indicator='z')
pnl_frame = backtest_output['pnl_frame']
report_results_list = backtest_output['report_results_list']

backtest_output = bcp.backtest_curve_pca(ticker_head=ticker_head,
                                         date_to=20160219,
                                        years_back=5,
                                        indicator='z2')
pnl_frame2 = backtest_output['pnl_frame']
report_results_list2 = backtest_output['report_results_list']

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(pnl_frame['pnl'],pnl_frame2['pnl'])
plt.grid()  
plt.show()

# %%
print(pnl_frame['pnl'].mean())
print(pnl_frame2['pnl'].mean())

pnl_frame.tail()
# Out:
# 9.162126393929979
# 8.800473203697626
#      settle_date  num_contracts         z  residual  short_side_weight  \
# 253     20160120              4  2.742500   0.19625           1.245902
# 254     20160127              4  2.037500   0.15800           1.387978
# 255     20160203              4  2.600000   0.20150           1.335165
# 256     20160210              3  3.843333   0.26200           1.223881
# 257     20160217              4  2.587500   0.17075           1.231183
#
#            pnl
# 253 -16.762295
# 254 -42.650273
# 255   3.420330
# 256  24.776119
# 257  15.954301

# %%
pnl_frame2.tail()
# Out:
#      settle_date  num_contracts         z  residual  short_side_weight  \
# 253     20160120              4  2.690000    0.1950           1.163265
# 254     20160127              4  2.120000    0.1645           1.413265
# 255     20160203              4  2.502500    0.2065           1.412088
# 256     20160210              3  3.693333    0.2620           1.223881
# 257     20160217              4  2.512500    0.1690           1.248756
#
#            pnl
# 253 -11.581633
# 254 -34.668367
# 255  19.574176
# 256  24.776119
# 257   6.902985

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(pnl_frame.index,pnl_frame['pnl'].cumsum(),
         pnl_frame2.index,pnl_frame2['pnl'].cumsum())
plt.grid()  
plt.legend(['z','z2'])
plt.show()

# %%
import backtesting.backtest_stats as bs

bs.get_indicator_rr_table(trade_data=pnl_frame,
                                          indicator_name='z',
                                          strategy_class='curve_pca',
                                         long_pnl_field='pnl',
                                         short_pnl_field='pnl')
# Out:
#    indicator_ulimit   mean_pnl  reward_risk
# 0               NaN  12.444299     0.361216
# 1          2.216944  20.693727     1.443444
# 2          1.892222  16.977163     3.561561
# 3          1.760833  -1.295129    -0.077058
# 4          1.612870  19.849023     1.336902
# 5          1.404074  15.348562     0.414729
# 6          1.269167   7.987753     0.531814
# 7          1.142963  -7.924739    -0.127017
# 8          0.960278  -4.575610    -0.102149

# %%
bs.get_indicator_rr_table(trade_data=pnl_frame2,
                                          indicator_name='z',
                                          strategy_class='curve_pca',
                                         long_pnl_field='pnl',
                                         short_pnl_field='pnl')
# Out:
#    indicator_ulimit   mean_pnl  reward_risk
# 0               NaN  11.662050     0.230743
# 1          1.980833   7.742251     0.402499
# 2          1.682963  18.680222     1.451006
# 3          1.482500  11.031402     0.486834
# 4          1.341944   4.410563     0.156200
# 5          1.209537  28.384680     0.876864
# 6          1.085000 -11.988566    -0.290526
# 7          0.976111  -1.113182    -0.028060
# 8          0.825556  -7.960965    -0.202886

# %%
import signals.futures_signals as fs
import pandas as pd
seasonality_adjustment = fs.get_pca_seasonality_adjustments(ticker_head='CL',years_back=5)

seasonality_adjustment
# Out:
#     monthSpread  ticker_month_front  z_seasonal_mean
# 0             1                   1         0.426020
# 1             1                   2         0.234384
# 2             1                   3         0.239966
# 3             1                   4         0.056564
# 4             1                   5        -0.116241
# 5             1                   6         0.494932
# 6             1                   7         0.307695
# 7             1                   8         0.044812
# 8             1                   9        -0.073525
# 9             1                  10        -0.392736
# 10            1                  11        -0.555690
# 11            1                  12         0.533231
# 12            6                   6        -0.474816
# 13            6                  12         0.608872

# %%
import opportunity_constructs.curve_pca as cpc
import pandas as pd
output = cpc.get_curve_pca_report(ticker_head='B',date_to=20160127,use_existing_filesQ=False)


pca_results = output['pca_results']

pca_results
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-41-5bbfbfbcab36> in <module>()
#       1 import opportunity_constructs.curve_pca as cpc
#       2 import pandas as pd
# ----> 3 output = cpc.get_curve_pca_report(ticker_head='B',date_to=20160127,use_existing_filesQ=False)
#       4
#       5
#
# C:\Research\PycharmProjects\opportunity_constructs\curve_pca.py in get_curve_pca_report(**kwargs)
#     124
#     125     # notice that this date_to needs to me removed once we are done with backtesting
# --> 126     seasonality_adjustment = fs.get_pca_seasonality_adjustments(ticker_head=ticker_head,date_to=date_to)
#     127
#     128     pca_results = pd.merge(pca_results, seasonality_adjustment,how='left',on=['monthSpread','ticker_month_front'])
#
# C:\Research\PycharmProjects\signals\futures_signals.py in get_pca_seasonality_adjustments(**kwargs)
#     382         backtest_results = pd.read_pickle(backtest_output_dir + '/curve_pca/' + file_name + '.pkl')
#     383
# --> 384     entire_report = pd.concat(backtest_results['report_results_list'])
#     385     selected_report = entire_report[(entire_report['report_date'] <= date_to) & (entire_report['report_date'] >= date5_years_ago)]
#     386     selected_report = selected_report[(selected_report['tr_dte_front'] > 80)&(selected_report['monthSpread'] < 12)]
#
# UnboundLocalError: local variable 'backtest_results' referenced before assignment

# %%
# Z Score Term Structure?

import shared.utils as su
import pandas as pd
import numpy as np

summary_frame = pd.DataFrame()

selected_report = entire_report[entire_report['monthSpread']==1]

bucket_data_output = su.bucket_data(data_input=selected_report,
                                    bucket_var='tr_dte_front', num_buckets=10,ascending_q=True)
bucket_data_list  = bucket_data_output['bucket_data_list']
bucket_limits  = bucket_data_output['bucket_limits']

summary_frame['upper_limit'] = np.append(bucket_limits, np.NAN)
summary_frame['z_mean'] = [x['z'].mean() for x in bucket_data_list]
summary_frame['z_std'] = [x['z'].std() for x in bucket_data_list]

summary_frame

# removing <80 will eliminate majority of the term structure issues
# Out:
#    upper_limit    z_mean     z_std
# 0         45.0  0.408456  1.250307
# 1         81.0  0.301797  0.928611
# 2        117.0  0.086767  0.689903
# 3        153.0 -0.026689  0.524625
# 4        189.0 -0.035429  0.398673
# 5        225.0 -0.023018  0.346989
# 6        260.6 -0.007271  0.317351
# 7        297.0  0.047673  0.288364
# 8        332.0  0.040607  0.658878
# 9          NaN  0.132890  1.156774

# %%
# Z score seasonality?

import pandas as pd
import numpy as np

month_list = np.array([6,12])
entire_report = pd.concat(report_results_list)
z_score_list = []

for month_select in month_list:
    selected_report = entire_report[(entire_report['monthSpread']==6)&(entire_report['ticker_month_front']==month_select)]
    z_score_list.append(selected_report['z'].mean())

pd.DataFrame.from_items([('month',month_list),('z-score',z_score_list)])

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(pnl_frame['pnl'].cumsum())
plt.grid()               
plt.show()

# %%
pnl_frame

# %%
import backtesting.backtest_stats as bs
bs.get_indicator_rr_table(trade_data=pnl_frame,
                          indicator_name='z',
                         long_pnl_field='pnl',
                         short_pnl_field='pnl',
                         strategy_class='curve_pca')

# %%
report_results_list[41]

# %%
# impact of zscore:

print(pnl_frame[pnl_frame['z']<0.5]['pnl'].sum())
print(pnl_frame[pnl_frame['z']>2]['pnl'].sum())

# %%
pnl_frame_sorted[pnl_frame_sorted['pnl']<-0.3]

# %%
pnl_frame_sorted['pnl'].max()

pnl_frame_sorted[pnl_frame_sorted['pnl']>0.5]

# %%
import opportunity_constructs.curve_pca as cpc
import datetime as dt
# use_existing_filesQ=False
#daily_report = cpc.get_curve_pca_report(ticker_head='CL',date_to=20070718,use_existing_filesQ=False)
daily_report[0].index[-1].to_datetime()!=dt.datetime(2007,7,18)

# %%
import opportunity_constructs.curve_pca as cpc
daily_report = cpc.get_curve_pca_report(ticker_head='CL',date_to=20160114,use_existing_filesQ=True)
daily_report['pca_results'].sort('z',ascending=True,inplace=True)
daily_report['pca_results']

# %%
daily_report = cpc.get_curve_pca_report(ticker_head='CL',date_to=20070727)
daily_report = daily_report['pca_results']
daily_report

# %%
if median_factor_load2>0:
    daily_report_filtered = daily_report[daily_report['factor_load2']>=0]
else:
    daily_report_filtered = daily_report[daily_report['factor_load2']<=0]
    
daily_report_filtered.sort('z',ascending=True,inplace=True)
num_contract_4side = round(len(daily_report_filtered.index)/4)
long_side = daily_report_filtered.iloc[:num_contract_4side]
short_side = daily_report_filtered.iloc[-num_contract_4side:]
short_side_weight = long_side['factor_load1'].sum()/short_side['factor_load1'].sum()

# %%
short_side

# %%
daily_report = cpc.get_curve_pca_report(ticker_head='CL',date_to=20070530)
daily_report = daily_report['pca_results']


daily_report.sort('z',ascending=True,inplace=True)
daily_report
