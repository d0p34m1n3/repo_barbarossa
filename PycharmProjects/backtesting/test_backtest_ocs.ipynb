# %%
import contract_utilities.expiration as exp
date_list = exp.get_bus_day_list(date_from=20090101, date_to=20170106)

# %%
import opportunity_constructs.spread_carry as sc

for i in range(len(date_list)):
    print(date_list[i])
    sc.generate_spread_carry_sheet_4date(report_date=date_list[i])
# Out:
# 20090102
# 20090105
# 20090106
# 20090107
# 20090108
# 20090109
# 20090112
# 20090113
# 20090114
# 20090115
# 20090116
# 20090120
# 20090121
# 20090122
# 20090123
# 20090126
# 20090127
# 20090128
# 20090129
# 20090130
# 20090202
# 20090203
# 20090204
# 20090205
# 20090206
# 20090209
# 20090210
# 20090211
# 20090212
# 20090213
# 20090217
# 20090218
# 20090219
# 20090220
# 20090223
# 20090224
# 20090225
# 20090226
# 20090227
# 20090302
# 20090303
# 20090304
# 20090305
# 20090306
# 20090309
# 20090310
# 20090311
# 20090312
# 20090313
# 20090316
# 20090317
# 20090318
# 20090319
# 20090320
# 20090323
# 20090324
# 20090325
# 20090326
# 20090327
# 20090330
# 20090331
# 20090401
# 20090402
# 20090403
# 20090406
# 20090407
# 20090408
# 20090409
# 20090413
# 20090414
# 20090415
# 20090416
# 20090417
# 20090420
# 20090421
# 20090422
# 20090423
# 20090424
# 20090427
# 20090428
# 20090429
# 20090430
# 20090501
# 20090504
# 20090505
# 20090506
# 20090507
# 20090508
# 20090511
# 20090512
# ...

# %%
import opportunity_constructs.overnight_calendar_spreads as ocs
import pandas as pd

backtest_result_list = []

for i in range(len(date_list)):
    print(date_list[i])
    backtest_output = ocs.generate_overnight_spreads_sheet_4date(date_to=date_list[i])
    if backtest_output['success']:
        overnight_calendars = backtest_output['overnight_calendars']
        overnight_calendars['report_date'] = date_list[i]
        backtest_result_list.append(backtest_output['overnight_calendars'])
        
backtest_frame = pd.concat(backtest_result_list)
backtest_frame = backtest_frame[backtest_frame['trDte1']>0]
# Out:
# 20090102
# 20090105
# 20090106
# 20090107
# 20090108
# 20090109
# 20090112
# 20090113
# 20090114
# 20090115
# 20090116
# 20090120
# 20090121
# 20090122
# 20090123
# 20090126
# 20090127
# 20090128
# 20090129
# 20090130
# 20090202
# 20090203
# 20090204
# 20090205
# 20090206
# 20090209
# 20090210
# 20090211
# 20090212
# 20090213
# 20090217
# 20090218
# 20090219
# 20090220
# 20090223
# 20090224
# 20090225
# 20090226
# 20090227
# 20090302
# 20090303
# 20090304
# 20090305
# 20090306
# 20090309
# 20090310
# 20090311
# 20090312
# 20090313
# 20090316
# 20090317
# 20090318
# 20090319
# 20090320
# 20090323
# 20090324
# 20090325
# 20090326
# 20090327
# 20090330
# 20090331
# 20090401
# 20090402
# 20090403
# 20090406
# 20090407
# 20090408
# 20090409
# 20090413
# 20090414
# 20090415
# 20090416
# 20090417
# 20090420
# 20090421
# 20090422
# 20090423
# 20090424
# 20090427
# 20090428
# 20090429
# 20090430
# 20090501
# 20090504
# 20090505
# 20090506
# 20090507
# 20090508
# 20090511
# 20090512
# ...

# %%
# Clean Extreme Moves Here But Will Need To Check For These Later

backtest_frame = backtest_frame[(backtest_frame['normalized_target']>-5)&(backtest_frame['normalized_target']<5)]
backtest_frame['normalized_target_'] = -backtest_frame['normalized_target']

# %%
import backtesting.backtest_stats as bs
bs.get_chisquare_independence_results(indicator_name='underlying_zscore',
                                      target_name='normalized_target',dataframe_input=backtest_frame)
# Out:
# {'chi_square': 14.696768070781999, 'cramers_v': 0.014641374541377405}

# %%
backtest_frame.columns
# Out:
# Index(['ticker1', 'ticker2', 'tickerHead', 'tickerClass', 'trDte1', 'trDte2',
#        'multiplier', 'agg', 'cBack', 'ts_slope5', 'ts_slope10',
#        'linear_deviation5', 'linear_deviation10', 'momentum5', 'momentum10',
#        'underlying_zscore', 'spread_price', 'normalized_target', 'noise_100',
#        'contract_multiplier', 'report_date', 'normalized_target_'],
#       dtype='object')

# %%
import backtesting.backtest_stats as bs
import pandas as pd
from IPython.display import display
rank_indicators_output = bs.rank_indicators(trade_data=backtest_frame,
                                            indicator_list = ['ts_slope5', 'ts_slope10', 'linear_deviation5', 'linear_deviation10', 'momentum5', 'momentum10','underlying_zscore'],
                                            long_pnl_field='normalized_target',
                                            short_pnl_field='normalized_target_',
                                            strategy_class='ocs',granular_ranking_type='ticker_head')
indicator_ranking_total = rank_indicators_output['indicator_ranking_total']
indicator_ranking_granular_total = rank_indicators_output['indicator_ranking_granular_total']
display(indicator_ranking_total)
display(indicator_ranking_granular_total)
# Out:
#                                   indicator  ranking
# 20          [linear_deviation5, ts_slope10]       90
# 23          [linear_deviation5, momentum10]       89
# 39          [momentum10, linear_deviation5]       89
# 2                         linear_deviation5       88
# 14          [ts_slope10, linear_deviation5]       87
# 19           [linear_deviation5, ts_slope5]       85
# 22           [linear_deviation5, momentum5]       84
# 8            [ts_slope5, linear_deviation5]       82
# 33           [momentum5, linear_deviation5]       82
# 27  [linear_deviation10, linear_deviation5]       78
# 9           [ts_slope5, linear_deviation10]       72
# 24   [linear_deviation5, underlying_zscore]       71
# 34          [momentum5, linear_deviation10]       71
# 25          [linear_deviation10, ts_slope5]       70
# 45   [underlying_zscore, linear_deviation5]       60
# 7                   [ts_slope5, ts_slope10]       55
# 32                  [momentum5, ts_slope10]       53
# ...

# %%
import backtesting.backtest_stats as bs
bs.get_indicator_rr_table(trade_data=backtest_frame,indicator_name='underlying_zscore',
                          strategy_class='ocs',
                          long_pnl_field='normalized_target',
                                            short_pnl_field='normalized_target')

# ts_slope5 negative correlation
# ts_slope10 stronger negative correlation
# linear_deviation5 positive correlation ??
# linear_deviation10 weaker positive correlation ??
# momentum5 negative correlation
# momentum10 negative correlation
# underlying_zscore not a strong relationship
# Out:
#    indicator_ulimit  mean_pnl  reward_risk
# 0         -1.368938 -0.022738    -0.031528
# 1         -0.928891  0.003036     0.004442
# 2         -0.552029  0.007230     0.010712
# 3         -0.194188  0.010164     0.015290
# 4          0.155856  0.006484     0.009702
# 5          0.515969  0.004612     0.006711
# 6          0.896253 -0.002417    -0.003384
# 7          1.348255  0.005722     0.007772
# 8               NaN -0.012740    -0.015901

# %%
import backtesting.backtest_stats as bs
bs.get_indicator_rr_double_table(trade_data=backtest_frame,indicator_list=['linear_deviation5','momentum10'],
                                 strategy_class='ocs',
                                 long_pnl_field='normalized_target',
                                            short_pnl_field='normalized_target_')
# Out:
#    indicator1_ulimit  indicator2_ulimit  mean_pnl  reward_risk
# 0                NaN          -1.199003  0.066459     0.100272
# 1                NaN           1.073731  0.023435     0.040084
# 2                NaN                NaN  0.026801     0.032692
# 3           0.481828          -1.204667  0.015873     0.023151
# 4           0.481828           0.931250  0.001576     0.002757
# 5           0.481828                NaN -0.016989    -0.020632
# 6          -0.448879          -1.253140  0.033407     0.047836
# 7          -0.448879           0.974699  0.022623     0.040037
# 8          -0.448879                NaN  0.063194     0.089149

# %%
backtest_frame.columns
# Out:
# Index(['ticker1', 'ticker2', 'tickerHead', 'tickerClass', 'trDte1', 'trDte2',
#        'multiplier', 'agg', 'cBack', 'ts_slope5', 'ts_slope10',
#        'linear_deviation5', 'linear_deviation10', 'momentum5', 'momentum10',
#        'underlying_zscore', 'spread_price', 'normalized_target', 'noise_100',
#        'contract_multiplier', 'report_date', 'normalized_target_'],
#       dtype='object')

# %%
# Tickerhead Based Results:


short_frame = backtest_frame[(backtest_frame['momentum10']>1)&(backtest_frame['linear_deviation5']<-0.5)]
long_frame = backtest_frame[(backtest_frame['momentum10']<-1)&(backtest_frame['linear_deviation5']>0.5)]

short_frame['normalized_target']=-short_frame['normalized_target']


total_frame = pd.concat([long_frame,short_frame])

total_frame['raw_target'] = total_frame['normalized_target']*total_frame['noise_100']*total_frame['contract_multiplier']

grouped = total_frame.groupby('tickerHead')
grouped['raw_target'].mean()
# Out:
# tickerHead
# B      4.910056
# BO     0.040283
# C      4.212329
# CC     1.245819
# CL     5.592413
# CT    36.715576
# ED     0.244068
# FC    15.832634
# HO     2.843548
# KC     0.253378
# KW     3.514121
# LC    10.735818
# LN    20.494665
# NG     5.257601
# OJ    25.121951
# RB     7.328476
# S     12.550444
# SB     0.480687
# SM     9.388131
# W     11.230895
# Name: raw_target, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(grouped['normalized_target'].sum().cumsum())
plt.grid()         
         
plt.show()

# %%
16*grouped['normalized_target'].sum().mean()/grouped['normalized_target'].sum().std()
# Out:
# 2.4694779798363293

# %%
import get_price.get_futures_price as gfp
data_out = gfp.get_futures_price_preloaded(ticker_head='CL',settle_date=20170124)
data_out
# Out:
#        settle_date   ticker ticker_head  ticker_month  ticker_year  cal_dte  \
# 325544  2017-01-24  CLH2017          CL             3         2017       28
# 325579  2017-01-24  CLJ2017          CL             4         2017       56
# 325614  2017-01-24  CLK2017          CL             5         2017       86
# 325649  2017-01-24  CLM2017          CL             6         2017      118
# 325684  2017-01-24  CLN2017          CL             7         2017      147
# 325719  2017-01-24  CLQ2017          CL             8         2017      177
# 325754  2017-01-24  CLU2017          CL             9         2017      210
# 325789  2017-01-24  CLV2017          CL            10         2017      239
# 325824  2017-01-24  CLX2017          CL            11         2017      269
# 325859  2017-01-24  CLZ2017          CL            12         2017      300
# 325894  2017-01-24  CLF2018          CL             1         2018      329
# ...

# %%
import opportunity_constructs.overnight_calendar_spreads as ocs
ocs.get_overnight_spreads_4date(date_to=20170124)
# Out:
#      ticker1  ticker2  ticker3 tickerHead tickerClass  trDte1  trDte2  trDte3  \
# 0    LNG2017  LNG2017  LNJ2017         LN   Livestock      15      15      57
# 1    LNG2017  LNJ2017  LNK2017         LN   Livestock      15      57      76
# 2    LNJ2017  LNK2017  LNM2017         LN   Livestock      57      76      98
# 3    LNK2017  LNM2017  LNN2017         LN   Livestock      76      98     120
# 4    LNM2017  LNN2017  LNQ2017         LN   Livestock      98     120     140
# 5    LNN2017  LNQ2017  LNV2017         LN   Livestock     120     140     183
# 6    LNQ2017  LNV2017  LNZ2017         LN   Livestock     140     183     226
# 7    LNV2017  LNZ2017  LNG2018         LN   Livestock     183     226     267
# 8    LNZ2017  LNG2018  LNJ2018         LN   Livestock     226     267     307
# 9    LNG2018  LNJ2018  LNK2018         LN   Livestock     267     307     328
# 10   LNJ2018  LNK2018  LNM2018         LN   Livestock     307     328     350
# ...
