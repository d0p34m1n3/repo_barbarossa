# %%
import opportunity_constructs.stock_mr as mr
output_frame = mr.get_smrl_signal_frame()
stocks = output_frame['stocks']

print('Data success: ' + str(100*stocks['data_success'].sum()/len(stocks)))
stocks[stocks['rsi_success']==1]
# Out:
# Data success: 90.51094890510949
#            adx7  adx_success     atr10  atr_percent10  atr_success  \
# 692   50.160133            1  4.808558       5.394851            1
# 1674  47.230586            1  0.212192       5.991892            1
# 3759  47.581086            1  0.412958       4.096929            1
# 5989  51.429924            1  3.772968       4.065364            1
#
#       close_price  data_success  dollar_volume_success  file_success  \
# 692         82.75             1                      1             1
# 1674         3.12             1                      1             1
# 3759         9.35             1                      1             1
# 5989        68.99             1                      1             1
#
#           ma150  price_success       rsi3  rsi_success symbol  trend_success  \
# 692   66.619067              1  28.063056            1   NKTR              1
# 1674   3.030933              1  24.126123            1   CVEO              1
# ...

# %%
import opportunity_constructs.stock_mr as mr
output_frame = mr.get_smrs_signal_frame()
stocks = output_frame['stocks']

print('Data success: ' + str(100*stocks['data_success'].sum()/len(stocks)))
stocks[stocks['rsi_success']==1]

# sell 47 shares of  I
# Out:
# Data success: 90.51094890510949
#            adx7  adx_success     atr10  atr_percent10  atr_success  \
# 5097  73.409795            1  1.003386       8.438422            1
#
#       close_price  data_success  file_success  price_success       rsi3  \
# 5097        14.02             1             1              1  93.707862
#
#       rsi_success symbol  volume_success
# 5097            1   DRNA               1

# %%
stocks['close_price'].loc[stocks['rsi_success']==1].values[0]
# Out:
# 10.02

# %%
import opportunity_constructs.stock_mrl as mrl
output_frame = mrl.import opportunity_constructs.stock_mrl as mrl
output_frame = mrl.get_signal_frame(settle_date=20180410)(settle_date=20180410)

# %%
stocks = output_frame['stocks']
stocks[stocks['rsi_success']==1]
# Out:
#            adx7  adx_success     atr10  atr_percent10  atr_success  \
# 278   47.965845            1  0.303165       9.629713            1
# 1028  47.914496            1  0.557095       6.476821            1
#
#       close_price  data_success  dollar_volume_success  file_success  \
# 278          3.07             1                      1             1
# 1028         8.20             1                      1             1
#
#          ma150  price_success       rsi3  rsi_success symbol  trend_success  \
# 278   2.029824              1  14.834085            1   AMPE              1
# 1028  6.374633              1  20.803129            1    RUN              1
#
#       volume_success
# 278                1
# 1028               1

# %%
import signals.stock_mr as smr
smr.get_stock_mrl_signals(symbol='LL',settle_date=20180419)
# Out:
# {'adx7': nan,
#  'adx_success': 0,
#  'atr10': nan,
#  'atr_percent10': nan,
#  'atr_success': 0,
#  'close_price': 22.949999999999999,
#  'data_success': 1,
#  'dollar_volume_success': 1,
#  'file_success': 1,
#  'ma150': 29.216800000000053,
#  'price_success': 1,
#  'rsi3': nan,
#  'rsi_success': 0,
#  'symbol': 'LL',
#  'trend_success': 0,
#  'volume_success': 1}

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(price_data.index)),price_data['close'],
         range(len(price_data.index)),price_data['adjusted_close'])
plt.grid()         
         
plt.show()

# %%
import opportunity_constructs.stock_mrl as mrl
output_frame = mrl.get_signal_frame(settle_date=20180418)

# %%
stocks = output_frame['stocks']
candidates = stocks[stocks['atr_success']==1]
candidates
# Out:
#            adx7  adx_success  atr_percent10  atr_success  close_price  \
# 102   59.468040            1       4.008514            1        32.60
# 114   50.117923            1       5.320499            1        81.45
# 123   52.737218            1      17.713565            1         3.38
# 151   45.683036            1       8.313686            1        19.54
# 244   47.127932            1       5.472562            1        14.50
# 265   49.194608            1      11.434728            1         4.34
# 336   62.809917            1       4.950843            1        15.40
# 454   46.327377            1       5.127623            1         3.09
# 466   59.483498            1       4.148051            1        29.25
# 685   49.216201            1       5.663485            1        22.79
# 822   51.107100            1       5.205356            1         6.97
# 1126  54.267594            1       4.952823            1        35.97
# ...
